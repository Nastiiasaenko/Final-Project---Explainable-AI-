# %% [markdown]
# <a href="https://colab.research.google.com/github/Nastiiasaenko/Final-Project---Explainable-AI-/blob/main/Datasets_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Creating a bias traces dataset - Phase 1.
# In this project phase, I’m creating a comprehensive, enriched dataset covering multiple topics like COVID-19, politics, wars, general news, and more. For now, I’m focusing on COVID-19-related content, pulling data from diverse sources (e.g., news articles, Reddit, Twitter) to capture various biases and perspectives.
#
# My goal is to organize and enrich this data by adding metadata like source, political leaning, publication date, and themes. This dataset will allow me to analyze narratives, identify biases, and later compare AI-generated content to real-world data.
#
# ### Steps:
#
# **Collect Data**: Identify and gather datasets focused on COVID-19 with diverse viewpoints and metadata potential.
#
# **Preprocess Data:** Clean and standardize entries for consistency (e.g., removing duplicates, normalizing formats).
#
# **Annotate:** Add labels for bias, source, and themes (e.g., vaccination, lockdowns).
#
# **Integrate:** Merge datasets into one unified, structured dataset.
#
# **Validate:** Double-check annotations and dataset quality to ensure accuracy.
#
# Once I finish the COVID-19 segment, I’ll expand this process to other topics like politics and general news to build a robust, multi-topic dataset for later AI analysis.

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)

# %%
import pandas as pd
import spacy
from tqdm import tqdm
import os
from datetime import datetime

# %%
from google.colab import drive
import os

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Specify the path to your desired folder in Drive
drive_folder = '/content/drive/MyDrive/MIDS/XAI/XAI_Final_project'

# Ensure the folder exists
os.makedirs(drive_folder, exist_ok=True)

# Change the current working directory to the specified folder
os.chdir(drive_folder)

# Confirm the working directory
print("Current working directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current working directory: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project

# %% [markdown]
# ## Global DF

# %%
# global_df = pd.DataFrame()
global_df = pd.read_csv('global_dataset.csv')
global_df.tail()
# Out:
# <ipython-input-6-01be6b5e8ff2>:2: DtypeWarning: Columns (5,6,8,10,12,13,14,15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   global_df = pd.read_csv('global_dataset.csv')
#                                                     title  \
# 219744  Obama's Job Approval Rating Hits 50 Percent In...
# 219745  New Site Tells Tourists What Their Destination...
# 219746  This LBJ Fan Says You Should See The Film "Selma"
# 219747           8 Reminders That The Best Is Yet To Come
# 219748  How This Mom Really Feels About Going Out To E...
#
#                                                      body source  \
# 219744  The president's ratings have risen among Democ...   news
# 219745  A soon-to-be-launched online platform will pro...   news
# 219746  Should you see the movie "Selma," or should yo...   news
# 219747  The stress and strain of constantly being conn...   news
# 219748  How many of us celebrate Mother's Day by going...   news
#
#                   timestamp  Misinfo_flag type_of_misinfo type_reddit  \
# 219744  2016-03-10 00:00:00           NaN             NaN         NaN
# 219745  2015-08-24 00:00:00           NaN             NaN         NaN
# 219746  2015-01-13 00:00:00           NaN             NaN         NaN
# 219747  2014-04-03 00:00:00           NaN             NaN         NaN
# 219748  2014-05-09 00:00:00           NaN             NaN         NaN
#
#                 topic subtopic  \
# 219744       POLITICS      NaN
# 219745         IMPACT      NaN
# 219746  ENTERTAINMENT      NaN
# 219747       WELLNESS      NaN
# 219748        PARENTS      NaN
#
#                                                  entities Polarization_flag  \
# 219744  {'people': [], 'organizations': [], 'locations...               NaN
# 219745  {'people': [], 'organizations': [], 'locations...               NaN
# 219746  {'people': [], 'organizations': ['LBJ', 'LBJ']...               NaN
# 219747  {'people': [], 'organizations': [], 'locations...               NaN
# 219748  {'people': [], 'organizations': [], 'locations...               NaN
#
#         \tMisinfo_flag type_of_content  \
# 219744             NaN             NaN
# 219745             NaN             NaN
# 219746             NaN             NaN
# 219747             NaN             NaN
# 219748             NaN             NaN
#
#                                         potential_prompt0 hashtags gender  \
# 219744  Obama's Job Approval Rating Hits 50 Percent In...      NaN    NaN
# 219745  New Site Tells Tourists What Their Destination...      NaN    NaN
# 219746  This LBJ Fan Says You Should See The Film "Selma"      NaN    NaN
# 219747           8 Reminders That The Best Is Yet To Come      NaN    NaN
# 219748  How This Mom Really Feels About Going Out To E...      NaN    NaN
#
#        sentiment_category Publisher subtitle prochoice_prolife
# 219744                NaN       NaN      NaN               NaN
# 219745                NaN       NaN      NaN               NaN
# 219746                NaN       NaN      NaN               NaN
# 219747                NaN       NaN      NaN               NaN
# 219748                NaN       NaN      NaN               NaN

# %% [markdown]
# ## Construction of the global dataset.
#
# ## Topic one - Covid, misinformation on the pandemic and vaccines.
#
# Datasets used for this topic and their purpose:
#
# * [Reddit Vaccine Myths](https://www.kaggle.com/code/fahadmehfoooz/reddit-vaccine-myths) - provides misinformation on vaccines in general so we can trace back the bias for vaccines in general.

# %% [markdown]
# ####  Preprocessing [Reddit Vaccine Myths](https://www.kaggle.com/code/fahadmehfoooz/reddit-vaccine-myths)

# %%
target_folder = '/content/drive/MyDrive/MIDS/XAI/XAI_Final_project/Datasets'
print(os.path.exists(target_folder))
# Out:
# True

# %%
global_df.head(1)
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
#
#    subtopic entities Polarization_flag  \tMisinfo_flag type_of_content  \
# 0  Vaccines      NaN               NaN             NaN             NaN
#
#   potential_prompt0 hashtags gender sentiment_category Publisher
# 0               NaN      NaN    NaN               None      None

# %%
## Reddit Vaccine Myths
reddit_vaccine_myths = pd.read_csv('./Datasets/Covid_Datasets/reddit_vm.csv')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
import pandas as pd
import spacy


# Initialize an empty global dataframe
# global_df = pd.DataFrame(columns=["title", "body", "source", "timestamp"])

# %%
def extract_entities(text):
    """
    Extract named entities from text using SpaCy.
    """
    doc = nlp(text)
    entities = {"people": [], "organizations": [], "locations": []}
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            entities["people"].append(ent.text)
        elif ent.label_ == "ORG":
            entities["organizations"].append(ent.text)
        elif ent.label_ == "GPE":
            entities["locations"].append(ent.text)
    return entities

# %%
from tqdm import tqdm
import os
from datetime import datetime

def process_and_add_to_global(
    dataset, dataset_name, column_mapping, topic=None, subtopic=None, additional_columns=None, save_dir=None
):
    """
    Process a dataset and integrate it into the global dataframe, dynamically updating the schema with a progress bar.

    Args:
    - dataset: pd.DataFrame, the input dataset.
    - dataset_name: str, the name of the dataset/source.
    - column_mapping: dict, mapping from dataset-specific column names to global column names.
    - topic: str, the high-level topic (e.g., 'COVID').
    - subtopic: str, the sub-topic within the main topic (e.g., 'Vaccines').
    - additional_columns: dict, optional additional columns and their default values for this dataset only.
    - save_dir: str, directory to save the global dataframe. Defaults to the current working directory.
    """
    global global_df

    print(f"Processing dataset: {dataset_name}")
    # Progress bar for the number of rows
    with tqdm(total=len(dataset), desc=f"Processing rows in {dataset_name}", unit="row", disable=True) as pbar:
        # Apply column mapping to standardize dataset
        standardized_data = pd.DataFrame()
        for global_col, dataset_col in column_mapping.items():
            if dataset_col in dataset.columns:
                standardized_data[global_col] = dataset[dataset_col]
            else:
                raise ValueError(f"Column '{dataset_col}' missing in the dataset '{dataset_name}'.")

        # Add standard fields
        standardized_data["source"] = dataset_name
        standardized_data["timestamp"] = pd.to_datetime(standardized_data.get("timestamp", None), errors="coerce")
        standardized_data["topic"] = topic
        standardized_data["subtopic"] = subtopic

        # Extract entities using SpaCy
        if "body" in standardized_data.columns:
            standardized_data["entities"] = [
                extract_entities(text) if pd.notna(text) else None for text in tqdm(
                    standardized_data["body"], desc="Extracting entities", leave=False, unit="entry"
                )
            ]
        elif "title" in standardized_data.columns:
            standardized_data["entities"] = [
                extract_entities(text) if pd.notna(text) else None for text in tqdm(
                    standardized_data["title"], desc="Extracting entities", leave=False, unit="entry"
                )
            ]
        else:
            standardized_data["entities"] = None

        # Add additional columns dynamically
        if additional_columns:
            for col_name, default_value in additional_columns.items():
                standardized_data[col_name] = default_value

                # Ensure column exists in global_df with None for prior rows
                if col_name not in global_df.columns:
                    global_df[col_name] = None

        # Simulate processing rows to update the progress bar
        for _ in standardized_data.iterrows():
            pbar.update(1)

    # Append new data to global_df
    global_df = pd.concat([global_df, standardized_data], ignore_index=True)

    # Save the updated global dataframe
    save_dir = save_dir or os.getcwd()  # Default to current working directory if no directory specified
    save_path = os.path.join(save_dir, "global_dataset.csv")
    global_df.to_csv(save_path, index=False)
    print(f"Global dataframe saved to: {save_path}")

# %%
# Compute "type_reddit" inline and pass dynamically
process_and_add_to_global(
    reddit_vaccine_myths,
    dataset_name="Reddit",
    column_mapping={"title": "title", "body": "body", "timestamp": "timestamp"},
    topic="COVID",
    subtopic="Vaccines",
    additional_columns={
        "Misinfo_flag": 1, "type_of_misinfo": "myth",
        "type_reddit": reddit_vaccine_myths["title"].apply(
            lambda x: "comment_body" if "Comment" in x else "post_title"
        )
    }
)
# Out:
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv
# <ipython-input-67-d921226ff766>:53: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   global_df = pd.concat([global_df, standardized_data], ignore_index=True)

# %%
global_df.head()
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
# 1  COVID-19 in Canada: 'Vaccination passports' a ...  NaN  Reddit
# 2  Coronavirus variants could fuel Canada's third...  NaN  Reddit
# 3  Canadian government to extend COVID-19 emergen...  NaN  Reddit
# 4  Canada: Pfizer is 'extremely committed' to mee...  NaN  Reddit
#
#             timestamp Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0 2021-02-27 06:33:45            1            myth  post_title  COVID
# 1 2021-02-26 07:11:07            1            myth  post_title  COVID
# 2 2021-02-21 07:50:08            1            myth  post_title  COVID
# 3 2021-02-20 06:35:13            1            myth  post_title  COVID
# 4 2021-02-16 11:36:28            1            myth  post_title  COVID
#
#    subtopic entities
# 0  Vaccines     None
# 1  Vaccines     None
# 2  Vaccines     None
# 3  Vaccines     None
# 4  Vaccines     None

# %% [markdown]
# ## [COVID-19 Vaccine News Reddit Discussions](https://www.kaggle.com/datasets/xhlulu/covid19-vaccine-news-reddit-discussions)

# %%
## download reddit comments
covid_vaccine_reddit_comments = pd.read_csv('./Datasets/Covid_Datasets/comments.csv')
#

# %%
process_and_add_to_global(
    covid_vaccine_reddit_comments,
    dataset_name="Reddit",
    column_mapping={"title": "post_title", "body": "comment_body", "timestamp": "comment_date"},
    topic="COVID",
    subtopic="Vaccines",
    additional_columns={
        "type_reddit": 'post_and_title'

    }
)
# Out:
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ### [COVID-19 Fake News Dataset](https://www.kaggle.com/datasets/arashnic/covid19-fake-news)

# %%
## read the data from the folder
import os
import pandas as pd

# Define the working directory containing the CSV files
working_directory = './Datasets/Covid_Datasets/Covid_realFake'

# Initialize empty DataFrames for "claim" and "news"
claim_df = pd.DataFrame()
news_df = pd.DataFrame()

# Iterate through all CSV files in the folder
for file in os.listdir(working_directory):
    if file.endswith('.csv'):
        file_path = os.path.join(working_directory, file)
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Check conditions for "claim" files
        if 'claim' in file.lower():
            if 'fake' in file.lower():
                df['Misinfo_flag'] = 1
                claim_df = pd.concat([claim_df, df], ignore_index=True)
            elif 'real' in file.lower():
                df['Misinfo_flag'] = 0
                claim_df = pd.concat([claim_df, df], ignore_index=True)

        # Check conditions for "news" files
        elif 'news' in file.lower():
            if 'fake' in file.lower():
                df['Misinfo_flag'] = 1
                news_df = pd.concat([news_df, df], ignore_index=True)
            elif 'real' in file.lower():
                df['Misinfo_flag'] = 0
                news_df = pd.concat([news_df, df], ignore_index=True)

# %%
## append claims_df
process_and_add_to_global(
    claim_df,
    dataset_name="twitter",
    column_mapping={"title": "title"},
    topic="COVID",

    additional_columns={
        'Misinfo_flag': claim_df['Misinfo_flag']


    }
)
# Out:
# Processing dataset: twitter
# Processing rows in twitter: 100%|██████████| 481/481 [00:00<00:00, 21553.37row/s]
# <ipython-input-84-585f1b844aa1>:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   global_df = pd.concat([global_df, standardized_data], ignore_index=True)
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
news_df.shape
# Out:
# (2914, 16)

# %%
## append news df

process_and_add_to_global(
    news_df,
    dataset_name="news_twitter",
    column_mapping={"title": "title"},
    topic="COVID",

    additional_columns={
        'Misinfo_flag': news_df['Misinfo_flag']


    }
)
# Out:
# Processing dataset: news_twitter
# Processing rows in news_twitter:   0%|          | 0/2914 [00:00<?, ?row/s]
# Extracting entities:   0%|          | 0/2914 [00:00<?, ?entry/s]
# Extracting entities:   0%|          | 12/2914 [00:00<00:24, 119.30entry/s]
# Extracting entities:   1%|          | 24/2914 [00:00<00:24, 118.51entry/s]
# Extracting entities:   1%|▏         | 37/2914 [00:00<00:24, 119.24entry/s]
# Extracting entities:   2%|▏         | 50/2914 [00:00<00:23, 120.94entry/s]
# Extracting entities:   2%|▏         | 63/2914 [00:00<00:23, 122.83entry/s]
# Extracting entities:   3%|▎         | 79/2914 [00:00<00:21, 132.27entry/s]
# Extracting entities:   3%|▎         | 95/2914 [00:00<00:20, 138.94entry/s]
# Extracting entities:   4%|▍         | 110/2914 [00:00<00:19, 141.20entry/s]
# Extracting entities:   4%|▍         | 125/2914 [00:00<00:19, 142.89entry/s]
# Extracting entities:   5%|▍         | 140/2914 [00:01<00:19, 143.92entry/s]
# Extracting entities:   5%|▌         | 155/2914 [00:01<00:19, 143.71entry/s]
# Extracting entities:   6%|▌         | 170/2914 [00:01<00:19, 139.93entry/s]
# Extracting entities:   6%|▋         | 185/2914 [00:01<00:19, 137.86entry/s]
# Extracting entities:   7%|▋         | 200/2914 [00:01<00:19, 139.95entry/s]
# Extracting entities:   7%|▋         | 215/2914 [00:01<00:19, 140.19entry/s]
# Extracting entities:   8%|▊         | 230/2914 [00:01<00:18, 143.00entry/s]
# Extracting entities:   8%|▊         | 246/2914 [00:01<00:18, 147.10entry/s]
# Extracting entities:   9%|▉         | 261/2914 [00:01<00:18, 145.52entry/s]
# Extracting entities:  10%|▉         | 277/2914 [00:01<00:17, 147.59entry/s]
# Extracting entities:  10%|█         | 293/2914 [00:02<00:17, 149.09entry/s]
# Extracting entities:  11%|█         | 310/2914 [00:02<00:16, 153.67entry/s]
# Extracting entities:  11%|█         | 327/2914 [00:02<00:16, 155.74entry/s]
# Extracting entities:  12%|█▏        | 343/2914 [00:02<00:16, 155.91entry/s]
# Extracting entities:  12%|█▏        | 359/2914 [00:02<00:16, 151.99entry/s]
# Extracting entities:  13%|█▎        | 375/2914 [00:02<00:16, 154.19entry/s]
# Extracting entities:  13%|█▎        | 391/2914 [00:02<00:16, 153.19entry/s]
# Extracting entities:  14%|█▍        | 407/2914 [00:02<00:16, 152.53entry/s]
# Extracting entities:  15%|█▍        | 423/2914 [00:02<00:16, 154.48entry/s]
# Extracting entities:  15%|█▌        | 439/2914 [00:03<00:15, 156.08entry/s]
# Extracting entities:  16%|█▌        | 455/2914 [00:03<00:15, 156.69entry/s]
# Extracting entities:  16%|█▌        | 472/2914 [00:03<00:15, 158.37entry/s]
# Extracting entities:  17%|█▋        | 488/2914 [00:03<00:15, 157.65entry/s]
# Extracting entities:  17%|█▋        | 505/2914 [00:03<00:15, 159.58entry/s]
# Extracting entities:  78%|███████▊  | 2284/2914 [00:14<00:05, 125.50entry/s]
# Extracting entities:  79%|███████▉  | 2300/2914 [00:15<00:04, 132.57entry/s]
# Extracting entities:  79%|███████▉  | 2314/2914 [00:15<00:04, 131.90entry/s]
# Extracting entities:  80%|███████▉  | 2328/2914 [00:15<00:04, 132.55entry/s]
# Extracting entities:  80%|████████  | 2343/2914 [00:15<00:04, 137.23entry/s]
# Extracting entities:  81%|████████  | 2358/2914 [00:15<00:04, 138.75entry/s]
# Extracting entities:  81%|████████▏ | 2372/2914 [00:15<00:03, 136.61entry/s]
# Extracting entities:  82%|████████▏ | 2386/2914 [00:15<00:03, 133.47entry/s]
# Extracting entities:  82%|████████▏ | 2400/2914 [00:15<00:03, 134.25entry/s]
# Extracting entities:  83%|████████▎ | 2415/2914 [00:15<00:03, 136.68entry/s]
# Extracting entities:  83%|████████▎ | 2430/2914 [00:15<00:03, 138.07entry/s]
# Extracting entities:  84%|████████▍ | 2445/2914 [00:16<00:03, 141.34entry/s]
# Extracting entities:  84%|████████▍ | 2460/2914 [00:16<00:03, 137.21entry/s]
# Extracting entities:  85%|████████▍ | 2475/2914 [00:16<00:03, 140.35entry/s]
# Extracting entities:  85%|████████▌ | 2490/2914 [00:16<00:03, 139.75entry/s]
# Extracting entities:  86%|████████▌ | 2505/2914 [00:16<00:02, 140.12entry/s]
# Extracting entities:  86%|████████▋ | 2520/2914 [00:16<00:02, 138.40entry/s]
# Extracting entities:  87%|████████▋ | 2535/2914 [00:16<00:02, 140.97entry/s]
# Extracting entities:  88%|████████▊ | 2550/2914 [00:16<00:02, 139.17entry/s]
# Extracting entities:  88%|████████▊ | 2566/2914 [00:16<00:02, 143.54entry/s]
# Extracting entities:  89%|████████▊ | 2581/2914 [00:17<00:02, 144.97entry/s]
# Extracting entities:  89%|████████▉ | 2596/2914 [00:17<00:02, 145.11entry/s]
# Extracting entities:  90%|████████▉ | 2611/2914 [00:17<00:02, 144.96entry/s]
# Extracting entities:  90%|█████████ | 2626/2914 [00:17<00:02, 141.11entry/s]
# Extracting entities:  91%|█████████ | 2641/2914 [00:17<00:01, 140.32entry/s]
# Extracting entities:  91%|█████████ | 2656/2914 [00:17<00:01, 134.66entry/s]
# Extracting entities:  92%|█████████▏| 2670/2914 [00:17<00:01, 131.68entry/s]
# Extracting entities:  92%|█████████▏| 2684/2914 [00:17<00:01, 126.25entry/s]
# Extracting entities:  93%|█████████▎| 2697/2914 [00:17<00:01, 122.72entry/s]
# Extracting entities:  93%|█████████▎| 2710/2914 [00:18<00:01, 120.26entry/s]
# Extracting entities:  93%|█████████▎| 2724/2914 [00:18<00:01, 123.25entry/s]
# Extracting entities:  94%|█████████▍| 2738/2914 [00:18<00:01, 125.51entry/s]
# Extracting entities:  94%|█████████▍| 2751/2914 [00:18<00:01, 126.54entry/s]
# Extracting entities:  95%|█████████▍| 2764/2914 [00:18<00:01, 124.66entry/s]
# Extracting entities:  95%|█████████▌| 2777/2914 [00:18<00:01, 121.07entry/s]
# Extracting entities:  96%|█████████▌| 2790/2914 [00:18<00:01, 121.31entry/s]
# Extracting entities:  96%|█████████▌| 2803/2914 [00:18<00:00, 122.97entry/s]
# Extracting entities:  97%|█████████▋| 2817/2914 [00:18<00:00, 125.49entry/s]
# Extracting entities:  97%|█████████▋| 2831/2914 [00:19<00:00, 127.70entry/s]
# Extracting entities:  98%|█████████▊| 2846/2914 [00:19<00:00, 131.43entry/s]
# Extracting entities:  98%|█████████▊| 2860/2914 [00:19<00:00, 132.08entry/s]
# Extracting entities:  99%|█████████▊| 2874/2914 [00:19<00:00, 132.23entry/s]
# Extracting entities:  99%|█████████▉| 2888/2914 [00:19<00:00, 131.93entry/s]
# Extracting entities: 100%|█████████▉| 2902/2914 [00:19<00:00, 130.38entry/s]
# Processing rows in news_twitter: 100%|██████████| 2914/2914 [00:19<00:00, 147.54row/s]
# <ipython-input-108-b282956a342d>:69: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   global_df = pd.concat([global_df, standardized_data], ignore_index=True)
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.shape
# Out:
# (36334, 10)

# %% [markdown]
# #### [COVID19 Fake News Dataset NLP](https://www.kaggle.com/datasets/elvinagammed/covid19-fake-news-dataset-nlp)

# %% [markdown]
# # Russia and Ukraine
#
# sentiment about news in Russian and ukraine (amazing) - https://www.kaggle.com/datasets/subhajournal/political-sentiment-analysis
#
# (theres also one about disinformation)
#
# headlines and news - https://www.kaggle.com/datasets/hskhawaja/russia-ukraine-conflict (FOR TRAINING)
#
# kremlin disinformation - https://www.kaggle.com/datasets/corrieaar/disinformation-articles
#
# reddit with comments (can be used for prompts) - https://www.kaggle.com/datasets/bwandowando/ukrainesubredditthreadsandcomments
#
# twitter - https://www.kaggle.com/datasets/bwandowando/ukraine-russian-crisis-twitter-dataset-1-2-m-rows
#
# reddit  - https://www.kaggle.com/datasets/tariqsays/reddit-russiaukraine-conflict-dataset
#
# https://www.kaggle.com/datasets/asaniczka/public-opinion-russia-ukraine-war-updated-daily
#
# https://www.kaggle.com/datasets/hskhawaja/russia-ukraine-conflict
#
#
# russia ukraine with sentiment - https://www.kaggle.com/datasets/subhajournal/political-sentiment-analysis

# %%
guirdian_news = pd.read_csv('./Datasets/Russia_Ukraine/Guardians_Russia_Ukraine.csv')

# %%
## append news df

process_and_add_to_global(
    guirdian_news,
    dataset_name="news",
    column_mapping={"title": "headlines", 'body':'articles'},
    topic="War",
    subtopic="Russia and Ukraine",

    additional_columns={
        'Polarization_flag': "Democratic",
        'Publisher': 'The Guardian'



    }
)
# Out:
# Processing dataset: news
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.columns
# Out:
# Index(['title', 'body', 'source', 'timestamp', 'Misinfo_flag',
#        'type_of_misinfo', 'type_reddit', 'topic', 'subtopic', 'entities',
#        'Polarization_flag', '\tMisinfo_flag', 'type_of_content',
#        'potential_prompt0', 'hashtags', 'gender', 'sentiment_category',
#        'Publisher', 'subtitle', 'prochoice_prolife'],
#       dtype='object')

# %%
nyt_news = pd.read_csv('./Datasets/Russia_Ukraine/NYT_Russia_Ukraine.csv')

# %%
process_and_add_to_global(
    nyt_news,
    dataset_name="news",
    column_mapping={"title": "headlines", 'body':'articles'},
    topic="War",
    subtopic="Russia and Ukraine",

    additional_columns={
        'Polarization_flag': "Democratic",
        'Publisher': 'NYT'



    }
)
# Out:
# Processing dataset: news
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.head()
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
# 1  COVID-19 in Canada: 'Vaccination passports' a ...  NaN  Reddit
# 2  Coronavirus variants could fuel Canada's third...  NaN  Reddit
# 3  Canadian government to extend COVID-19 emergen...  NaN  Reddit
# 4  Canada: Pfizer is 'extremely committed' to mee...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
# 1  2021-02-26 07:11:07           1.0            myth  post_title  COVID
# 2  2021-02-21 07:50:08           1.0            myth  post_title  COVID
# 3  2021-02-20 06:35:13           1.0            myth  post_title  COVID
# 4  2021-02-16 11:36:28           1.0            myth  post_title  COVID
#
#    subtopic entities Polarization_flag  \tMisinfo_flag type_of_content  \
# 0  Vaccines      NaN               NaN             NaN             NaN
# 1  Vaccines      NaN               NaN             NaN             NaN
# 2  Vaccines      NaN               NaN             NaN             NaN
# 3  Vaccines      NaN               NaN             NaN             NaN
# 4  Vaccines      NaN               NaN             NaN             NaN
#
#   potential_prompt0 hashtags gender sentiment_category Publisher subtitle  \
# 0               NaN      NaN    NaN                NaN       NaN      NaN
# 1               NaN      NaN    NaN                NaN       NaN      NaN
# 2               NaN      NaN    NaN                NaN       NaN      NaN
# 3               NaN      NaN    NaN                NaN       NaN      NaN
# 4               NaN      NaN    NaN                NaN       NaN      NaN
#
#   prochoice_prolife
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# ## disinformation tactics pro russian media

# %%
rus_disinfo = pd.read_csv('./Datasets/Russia_Ukraine/russian_disinformation.csv')

# %%
rus_disinfo.columns
# Out:
# Index(['Unnamed: 0', 'claims_id', 'claim_published', 'first_appearance',
#        'review_id', 'is_part_of', 'claim_reviewed', 'review_published',
#        'review_name', 'html_text', 'text', 'issue_id', 'keyword_id',
#        'keyword_name', 'country_id', 'country_name', 'appearances',
#        'has_parts', 'creative_work_id', 'type', 'url', 'author', 'claim',
#        'web_archive_url', 'abstract', 'in_language', 'start_time', 'end_time',
#        'organization_id', 'location', 'organization_name', 'image_id',
#        'image_type', 'image_content_url', 'language_id', 'language_name',
#        'language_code'],
#       dtype='object')

# %%
rus_disinfo.head()
# Out:
#    Unnamed: 0     claims_id            claim_published     first_appearance  \
# 0           0   /claims/100  2019-12-13T00:00:00+00:00   /news_articles/598
# 1           1  /claims/1000  2019-09-26T00:00:00+00:00  /news_articles/1835
# 2           2  /claims/1002  2019-09-23T00:00:00+00:00  /media_objects/1837
# 3           3  /claims/1003  2019-09-27T00:00:00+00:00  /media_objects/1838
# 4           4  /claims/1004  2019-09-25T00:00:00+00:00  /news_articles/1839
#
#              review_id   is_part_of  \
# 0   /claim_reviews/100  /issues/177
# 1  /claim_reviews/1000  /issues/166
# 2  /claim_reviews/1002  /issues/166
# 3  /claim_reviews/1003  /issues/166
# 4  /claim_reviews/1004  /issues/166
#
#                                       claim_reviewed  \
# 0  Ukraine has put itself in a situation when ext...
# 1  Regardless who was behind the recent attack on...
# 2  Pilsudski is a historical figure, who establis...
# 3  Washington (and to a large degree Brussels) ar...
# 4  The beneficiary of the resolution of the Europ...
#
#             review_published  \
# 0  2019-12-16T00:00:00+00:00
# 1  2019-09-27T00:00:00+00:00
# 2  2019-09-27T00:00:00+00:00
# 3  2019-09-27T00:00:00+00:00
# 4  2019-09-27T00:00:00+00:00
#
#                                          review_name  \
# 0  Normandy summit results: the EU plays on Russi...
# 1  The US benefits from the attack on the Saudi o...
# 2  The Polish Legions of Pilsudski organized the ...
# 3  The West might use the Eastern Europeans as ca...
# 4  The resolution of the European Parliament reli...
#
#                                            html_text  ... end_time  \
# 0  <p>This article misrepresents the actual Germa...  ...      NaN
# 1  <p>No evidence is provided to support the clai...  ...      NaN
# 2  <p>This message is a part of the Kremlin’s pol...  ...    262.0
# 3  <p><a href="https://euvsdisinfo.eu/why-authori...  ...      NaN
# 4  <p>This message is part of the Kremlin’s polic...  ...      NaN
#
#       organization_id       location          organization_name  \
# 0  /organizations/262  /countries/55  sputnik.by // lifenews.ru
# 1  /organizations/205            NaN             southfront.org
# 2  /organizations/122   /countries/4                  Rossia 24
# 3  /organizations/461            NaN              fort-russ.com
# 4  /organizations/335            NaN                rubaltic.ru
#
#             image_id                     image_type  \
# 0  /image_objects/23  http://schema.org/ImageObject
# 1                NaN                            NaN
# 2  /image_objects/10  http://schema.org/ImageObject
# 3                NaN                            NaN
# 4                NaN                            NaN
#
#                                    image_content_url   language_id  \
# 0  https://api.veedoo.io/images/5e3150bc27830_2fd...  /languages/3
# 1                                                NaN  /languages/7
# 2  https://api.veedoo.io/images/5e313449bca43_Ros...  /languages/3
# 3                                                NaN  /languages/7
# 4                                                NaN  /languages/3
#
#   language_name language_code
# 0       Russian           rus
# 1       English           eng
# 2       Russian           rus
# 3       English           eng
# 4       Russian           rus
#
# [5 rows x 37 columns]

# %%
rus_disinfo = rus_disinfo[['claim_reviewed','review_published',
             'review_name',
             'text',
             'keyword_name',
             'country_name',
             'abstract',
                            'language_code'
             ]]
eng_rusdisinfo = rus_disinfo[rus_disinfo[ 'language_code']=='eng']

# %%
eng_rusdisinfo
# Out:
#                                          claim_reviewed  \
# 1     Regardless who was behind the recent attack on...
# 3     Washington (and to a large degree Brussels) ar...
# 6     A growing backlash has begun across Hong Kong ...
# 9     Under the guise of a concrete pressing issue (...
# 61    Nowadays, Washington is playing the “religion ...
# ...                                                 ...
# 7298  Crimea carried out a referendum in 2014 after ...
# 7299  Since Ukraine declared independence in 1991, W...
# 7303  Ukraine has filed a problematic complaint thro...
# 7323  While there is a significant grassroots moveme...
# 7343  The distorted face and psychopathic manners of...
#
#                review_published  \
# 1     2019-09-27T00:00:00+00:00
# 3     2019-09-27T00:00:00+00:00
# 6     2019-09-27T00:00:00+00:00
# 9     2019-09-26T00:00:00+00:00
# 61    2019-09-23T00:00:00+00:00
# ...                         ...
# 7298  2019-10-05T00:00:00+00:00
# 7299  2019-10-05T00:00:00+00:00
# 7303  2019-10-03T00:00:00+00:00
# 7323  2019-10-01T00:00:00+00:00
# 7343  2019-09-30T00:00:00+00:00
#
#                                             review_name  \
# 1     The US benefits from the attack on the Saudi o...
# 3     The West might use the Eastern Europeans as ca...
# 6               The protests in Hong Kong are US-funded
# 9     Western propaganda masters control mass demons...
# 61    Washington is playing the "religion card" agai...
# ...                                                 ...
# 7298  2014 Kyiv coup led to Crimea referendum and Do...
# 7299  Ukraine has been ruled by a US-funded client r...
# 7303  ECHR might rule to treat Russian control of Cr...
# 7323  The Climate Movement is distracting millions f...
# 7343  Greta Thunberg is a tool of the unelected glob...
#
#                                                    text  \
# 1     No evidence is provided to support the claim. ...
# 3     Conspiracy theory, presented without evidence....
# 6     Conspiracy theory presented without evidence.\...
# 9     Conspiracy theory presented without evidence.\...
# 61    No evidence given. Conspiracy theory and recur...
# ...                                                 ...
# 7298  Recurring pro-Kremlin disinformation narrative...
# 7299  The story advances a recurring pro-Kremlin nar...
# 7303  Recurring pro-Kremlin narrative about alleged ...
# 7323  Conspiracy theory, presented without evidence....
# 7343  A conspiracy theory, presented without evidenc...
#
#                                            keyword_name  \
# 1           ['Conspiracy', 'Terrorism', 'Donald Trump']
# 3     ['Russophobia', 'Encircling Russia', 'Operatio...
# 6                             ['Conspiracy', 'Protest']
# 9                             ['Conspiracy', 'Protest']
# 61                           ['Conspiracy', 'Religion']
# ...                                                 ...
# 7298  ['Crimea', 'Donbas', 'War in Ukraine', 'Easter...
# 7299  ['Ukrainian disintegration', 'US presence in E...
# 7303                                 ['Crimea', 'ECHR']
# 7323                          ['Conspiracy', 'Climate']
# 7343                      ['Climate', 'Greta Thunberg']
#
#                                            country_name abstract language_code
# 1             ['Iran', 'United States', 'Saudi Arabia']      NaN           eng
# 3     ['United States', 'The West', 'Czech Republic'...      NaN           eng
# 6                        ['United States', 'Hong Kong']      NaN           eng
# 9                             ['The West', 'Hong Kong']      NaN           eng
# 61      ['United States', 'The West', 'Georgia', 'CIS']      NaN           eng
# ...                                                 ...      ...           ...
# 7298                              ['Russia', 'Ukraine']      NaN           eng
# 7299                        ['Russia', 'US', 'Ukraine']      NaN           eng
# 7303                              ['Russia', 'Ukraine']      NaN           eng
# 7323                                  ['United States']      NaN           eng
# 7343                                         ['Sweden']      NaN           eng
#
# [333 rows x 8 columns]

# %% [markdown]
# ## Political biases

# %% [markdown]
# ## Political polarizations datasets

# %% [markdown]
# ### [Democrat Vs. Republican Tweets](https://www.kaggle.com/datasets/kapastor/democratvsrepublicantweets)

# %%
dem_vs_rep_tweets = pd.read_csv('./Datasets/Polarization_datasets/DemocratVsRepublicanTweets.csv')

# %%
global_df.head()
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
# 1  COVID-19 in Canada: 'Vaccination passports' a ...  NaN  Reddit
# 2  Coronavirus variants could fuel Canada's third...  NaN  Reddit
# 3  Canadian government to extend COVID-19 emergen...  NaN  Reddit
# 4  Canada: Pfizer is 'extremely committed' to mee...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
# 1  2021-02-26 07:11:07           1.0            myth  post_title  COVID
# 2  2021-02-21 07:50:08           1.0            myth  post_title  COVID
# 3  2021-02-20 06:35:13           1.0            myth  post_title  COVID
# 4  2021-02-16 11:36:28           1.0            myth  post_title  COVID
#
#    subtopic entities
# 0  Vaccines      NaN
# 1  Vaccines      NaN
# 2  Vaccines      NaN
# 3  Vaccines      NaN
# 4  Vaccines      NaN

# %%
global_df.shape
# Out:
# (39729, 10)

# %%
dem_vs_rep_tweets['Party'].value_counts()
# Out:
# Party
# Republican    44392
# Democrat      42068
# Name: count, dtype: int64

# %%
 dem_vs_rep_tweets = dem_vs_rep_tweets.sample(25000)
 process_and_add_to_global(
     dem_vs_rep_tweets,
    dataset_name="twitter",
    column_mapping={"body": "Tweet"},
    topic="Polarization",

    additional_columns={
        'Polarization_flag':  dem_vs_rep_tweets['Party']


    }
)
# Out:
# Processing dataset: twitter
# Processing rows in twitter:   0%|          | 0/25000 [00:00<?, ?row/s]
# Extracting entities:   0%|          | 0/25000 [00:00<?, ?entry/s]
# Extracting entities:   0%|          | 13/25000 [00:00<03:16, 127.06entry/s]
# Extracting entities:   0%|          | 26/25000 [00:00<03:20, 124.68entry/s]
# Extracting entities:   0%|          | 39/25000 [00:00<03:27, 120.24entry/s]
# Extracting entities:   0%|          | 52/25000 [00:00<03:24, 122.10entry/s]
# Extracting entities:   0%|          | 65/25000 [00:00<03:22, 123.36entry/s]
# Extracting entities:   0%|          | 78/25000 [00:00<03:18, 125.35entry/s]
# Extracting entities:   0%|          | 91/25000 [00:00<03:19, 125.09entry/s]
# Extracting entities:   0%|          | 104/25000 [00:00<03:21, 123.43entry/s]
# Extracting entities:   0%|          | 117/25000 [00:00<03:23, 122.05entry/s]
# Extracting entities:   1%|          | 130/25000 [00:01<03:22, 122.80entry/s]
# Extracting entities:   1%|          | 143/25000 [00:01<03:20, 124.11entry/s]
# Extracting entities:   1%|          | 156/25000 [00:01<03:19, 124.26entry/s]
# Extracting entities:   1%|          | 169/25000 [00:01<03:17, 125.88entry/s]
# Extracting entities:   1%|          | 182/25000 [00:01<03:16, 126.33entry/s]
# Extracting entities:   1%|          | 195/25000 [00:01<03:16, 126.06entry/s]
# Extracting entities:   1%|          | 208/25000 [00:01<03:15, 126.68entry/s]
# Extracting entities:   1%|          | 222/25000 [00:01<03:13, 127.88entry/s]
# Extracting entities:   1%|          | 235/25000 [00:01<03:14, 127.20entry/s]
# Extracting entities:   1%|          | 248/25000 [00:01<03:16, 126.17entry/s]
# Extracting entities:   1%|          | 261/25000 [00:02<03:16, 126.02entry/s]
# Extracting entities:   1%|          | 274/25000 [00:02<03:17, 125.32entry/s]
# Extracting entities:   1%|          | 287/25000 [00:02<03:17, 125.25entry/s]
# Extracting entities:   1%|          | 300/25000 [00:02<03:18, 124.30entry/s]
# Extracting entities:   1%|▏         | 313/25000 [00:02<03:17, 124.93entry/s]
# Extracting entities:   1%|▏         | 326/25000 [00:02<03:16, 125.50entry/s]
# Extracting entities:   1%|▏         | 339/25000 [00:02<03:17, 124.88entry/s]
# Extracting entities:   1%|▏         | 352/25000 [00:02<03:18, 124.39entry/s]
# Extracting entities:   1%|▏         | 365/25000 [00:02<03:19, 123.67entry/s]
# Extracting entities:   2%|▏         | 378/25000 [00:03<03:17, 124.92entry/s]
# Extracting entities:   2%|▏         | 391/25000 [00:03<03:16, 125.00entry/s]
# Extracting entities:   2%|▏         | 404/25000 [00:03<03:16, 124.91entry/s]
# Extracting entities:   2%|▏         | 417/25000 [00:03<03:20, 122.60entry/s]
# Extracting entities:   2%|▏         | 430/25000 [00:03<03:17, 124.49entry/s]
# Extracting entities:   2%|▏         | 444/25000 [00:03<03:14, 126.12entry/s]
# Extracting entities:   2%|▏         | 458/25000 [00:03<03:12, 127.60entry/s]
# Extracting entities:   2%|▏         | 471/25000 [00:03<03:26, 118.63entry/s]
# Extracting entities:   2%|▏         | 483/25000 [00:03<03:26, 118.74entry/s]
# Extracting entities:   2%|▏         | 495/25000 [00:03<03:26, 118.39entry/s]
# Extracting entities:   2%|▏         | 508/25000 [00:04<03:26, 118.59entry/s]
# Extracting entities:   2%|▏         | 520/25000 [00:04<03:26, 118.63entry/s]
# Extracting entities:   2%|▏         | 533/25000 [00:04<03:21, 121.32entry/s]
# Extracting entities:   2%|▏         | 546/25000 [00:04<03:18, 123.25entry/s]
# Extracting entities:   2%|▏         | 559/25000 [00:04<03:16, 124.37entry/s]
# Extracting entities:   2%|▏         | 572/25000 [00:04<03:16, 124.44entry/s]
# Extracting entities:   2%|▏         | 585/25000 [00:04<03:18, 123.25entry/s]
# Extracting entities:   2%|▏         | 598/25000 [00:04<03:18, 123.19entry/s]
# Extracting entities:   2%|▏         | 611/25000 [00:04<03:18, 122.79entry/s]
# Extracting entities:   2%|▎         | 625/25000 [00:05<03:14, 125.39entry/s]
# Extracting entities:   3%|▎         | 638/25000 [00:05<03:12, 126.60entry/s]
# Extracting entities:   3%|▎         | 651/25000 [00:05<03:11, 127.29entry/s]
# Extracting entities:   3%|▎         | 664/25000 [00:05<03:13, 125.71entry/s]
# Extracting entities:   3%|▎         | 677/25000 [00:05<03:15, 124.50entry/s]
# Extracting entities:   3%|▎         | 691/25000 [00:05<03:12, 126.23entry/s]
# Extracting entities:   3%|▎         | 704/25000 [00:05<03:13, 125.49entry/s]
# Extracting entities:   3%|▎         | 717/25000 [00:05<03:12, 125.89entry/s]
# Extracting entities:   3%|▎         | 730/25000 [00:05<03:13, 125.61entry/s]
# Extracting entities:   3%|▎         | 743/25000 [00:05<03:14, 124.86entry/s]
# Extracting entities:   3%|▎         | 756/25000 [00:06<03:12, 126.03entry/s]
# Extracting entities:   3%|▎         | 769/25000 [00:06<03:13, 125.02entry/s]
# Extracting entities:   3%|▎         | 782/25000 [00:06<03:12, 125.63entry/s]
# Extracting entities:   3%|▎         | 795/25000 [00:06<03:13, 124.84entry/s]
# Extracting entities:   3%|▎         | 808/25000 [00:06<03:12, 125.51entry/s]
# Extracting entities:   3%|▎         | 821/25000 [00:06<03:12, 125.55entry/s]
# Extracting entities:   3%|▎         | 835/25000 [00:06<03:10, 127.07entry/s]
# Extracting entities:   3%|▎         | 848/25000 [00:06<03:12, 125.73entry/s]
# Extracting entities:   3%|▎         | 861/25000 [00:06<03:14, 124.27entry/s]
# Extracting entities:   3%|▎         | 874/25000 [00:07<03:15, 123.23entry/s]
# Extracting entities:   4%|▎         | 887/25000 [00:07<03:13, 124.48entry/s]
# Extracting entities:   4%|▎         | 900/25000 [00:07<03:14, 124.07entry/s]
# Extracting entities:   4%|▎         | 913/25000 [00:07<03:16, 122.82entry/s]
# Extracting entities:   4%|▎         | 926/25000 [00:07<03:15, 123.28entry/s]
# Extracting entities:   4%|▍         | 939/25000 [00:07<03:13, 124.41entry/s]
# Extracting entities:   4%|▍         | 953/25000 [00:07<03:10, 125.96entry/s]
# Extracting entities:   4%|▍         | 967/25000 [00:07<03:09, 127.03entry/s]
# Extracting entities:   4%|▍         | 980/25000 [00:08<05:29, 72.89entry/s]
# Extracting entities:   4%|▍         | 992/25000 [00:08<04:53, 81.79entry/s]
# Extracting entities:   4%|▍         | 1003/25000 [00:08<04:34, 87.37entry/s]
# Extracting entities:   4%|▍         | 1015/25000 [00:08<04:15, 93.88entry/s]
# Extracting entities:   4%|▍         | 1028/25000 [00:08<03:55, 101.97entry/s]
# Extracting entities:   4%|▍         | 1041/25000 [00:08<03:40, 108.42entry/s]
# Extracting entities:   4%|▍         | 1053/25000 [00:08<03:38, 109.46entry/s]
# Extracting entities:   4%|▍         | 1065/25000 [00:08<03:33, 112.14entry/s]
# Extracting entities:   4%|▍         | 1077/25000 [00:08<03:39, 108.86entry/s]
# Extracting entities:   4%|▍         | 1090/25000 [00:09<03:29, 114.39entry/s]
# Extracting entities:   4%|▍         | 1103/25000 [00:09<03:24, 116.62entry/s]
# Extracting entities:   4%|▍         | 1116/25000 [00:09<03:21, 118.31entry/s]
# Extracting entities:   5%|▍         | 1129/25000 [00:09<03:19, 119.46entry/s]
# Extracting entities:   5%|▍         | 1142/25000 [00:09<03:14, 122.39entry/s]
# Extracting entities:   5%|▍         | 1155/25000 [00:09<03:17, 120.64entry/s]
# Extracting entities:   5%|▍         | 1168/25000 [00:09<03:26, 115.23entry/s]
# Extracting entities:   5%|▍         | 1180/25000 [00:09<03:26, 115.32entry/s]
# Extracting entities:   5%|▍         | 1193/25000 [00:09<03:20, 118.93entry/s]
# Extracting entities:   5%|▍         | 1206/25000 [00:10<03:18, 119.83entry/s]
# Extracting entities:   5%|▍         | 1219/25000 [00:10<03:14, 122.19entry/s]
# Extracting entities:   5%|▍         | 1232/25000 [00:10<03:17, 120.35entry/s]
# Extracting entities:   5%|▍         | 1245/25000 [00:10<03:16, 120.97entry/s]
# Extracting entities:   5%|▌         | 1258/25000 [00:10<03:14, 121.96entry/s]
# Extracting entities:   5%|▌         | 1271/25000 [00:10<03:13, 122.66entry/s]
# Extracting entities:   5%|▌         | 1284/25000 [00:10<03:11, 124.12entry/s]
# Extracting entities:   5%|▌         | 1297/25000 [00:10<03:09, 125.00entry/s]
# Extracting entities:   5%|▌         | 1310/25000 [00:10<03:09, 125.04entry/s]
# Extracting entities:   5%|▌         | 1323/25000 [00:10<03:10, 124.34entry/s]
# Extracting entities:   5%|▌         | 1336/25000 [00:11<03:09, 124.60entry/s]
# Extracting entities:   5%|▌         | 1349/25000 [00:11<03:09, 125.00entry/s]
# Extracting entities:   5%|▌         | 1362/25000 [00:11<03:08, 125.39entry/s]
# Extracting entities:   6%|▌         | 1375/25000 [00:11<03:08, 125.49entry/s]
# Extracting entities:   6%|▌         | 1388/25000 [00:11<03:07, 125.84entry/s]
# Extracting entities:   6%|▌         | 1401/25000 [00:11<03:07, 125.57entry/s]
# Extracting entities:   6%|▌         | 1414/25000 [00:11<03:10, 124.12entry/s]
# Extracting entities:   6%|▌         | 1427/25000 [00:11<03:10, 123.95entry/s]
# Extracting entities:   6%|▌         | 1440/25000 [00:11<03:10, 123.82entry/s]
# Extracting entities:   6%|▌         | 1453/25000 [00:12<03:10, 123.53entry/s]
# Extracting entities:   6%|▌         | 1466/25000 [00:12<03:10, 123.36entry/s]
# Extracting entities:   6%|▌         | 1480/25000 [00:12<03:06, 126.04entry/s]
# Extracting entities:   6%|▌         | 1493/25000 [00:12<03:07, 125.52entry/s]
# Extracting entities:   6%|▌         | 1506/25000 [00:12<03:08, 124.79entry/s]
# Extracting entities:   6%|▌         | 1519/25000 [00:12<03:06, 126.15entry/s]
# Extracting entities:   6%|▌         | 1532/25000 [00:12<03:08, 124.64entry/s]
# Extracting entities:   6%|▌         | 1545/25000 [00:12<03:17, 118.89entry/s]
# Extracting entities:   6%|▌         | 1558/25000 [00:12<03:13, 121.25entry/s]
# Extracting entities:   6%|▋         | 1571/25000 [00:12<03:10, 123.09entry/s]
# Extracting entities:   6%|▋         | 1584/25000 [00:13<03:08, 123.96entry/s]
# Extracting entities:   6%|▋         | 1597/25000 [00:13<03:07, 124.84entry/s]
# Extracting entities:   6%|▋         | 1610/25000 [00:13<03:07, 124.99entry/s]
# Extracting entities:   6%|▋         | 1624/25000 [00:13<03:02, 127.78entry/s]
# Extracting entities:   7%|▋         | 1637/25000 [00:13<03:06, 125.33entry/s]
# Extracting entities:   7%|▋         | 1650/25000 [00:13<03:07, 124.24entry/s]
# Extracting entities:   7%|▋         | 1663/25000 [00:13<03:06, 124.97entry/s]
# Extracting entities:   7%|▋         | 1676/25000 [00:13<03:05, 125.49entry/s]
# Extracting entities:   7%|▋         | 1690/25000 [00:13<03:02, 127.76entry/s]
# Extracting entities:   7%|▋         | 1703/25000 [00:14<03:03, 127.10entry/s]
# Extracting entities:   7%|▋         | 1716/25000 [00:14<03:01, 127.94entry/s]
# Extracting entities:   7%|▋         | 1729/25000 [00:14<03:05, 125.27entry/s]
# Extracting entities:   7%|▋         | 1742/25000 [00:14<03:12, 120.90entry/s]
# Extracting entities:   7%|▋         | 1755/25000 [00:14<03:09, 122.57entry/s]
# Extracting entities:   7%|▋         | 1768/25000 [00:14<03:07, 123.95entry/s]
# Extracting entities:   7%|▋         | 1781/25000 [00:14<03:07, 123.58entry/s]
# Extracting entities:   7%|▋         | 1794/25000 [00:14<03:09, 122.78entry/s]
# Extracting entities:   7%|▋         | 1807/25000 [00:14<03:09, 122.51entry/s]
# Extracting entities:   7%|▋         | 1820/25000 [00:14<03:12, 120.39entry/s]
# Extracting entities:   7%|▋         | 1833/25000 [00:15<03:12, 120.50entry/s]
# Extracting entities:   7%|▋         | 1847/25000 [00:15<03:06, 124.07entry/s]
# Extracting entities:   7%|▋         | 1860/25000 [00:15<03:04, 125.32entry/s]
# Extracting entities:   7%|▋         | 1873/25000 [00:15<03:03, 126.28entry/s]
# Extracting entities:   8%|▊         | 1886/25000 [00:15<03:03, 125.63entry/s]
# Extracting entities:   8%|▊         | 1899/25000 [00:15<03:04, 125.19entry/s]
# Extracting entities:   8%|▊         | 1913/25000 [00:15<03:00, 127.56entry/s]
# Extracting entities:   8%|▊         | 1926/25000 [00:15<03:05, 124.41entry/s]
# Extracting entities:   8%|▊         | 1939/25000 [00:15<03:04, 124.89entry/s]
# Extracting entities:   8%|▊         | 1952/25000 [00:16<03:03, 125.78entry/s]
# Extracting entities:   8%|▊         | 1965/25000 [00:16<03:03, 125.21entry/s]
# Extracting entities:   8%|▊         | 1978/25000 [00:16<03:03, 125.80entry/s]
# Extracting entities:   8%|▊         | 1991/25000 [00:16<03:02, 125.77entry/s]
# Extracting entities:   8%|▊         | 2004/25000 [00:16<03:03, 125.41entry/s]
# Extracting entities:   8%|▊         | 2017/25000 [00:16<03:01, 126.30entry/s]
# Extracting entities:   8%|▊         | 2031/25000 [00:16<03:00, 127.28entry/s]
# Extracting entities:   8%|▊         | 2044/25000 [00:16<03:03, 124.81entry/s]
# Extracting entities:   8%|▊         | 2058/25000 [00:16<03:01, 126.42entry/s]
# Extracting entities:   8%|▊         | 2071/25000 [00:16<03:02, 125.70entry/s]
# Extracting entities:   8%|▊         | 2085/25000 [00:17<02:59, 127.99entry/s]
# Extracting entities:   8%|▊         | 2098/25000 [00:17<02:59, 127.38entry/s]
# Extracting entities:   8%|▊         | 2111/25000 [00:17<03:00, 126.58entry/s]
# Extracting entities:   8%|▊         | 2124/25000 [00:17<03:00, 126.48entry/s]
# Extracting entities:   9%|▊         | 2137/25000 [00:17<03:02, 125.14entry/s]
# Extracting entities:   9%|▊         | 2151/25000 [00:17<02:57, 128.45entry/s]
# Extracting entities:   9%|▊         | 2164/25000 [00:17<02:57, 128.45entry/s]
# Extracting entities:   9%|▊         | 2177/25000 [00:17<03:00, 126.26entry/s]
# Extracting entities:   9%|▉         | 2191/25000 [00:17<02:58, 127.87entry/s]
# Extracting entities:   9%|▉         | 2204/25000 [00:18<02:58, 127.98entry/s]
# Extracting entities:   9%|▉         | 2218/25000 [00:18<02:56, 129.27entry/s]
# Extracting entities:   9%|▉         | 2231/25000 [00:18<02:59, 126.73entry/s]
# Extracting entities:   9%|▉         | 2245/25000 [00:18<02:58, 127.70entry/s]
# Extracting entities:   9%|▉         | 2259/25000 [00:18<02:56, 128.74entry/s]
# Extracting entities:   9%|▉         | 2273/25000 [00:18<02:53, 130.67entry/s]
# Extracting entities:   9%|▉         | 2287/25000 [00:18<02:55, 129.16entry/s]
# Extracting entities:   9%|▉         | 2300/25000 [00:18<03:00, 125.44entry/s]
# Extracting entities:   9%|▉         | 2313/25000 [00:18<02:59, 126.45entry/s]
# Extracting entities:   9%|▉         | 2327/25000 [00:18<02:56, 128.17entry/s]
# Extracting entities:   9%|▉         | 2340/25000 [00:19<02:56, 128.48entry/s]
# Extracting entities:   9%|▉         | 2353/25000 [00:19<02:55, 128.78entry/s]
# Extracting entities:   9%|▉         | 2366/25000 [00:19<02:55, 128.71entry/s]
# Extracting entities:  10%|▉         | 2379/25000 [00:19<02:55, 128.65entry/s]
# Extracting entities:  10%|▉         | 2392/25000 [00:19<02:57, 127.64entry/s]
# Extracting entities:  10%|▉         | 2405/25000 [00:19<02:57, 127.16entry/s]
# Extracting entities:  10%|▉         | 2418/25000 [00:19<02:59, 125.89entry/s]
# Extracting entities:  10%|▉         | 2431/25000 [00:19<03:04, 122.60entry/s]
# Extracting entities:  10%|▉         | 2444/25000 [00:19<03:01, 124.40entry/s]
# Extracting entities:  10%|▉         | 2457/25000 [00:20<03:01, 124.13entry/s]
# Extracting entities:  10%|▉         | 2470/25000 [00:20<02:59, 125.70entry/s]
# Extracting entities:  10%|▉         | 2483/25000 [00:20<02:58, 125.98entry/s]
# Extracting entities:  10%|▉         | 2497/25000 [00:20<02:56, 127.75entry/s]
# Extracting entities:  10%|█         | 2510/25000 [00:20<02:59, 125.14entry/s]
# Extracting entities:  10%|█         | 2523/25000 [00:20<02:59, 124.99entry/s]
# Extracting entities:  10%|█         | 2537/25000 [00:20<02:56, 126.92entry/s]
# Extracting entities:  10%|█         | 2550/25000 [00:20<02:58, 125.42entry/s]
# Extracting entities:  10%|█         | 2563/25000 [00:20<03:01, 123.71entry/s]
# Extracting entities:  10%|█         | 2576/25000 [00:20<03:01, 123.80entry/s]
# Extracting entities:  10%|█         | 2589/25000 [00:21<03:00, 124.47entry/s]
# Extracting entities:  10%|█         | 2602/25000 [00:21<02:58, 125.29entry/s]
# Extracting entities:  10%|█         | 2615/25000 [00:21<02:59, 124.68entry/s]
# Extracting entities:  11%|█         | 2628/25000 [00:21<03:00, 124.21entry/s]
# Extracting entities:  11%|█         | 2641/25000 [00:21<03:31, 105.71entry/s]
# Extracting entities:  13%|█▎        | 3129/25000 [00:25<02:51, 127.65entry/s]
# Extracting entities:  13%|█▎        | 3142/25000 [00:25<02:50, 127.87entry/s]
# Extracting entities:  13%|█▎        | 3156/25000 [00:25<02:48, 129.80entry/s]
# Extracting entities:  13%|█▎        | 3169/25000 [00:25<02:48, 129.68entry/s]
# Extracting entities:  13%|█▎        | 3182/25000 [00:25<02:48, 129.53entry/s]
# Extracting entities:  13%|█▎        | 3195/25000 [00:25<02:48, 129.63entry/s]
# Extracting entities:  13%|█▎        | 3209/25000 [00:26<02:47, 129.98entry/s]
# Extracting entities:  13%|█▎        | 3222/25000 [00:26<02:47, 129.68entry/s]
# Extracting entities:  13%|█▎        | 3236/25000 [00:26<02:47, 130.12entry/s]
# Extracting entities:  13%|█▎        | 3250/25000 [00:26<02:47, 129.80entry/s]
# Extracting entities:  13%|█▎        | 3263/25000 [00:26<02:51, 126.95entry/s]
# Extracting entities:  13%|█▎        | 3276/25000 [00:26<02:53, 125.08entry/s]
# Extracting entities:  13%|█▎        | 3289/25000 [00:26<02:52, 125.79entry/s]
# Extracting entities:  13%|█▎        | 3302/25000 [00:26<02:53, 124.91entry/s]
# Extracting entities:  13%|█▎        | 3316/25000 [00:26<02:51, 126.57entry/s]
# Extracting entities:  13%|█▎        | 3329/25000 [00:26<02:51, 126.66entry/s]
# Extracting entities:  13%|█▎        | 3342/25000 [00:27<02:51, 126.35entry/s]
# Extracting entities:  13%|█▎        | 3355/25000 [00:27<02:53, 125.11entry/s]
# Extracting entities:  13%|█▎        | 3368/25000 [00:27<02:52, 125.42entry/s]
# Extracting entities:  14%|█▎        | 3381/25000 [00:27<02:56, 122.25entry/s]
# Extracting entities:  14%|█▎        | 3394/25000 [00:27<02:53, 124.21entry/s]
# Extracting entities:  14%|█▎        | 3407/25000 [00:27<02:53, 124.52entry/s]
# Extracting entities:  14%|█▎        | 3420/25000 [00:27<02:52, 124.94entry/s]
# Extracting entities:  14%|█▎        | 3434/25000 [00:27<02:50, 126.62entry/s]
# Extracting entities:  14%|█▍        | 3448/25000 [00:27<02:47, 128.47entry/s]
# Extracting entities:  14%|█▍        | 3462/25000 [00:28<02:45, 129.88entry/s]
# Extracting entities:  14%|█▍        | 3475/25000 [00:28<02:48, 128.02entry/s]
# Extracting entities:  14%|█▍        | 3488/25000 [00:28<02:49, 126.67entry/s]
# Extracting entities:  14%|█▍        | 3501/25000 [00:28<02:52, 124.66entry/s]
# Extracting entities:  14%|█▍        | 3514/25000 [00:28<02:51, 125.10entry/s]
# Extracting entities:  14%|█▍        | 3527/25000 [00:28<02:51, 125.28entry/s]
# Extracting entities:  14%|█▍        | 3540/25000 [00:28<02:51, 125.02entry/s]
# Extracting entities:  14%|█▍        | 3553/25000 [00:28<02:53, 123.80entry/s]
# Extracting entities:  14%|█▍        | 3566/25000 [00:28<02:53, 123.36entry/s]
# Extracting entities:  14%|█▍        | 3579/25000 [00:28<02:52, 124.21entry/s]
# Extracting entities:  14%|█▍        | 3592/25000 [00:29<02:50, 125.76entry/s]
# Extracting entities:  14%|█▍        | 3605/25000 [00:29<02:51, 124.45entry/s]
# Extracting entities:  14%|█▍        | 3619/25000 [00:29<02:49, 126.30entry/s]
# Extracting entities:  15%|█▍        | 3632/25000 [00:29<02:48, 127.06entry/s]
# Extracting entities:  15%|█▍        | 3646/25000 [00:29<02:46, 128.29entry/s]
# Extracting entities:  15%|█▍        | 3659/25000 [00:29<02:46, 128.44entry/s]
# Extracting entities:  15%|█▍        | 3672/25000 [00:29<02:47, 127.03entry/s]
# Extracting entities:  15%|█▍        | 3685/25000 [00:29<02:46, 127.89entry/s]
# Extracting entities:  15%|█▍        | 3698/25000 [00:29<02:46, 127.90entry/s]
# Extracting entities:  15%|█▍        | 3712/25000 [00:30<02:44, 129.72entry/s]
# Extracting entities:  15%|█▍        | 3726/25000 [00:30<02:41, 131.36entry/s]
# Extracting entities:  15%|█▍        | 3740/25000 [00:30<02:44, 129.18entry/s]
# Extracting entities:  15%|█▌        | 3753/25000 [00:30<02:46, 127.51entry/s]
# Extracting entities:  15%|█▌        | 3767/25000 [00:30<02:43, 129.72entry/s]
# Extracting entities:  15%|█▌        | 3780/25000 [00:30<02:43, 129.44entry/s]
# Extracting entities:  15%|█▌        | 3793/25000 [00:30<02:44, 128.65entry/s]
# Extracting entities:  15%|█▌        | 3806/25000 [00:30<02:50, 124.49entry/s]
# Extracting entities:  15%|█▌        | 3819/25000 [00:30<02:48, 125.84entry/s]
# Extracting entities:  15%|█▌        | 3832/25000 [00:30<02:47, 126.63entry/s]
# Extracting entities:  15%|█▌        | 3846/25000 [00:31<02:44, 128.43entry/s]
# Extracting entities:  15%|█▌        | 3860/25000 [00:31<02:41, 130.50entry/s]
# Extracting entities:  15%|█▌        | 3874/25000 [00:31<02:43, 129.15entry/s]
# Extracting entities:  16%|█▌        | 3887/25000 [00:31<02:43, 129.05entry/s]
# Extracting entities:  16%|█▌        | 3900/25000 [00:31<02:45, 127.65entry/s]
# Extracting entities:  16%|█▌        | 3913/25000 [00:31<02:45, 127.47entry/s]
# Extracting entities:  16%|█▌        | 3926/25000 [00:31<02:46, 126.85entry/s]
# Extracting entities:  16%|█▌        | 3939/25000 [00:31<02:45, 127.43entry/s]
# Extracting entities:  16%|█▌        | 3952/25000 [00:31<02:44, 127.81entry/s]
# Extracting entities:  16%|█▌        | 3966/25000 [00:32<02:41, 129.98entry/s]
# Extracting entities:  16%|█▌        | 3980/25000 [00:32<02:38, 132.34entry/s]
# Extracting entities:  16%|█▌        | 3994/25000 [00:32<02:41, 130.11entry/s]
# Extracting entities:  16%|█▌        | 4008/25000 [00:32<02:40, 130.52entry/s]
# Extracting entities:  16%|█▌        | 4022/25000 [00:32<02:41, 129.68entry/s]
# Extracting entities:  16%|█▌        | 4035/25000 [00:32<02:41, 129.52entry/s]
# Extracting entities:  16%|█▌        | 4048/25000 [00:32<02:42, 128.62entry/s]
# Extracting entities:  16%|█▌        | 4061/25000 [00:32<02:48, 124.09entry/s]
# Extracting entities:  16%|█▋        | 4074/25000 [00:32<02:49, 123.61entry/s]
# Extracting entities:  16%|█▋        | 4087/25000 [00:32<02:46, 125.32entry/s]
# Extracting entities:  16%|█▋        | 4101/25000 [00:33<02:44, 126.99entry/s]
# Extracting entities:  16%|█▋        | 4114/25000 [00:33<02:46, 125.66entry/s]
# Extracting entities:  17%|█▋        | 4127/25000 [00:33<02:44, 126.87entry/s]
# Extracting entities:  17%|█▋        | 4140/25000 [00:33<02:44, 126.93entry/s]
# Extracting entities:  17%|█▋        | 4154/25000 [00:33<02:42, 128.07entry/s]
# Extracting entities:  17%|█▋        | 4167/25000 [00:33<02:46, 125.45entry/s]
# Extracting entities:  17%|█▋        | 4180/25000 [00:33<02:49, 123.18entry/s]
# Extracting entities:  17%|█▋        | 4193/25000 [00:33<02:48, 123.78entry/s]
# Extracting entities:  17%|█▋        | 4206/25000 [00:33<02:46, 125.20entry/s]
# Extracting entities:  17%|█▋        | 4219/25000 [00:34<02:44, 126.01entry/s]
# Extracting entities:  17%|█▋        | 4232/25000 [00:34<02:44, 126.14entry/s]
# Extracting entities:  17%|█▋        | 4245/25000 [00:34<02:43, 127.13entry/s]
# Extracting entities:  17%|█▋        | 4258/25000 [00:34<02:43, 127.22entry/s]
# Extracting entities:  17%|█▋        | 4271/25000 [00:34<02:43, 126.55entry/s]
# Extracting entities:  17%|█▋        | 4284/25000 [00:34<02:44, 125.80entry/s]
# Extracting entities:  17%|█▋        | 4297/25000 [00:34<02:43, 126.28entry/s]
# Extracting entities:  17%|█▋        | 4310/25000 [00:34<02:43, 126.20entry/s]
# Extracting entities:  17%|█▋        | 4323/25000 [00:34<02:43, 126.39entry/s]
# Extracting entities:  17%|█▋        | 4336/25000 [00:34<02:44, 125.40entry/s]
# Extracting entities:  17%|█▋        | 4349/25000 [00:35<02:44, 125.75entry/s]
# Extracting entities:  17%|█▋        | 4362/25000 [00:35<02:45, 125.02entry/s]
# Extracting entities:  18%|█▊        | 4376/25000 [00:35<02:42, 126.90entry/s]
# Extracting entities:  18%|█▊        | 4389/25000 [00:35<02:42, 126.75entry/s]
# Extracting entities:  18%|█▊        | 4402/25000 [00:35<02:43, 126.07entry/s]
# Extracting entities:  18%|█▊        | 4416/25000 [00:35<02:40, 127.97entry/s]
# Extracting entities:  18%|█▊        | 4429/25000 [00:35<02:41, 127.01entry/s]
# Extracting entities:  18%|█▊        | 4442/25000 [00:35<02:44, 124.80entry/s]
# Extracting entities:  18%|█▊        | 4456/25000 [00:35<02:42, 126.81entry/s]
# Extracting entities:  18%|█▊        | 4469/25000 [00:35<02:42, 126.33entry/s]
# Extracting entities:  18%|█▊        | 4482/25000 [00:36<02:43, 125.38entry/s]
# Extracting entities:  18%|█▊        | 4495/25000 [00:36<02:42, 126.30entry/s]
# Extracting entities:  18%|█▊        | 4508/25000 [00:36<02:42, 125.92entry/s]
# Extracting entities:  18%|█▊        | 4521/25000 [00:36<02:41, 126.66entry/s]
# Extracting entities:  18%|█▊        | 4535/25000 [00:36<02:40, 127.26entry/s]
# Extracting entities:  18%|█▊        | 4548/25000 [00:36<02:41, 126.66entry/s]
# Extracting entities:  18%|█▊        | 4561/25000 [00:36<02:42, 125.68entry/s]
# Extracting entities:  18%|█▊        | 4574/25000 [00:36<02:42, 125.87entry/s]
# Extracting entities:  18%|█▊        | 4587/25000 [00:36<02:40, 127.04entry/s]
# Extracting entities:  18%|█▊        | 4600/25000 [00:37<02:40, 126.91entry/s]
# Extracting entities:  18%|█▊        | 4614/25000 [00:37<02:38, 128.46entry/s]
# Extracting entities:  19%|█▊        | 4627/25000 [00:37<02:39, 127.54entry/s]
# Extracting entities:  19%|█▊        | 4640/25000 [00:37<02:41, 125.87entry/s]
# Extracting entities:  19%|█▊        | 4653/25000 [00:37<02:41, 126.27entry/s]
# Extracting entities:  19%|█▊        | 4666/25000 [00:37<02:42, 125.14entry/s]
# Extracting entities:  19%|█▊        | 4679/25000 [00:37<02:41, 126.21entry/s]
# Extracting entities:  19%|█▉        | 4692/25000 [00:37<02:40, 126.88entry/s]
# Extracting entities:  19%|█▉        | 4705/25000 [00:37<02:45, 122.27entry/s]
# Extracting entities:  19%|█▉        | 4718/25000 [00:37<02:43, 124.31entry/s]
# Extracting entities:  19%|█▉        | 4732/25000 [00:38<02:39, 127.14entry/s]
# Extracting entities:  19%|█▉        | 4745/25000 [00:38<02:41, 125.35entry/s]
# Extracting entities:  19%|█▉        | 4758/25000 [00:38<02:41, 125.20entry/s]
# Extracting entities:  19%|█▉        | 4771/25000 [00:38<02:43, 123.47entry/s]
# Extracting entities:  19%|█▉        | 4785/25000 [00:38<02:40, 125.66entry/s]
# Extracting entities:  19%|█▉        | 4798/25000 [00:38<02:41, 125.16entry/s]
# Extracting entities:  19%|█▉        | 4811/25000 [00:38<02:39, 126.33entry/s]
# Extracting entities:  19%|█▉        | 4824/25000 [00:38<02:40, 125.86entry/s]
# Extracting entities:  19%|█▉        | 4837/25000 [00:38<02:41, 124.47entry/s]
# Extracting entities:  19%|█▉        | 4850/25000 [00:39<02:43, 123.54entry/s]
# Extracting entities:  19%|█▉        | 4864/25000 [00:39<02:39, 126.26entry/s]
# Extracting entities:  20%|█▉        | 4878/25000 [00:39<02:35, 129.46entry/s]
# Extracting entities:  20%|█▉        | 4891/25000 [00:39<02:36, 128.71entry/s]
# Extracting entities:  20%|█▉        | 4904/25000 [00:39<02:35, 128.87entry/s]
# Extracting entities:  20%|█▉        | 4917/25000 [00:39<02:37, 127.88entry/s]
# Extracting entities:  20%|█▉        | 4930/25000 [00:39<02:38, 126.54entry/s]
# Extracting entities:  20%|█▉        | 4943/25000 [00:39<02:37, 127.40entry/s]
# Extracting entities:  20%|█▉        | 4957/25000 [00:39<02:36, 128.30entry/s]
# Extracting entities:  20%|█▉        | 4971/25000 [00:39<02:34, 129.77entry/s]
# Extracting entities:  20%|█▉        | 4984/25000 [00:40<02:34, 129.15entry/s]
# Extracting entities:  20%|█▉        | 4998/25000 [00:40<02:34, 129.81entry/s]
# Extracting entities:  20%|██        | 5011/25000 [00:40<02:34, 129.48entry/s]
# Extracting entities:  24%|██▍       | 5974/25000 [00:47<02:32, 124.40entry/s]
# Extracting entities:  24%|██▍       | 5987/25000 [00:48<02:32, 124.70entry/s]
# Extracting entities:  24%|██▍       | 6001/25000 [00:48<02:29, 126.97entry/s]
# Extracting entities:  24%|██▍       | 6015/25000 [00:48<02:27, 128.97entry/s]
# Extracting entities:  24%|██▍       | 6028/25000 [00:48<02:27, 128.40entry/s]
# Extracting entities:  24%|██▍       | 6042/25000 [00:48<02:26, 129.32entry/s]
# Extracting entities:  24%|██▍       | 6056/25000 [00:48<02:26, 129.57entry/s]
# Extracting entities:  24%|██▍       | 6070/25000 [00:48<02:24, 130.66entry/s]
# Extracting entities:  24%|██▍       | 6084/25000 [00:48<02:25, 129.61entry/s]
# Extracting entities:  24%|██▍       | 6097/25000 [00:48<02:26, 128.95entry/s]
# Extracting entities:  24%|██▍       | 6111/25000 [00:48<02:24, 130.27entry/s]
# Extracting entities:  24%|██▍       | 6125/25000 [00:49<02:25, 129.43entry/s]
# Extracting entities:  25%|██▍       | 6138/25000 [00:49<02:26, 129.16entry/s]
# Extracting entities:  25%|██▍       | 6152/25000 [00:49<02:24, 130.26entry/s]
# Extracting entities:  25%|██▍       | 6166/25000 [00:49<02:25, 129.34entry/s]
# Extracting entities:  25%|██▍       | 6179/25000 [00:49<02:28, 126.51entry/s]
# Extracting entities:  25%|██▍       | 6192/25000 [00:49<02:27, 127.49entry/s]
# Extracting entities:  25%|██▍       | 6205/25000 [00:49<02:29, 125.62entry/s]
# Extracting entities:  25%|██▍       | 6219/25000 [00:49<02:26, 128.14entry/s]
# Extracting entities:  25%|██▍       | 6232/25000 [00:49<02:28, 126.55entry/s]
# Extracting entities:  25%|██▍       | 6245/25000 [00:50<02:27, 127.04entry/s]
# Extracting entities:  25%|██▌       | 6258/25000 [00:50<02:28, 126.23entry/s]
# Extracting entities:  25%|██▌       | 6271/25000 [00:50<02:27, 127.22entry/s]
# Extracting entities:  25%|██▌       | 6284/25000 [00:50<02:30, 124.10entry/s]
# Extracting entities:  25%|██▌       | 6297/25000 [00:50<02:29, 125.50entry/s]
# Extracting entities:  25%|██▌       | 6310/25000 [00:50<02:28, 125.44entry/s]
# Extracting entities:  25%|██▌       | 6323/25000 [00:50<02:29, 125.27entry/s]
# Extracting entities:  25%|██▌       | 6336/25000 [00:50<02:28, 125.50entry/s]
# Extracting entities:  25%|██▌       | 6350/25000 [00:50<02:26, 127.09entry/s]
# Extracting entities:  25%|██▌       | 6364/25000 [00:50<02:23, 129.83entry/s]
# Extracting entities:  26%|██▌       | 6377/25000 [00:51<02:24, 128.70entry/s]
# Extracting entities:  26%|██▌       | 6391/25000 [00:51<02:22, 130.29entry/s]
# Extracting entities:  26%|██▌       | 6405/25000 [00:51<02:22, 130.06entry/s]
# Extracting entities:  26%|██▌       | 6419/25000 [00:51<02:22, 130.32entry/s]
# Extracting entities:  26%|██▌       | 6433/25000 [00:51<02:21, 130.81entry/s]
# Extracting entities:  26%|██▌       | 6447/25000 [00:51<02:24, 128.59entry/s]
# Extracting entities:  90%|█████████ | 22606/25000 [02:59<00:19, 122.63entry/s]
# Extracting entities:  90%|█████████ | 22619/25000 [03:00<00:19, 123.99entry/s]
# Extracting entities:  91%|█████████ | 22632/25000 [03:00<00:18, 125.64entry/s]
# Extracting entities:  91%|█████████ | 22645/25000 [03:00<00:18, 125.78entry/s]
# Extracting entities:  91%|█████████ | 22659/25000 [03:00<00:18, 128.24entry/s]
# Extracting entities:  91%|█████████ | 22672/25000 [03:00<00:18, 128.59entry/s]
# Extracting entities:  91%|█████████ | 22685/25000 [03:00<00:18, 128.44entry/s]
# Extracting entities:  91%|█████████ | 22698/25000 [03:00<00:17, 128.10entry/s]
# Extracting entities:  91%|█████████ | 22712/25000 [03:00<00:17, 129.29entry/s]
# Extracting entities:  91%|█████████ | 22725/25000 [03:00<00:17, 128.46entry/s]
# Extracting entities:  91%|█████████ | 22738/25000 [03:00<00:18, 124.69entry/s]
# Extracting entities:  91%|█████████ | 22751/25000 [03:01<00:17, 125.83entry/s]
# Extracting entities:  91%|█████████ | 22764/25000 [03:01<00:17, 125.46entry/s]
# Extracting entities:  91%|█████████ | 22777/25000 [03:01<00:17, 123.70entry/s]
# Extracting entities:  91%|█████████ | 22790/25000 [03:01<00:17, 125.43entry/s]
# Extracting entities:  91%|█████████ | 22803/25000 [03:01<00:17, 124.62entry/s]
# Extracting entities:  91%|█████████▏| 22816/25000 [03:01<00:17, 125.19entry/s]
# Extracting entities:  91%|█████████▏| 22830/25000 [03:01<00:17, 126.74entry/s]
# Extracting entities:  91%|█████████▏| 22843/25000 [03:01<00:17, 126.37entry/s]
# Extracting entities:  91%|█████████▏| 22856/25000 [03:01<00:17, 126.00entry/s]
# Extracting entities:  91%|█████████▏| 22869/25000 [03:01<00:17, 124.68entry/s]
# Extracting entities:  92%|█████████▏| 22883/25000 [03:02<00:16, 126.61entry/s]
# Extracting entities:  92%|█████████▏| 22896/25000 [03:02<00:16, 125.79entry/s]
# Extracting entities:  92%|█████████▏| 22909/25000 [03:02<00:16, 126.40entry/s]
# Extracting entities:  92%|█████████▏| 22922/25000 [03:02<00:16, 126.24entry/s]
# Extracting entities:  92%|█████████▏| 22935/25000 [03:02<00:16, 126.86entry/s]
# Extracting entities:  92%|█████████▏| 22948/25000 [03:02<00:16, 123.12entry/s]
# Extracting entities:  92%|█████████▏| 22961/25000 [03:02<00:16, 122.50entry/s]
# Extracting entities:  92%|█████████▏| 22974/25000 [03:02<00:16, 122.90entry/s]
# Extracting entities:  92%|█████████▏| 22988/25000 [03:02<00:16, 125.34entry/s]
# Extracting entities:  92%|█████████▏| 23001/25000 [03:03<00:15, 126.25entry/s]
# Extracting entities:  92%|█████████▏| 23014/25000 [03:03<00:16, 124.12entry/s]
# Extracting entities:  92%|█████████▏| 23027/25000 [03:03<00:15, 124.23entry/s]
# Extracting entities:  92%|█████████▏| 23040/25000 [03:03<00:15, 124.58entry/s]
# Extracting entities:  92%|█████████▏| 23053/25000 [03:03<00:15, 124.37entry/s]
# Extracting entities:  92%|█████████▏| 23066/25000 [03:03<00:15, 124.98entry/s]
# Extracting entities:  92%|█████████▏| 23080/25000 [03:03<00:15, 126.60entry/s]
# Extracting entities:  92%|█████████▏| 23094/25000 [03:03<00:14, 127.54entry/s]
# Extracting entities:  92%|█████████▏| 23107/25000 [03:03<00:15, 122.99entry/s]
# Extracting entities:  92%|█████████▏| 23120/25000 [03:03<00:15, 124.56entry/s]
# Extracting entities:  93%|█████████▎| 23133/25000 [03:04<00:14, 125.13entry/s]
# Extracting entities:  93%|█████████▎| 23147/25000 [03:04<00:14, 127.10entry/s]
# Extracting entities:  93%|█████████▎| 23160/25000 [03:04<00:14, 127.64entry/s]
# Extracting entities:  93%|█████████▎| 23173/25000 [03:04<00:14, 125.54entry/s]
# Extracting entities:  93%|█████████▎| 23186/25000 [03:04<00:14, 125.23entry/s]
# Extracting entities:  93%|█████████▎| 23199/25000 [03:04<00:14, 125.45entry/s]
# Extracting entities:  93%|█████████▎| 23212/25000 [03:04<00:14, 123.43entry/s]
# Extracting entities:  93%|█████████▎| 23225/25000 [03:04<00:14, 119.53entry/s]
# Extracting entities:  93%|█████████▎| 23239/25000 [03:04<00:14, 123.23entry/s]
# Extracting entities:  93%|█████████▎| 23252/25000 [03:05<00:14, 123.02entry/s]
# Extracting entities:  93%|█████████▎| 23265/25000 [03:05<00:14, 123.53entry/s]
# Extracting entities:  93%|█████████▎| 23279/25000 [03:05<00:13, 125.60entry/s]
# Extracting entities:  93%|█████████▎| 23293/25000 [03:05<00:13, 128.44entry/s]
# Extracting entities:  93%|█████████▎| 23307/25000 [03:05<00:12, 130.50entry/s]
# Extracting entities:  93%|█████████▎| 23321/25000 [03:05<00:13, 127.80entry/s]
# Extracting entities:  93%|█████████▎| 23334/25000 [03:05<00:13, 127.73entry/s]
# Extracting entities:  93%|█████████▎| 23347/25000 [03:05<00:12, 127.57entry/s]
# Extracting entities:  93%|█████████▎| 23360/25000 [03:05<00:13, 124.95entry/s]
# Extracting entities:  93%|█████████▎| 23373/25000 [03:06<00:22, 73.29entry/s]
# Extracting entities:  94%|█████████▎| 23386/25000 [03:06<00:19, 83.57entry/s]
# Extracting entities:  94%|█████████▎| 23399/25000 [03:06<00:17, 91.93entry/s]
# Extracting entities:  94%|█████████▎| 23412/25000 [03:06<00:15, 99.31entry/s]
# Extracting entities:  94%|█████████▎| 23425/25000 [03:06<00:14, 105.18entry/s]
# Extracting entities:  94%|█████████▎| 23437/25000 [03:06<00:14, 108.14entry/s]
# Extracting entities:  94%|█████████▍| 23451/25000 [03:06<00:13, 115.58entry/s]
# Extracting entities:  94%|█████████▍| 23464/25000 [03:06<00:12, 119.31entry/s]
# Extracting entities:  94%|█████████▍| 23477/25000 [03:07<00:12, 121.02entry/s]
# Extracting entities:  94%|█████████▍| 23490/25000 [03:07<00:12, 122.00entry/s]
# Extracting entities:  94%|█████████▍| 23503/25000 [03:07<00:12, 121.63entry/s]
# Extracting entities:  94%|█████████▍| 23516/25000 [03:07<00:12, 122.85entry/s]
# Extracting entities:  94%|█████████▍| 23530/25000 [03:07<00:11, 125.32entry/s]
# Extracting entities:  94%|█████████▍| 23544/25000 [03:07<00:11, 128.06entry/s]
# Extracting entities:  94%|█████████▍| 23558/25000 [03:07<00:11, 128.88entry/s]
# Extracting entities:  94%|█████████▍| 23571/25000 [03:07<00:11, 128.17entry/s]
# Extracting entities:  94%|█████████▍| 23584/25000 [03:07<00:11, 126.84entry/s]
# Extracting entities:  94%|█████████▍| 23597/25000 [03:08<00:11, 126.32entry/s]
# Extracting entities:  94%|█████████▍| 23610/25000 [03:08<00:11, 125.59entry/s]
# Extracting entities:  94%|█████████▍| 23624/25000 [03:08<00:10, 127.23entry/s]
# Extracting entities:  95%|█████████▍| 23637/25000 [03:08<00:10, 127.12entry/s]
# Extracting entities:  95%|█████████▍| 23650/25000 [03:08<00:10, 127.79entry/s]
# Extracting entities:  95%|█████████▍| 23663/25000 [03:08<00:10, 124.73entry/s]
# Extracting entities:  95%|█████████▍| 23676/25000 [03:08<00:10, 121.75entry/s]
# Extracting entities:  95%|█████████▍| 23689/25000 [03:08<00:10, 123.52entry/s]
# Extracting entities:  95%|█████████▍| 23702/25000 [03:08<00:10, 120.88entry/s]
# Extracting entities:  95%|█████████▍| 23715/25000 [03:08<00:10, 121.18entry/s]
# Extracting entities:  95%|█████████▍| 23728/25000 [03:09<00:10, 122.73entry/s]
# Extracting entities:  95%|█████████▍| 23741/25000 [03:09<00:10, 124.41entry/s]
# Extracting entities:  95%|█████████▌| 23755/25000 [03:09<00:09, 126.09entry/s]
# Extracting entities:  95%|█████████▌| 23768/25000 [03:09<00:09, 126.44entry/s]
# Extracting entities:  95%|█████████▌| 23781/25000 [03:09<00:09, 126.19entry/s]
# Extracting entities:  95%|█████████▌| 23794/25000 [03:09<00:09, 125.88entry/s]
# Extracting entities:  95%|█████████▌| 23807/25000 [03:09<00:09, 123.45entry/s]
# Extracting entities:  95%|█████████▌| 23820/25000 [03:09<00:09, 122.80entry/s]
# Extracting entities:  95%|█████████▌| 23834/25000 [03:09<00:09, 125.51entry/s]
# Extracting entities:  95%|█████████▌| 23847/25000 [03:10<00:09, 125.97entry/s]
# Extracting entities:  95%|█████████▌| 23861/25000 [03:10<00:08, 128.89entry/s]
# Extracting entities:  95%|█████████▌| 23874/25000 [03:10<00:08, 128.65entry/s]
# Extracting entities:  96%|█████████▌| 23888/25000 [03:10<00:08, 130.30entry/s]
# Extracting entities:  96%|█████████▌| 23902/25000 [03:10<00:08, 129.25entry/s]
# Extracting entities:  96%|█████████▌| 23915/25000 [03:10<00:08, 129.33entry/s]
# Extracting entities:  96%|█████████▌| 23928/25000 [03:10<00:08, 128.61entry/s]
# Extracting entities:  96%|█████████▌| 23941/25000 [03:10<00:08, 126.26entry/s]
# Extracting entities:  96%|█████████▌| 23955/25000 [03:10<00:08, 127.51entry/s]
# Extracting entities:  96%|█████████▌| 23968/25000 [03:10<00:08, 127.73entry/s]
# Extracting entities:  96%|█████████▌| 23981/25000 [03:11<00:08, 126.43entry/s]
# Extracting entities:  96%|█████████▌| 23995/25000 [03:11<00:07, 129.87entry/s]
# Extracting entities:  96%|█████████▌| 24008/25000 [03:11<00:07, 128.54entry/s]
# Extracting entities:  96%|█████████▌| 24021/25000 [03:11<00:07, 128.01entry/s]
# Extracting entities:  96%|█████████▌| 24035/25000 [03:11<00:07, 128.92entry/s]
# Extracting entities:  96%|█████████▌| 24049/25000 [03:11<00:07, 130.21entry/s]
# Extracting entities:  96%|█████████▋| 24063/25000 [03:11<00:07, 128.78entry/s]
# Extracting entities:  96%|█████████▋| 24076/25000 [03:11<00:07, 128.57entry/s]
# Extracting entities:  96%|█████████▋| 24090/25000 [03:11<00:07, 129.88entry/s]
# Extracting entities:  96%|█████████▋| 24103/25000 [03:12<00:06, 129.73entry/s]
# Extracting entities:  96%|█████████▋| 24116/25000 [03:12<00:06, 129.23entry/s]
# Extracting entities:  97%|█████████▋| 24129/25000 [03:12<00:06, 129.17entry/s]
# Extracting entities:  97%|█████████▋| 24143/25000 [03:12<00:06, 129.86entry/s]
# Extracting entities:  97%|█████████▋| 24156/25000 [03:12<00:06, 128.39entry/s]
# Extracting entities:  97%|█████████▋| 24169/25000 [03:12<00:06, 127.91entry/s]
# Extracting entities:  97%|█████████▋| 24182/25000 [03:12<00:06, 127.54entry/s]
# Extracting entities:  97%|█████████▋| 24195/25000 [03:12<00:06, 122.23entry/s]
# Extracting entities:  97%|█████████▋| 24208/25000 [03:12<00:06, 122.64entry/s]
# Extracting entities:  97%|█████████▋| 24221/25000 [03:12<00:06, 123.73entry/s]
# Extracting entities:  97%|█████████▋| 24234/25000 [03:13<00:06, 124.29entry/s]
# Extracting entities:  97%|█████████▋| 24247/25000 [03:13<00:06, 124.13entry/s]
# Extracting entities:  97%|█████████▋| 24260/25000 [03:13<00:05, 123.38entry/s]
# Extracting entities:  97%|█████████▋| 24273/25000 [03:13<00:05, 123.29entry/s]
# Extracting entities:  97%|█████████▋| 24286/25000 [03:13<00:05, 119.32entry/s]
# Extracting entities:  97%|█████████▋| 24299/25000 [03:13<00:05, 121.61entry/s]
# Extracting entities:  97%|█████████▋| 24312/25000 [03:13<00:05, 123.30entry/s]
# Extracting entities:  97%|█████████▋| 24326/25000 [03:13<00:05, 125.15entry/s]
# Extracting entities:  97%|█████████▋| 24339/25000 [03:13<00:05, 125.12entry/s]
# Extracting entities:  97%|█████████▋| 24352/25000 [03:14<00:05, 123.54entry/s]
# Extracting entities:  97%|█████████▋| 24365/25000 [03:14<00:05, 122.69entry/s]
# Extracting entities:  98%|█████████▊| 24378/25000 [03:14<00:05, 122.20entry/s]
# Extracting entities:  98%|█████████▊| 24391/25000 [03:14<00:04, 123.77entry/s]
# Extracting entities:  98%|█████████▊| 24404/25000 [03:14<00:04, 124.48entry/s]
# Extracting entities:  98%|█████████▊| 24418/25000 [03:14<00:04, 126.49entry/s]
# Extracting entities:  98%|█████████▊| 24431/25000 [03:14<00:04, 127.33entry/s]
# Extracting entities:  98%|█████████▊| 24444/25000 [03:14<00:04, 124.52entry/s]
# Extracting entities:  98%|█████████▊| 24457/25000 [03:14<00:04, 124.91entry/s]
# Extracting entities:  98%|█████████▊| 24470/25000 [03:14<00:04, 124.86entry/s]
# Extracting entities:  98%|█████████▊| 24483/25000 [03:15<00:04, 125.44entry/s]
# Extracting entities:  98%|█████████▊| 24497/25000 [03:15<00:03, 127.44entry/s]
# Extracting entities:  98%|█████████▊| 24510/25000 [03:15<00:03, 125.56entry/s]
# Extracting entities:  98%|█████████▊| 24523/25000 [03:15<00:03, 125.50entry/s]
# Extracting entities:  98%|█████████▊| 24536/25000 [03:15<00:03, 122.51entry/s]
# Extracting entities:  98%|█████████▊| 24549/25000 [03:15<00:03, 121.61entry/s]
# Extracting entities:  98%|█████████▊| 24562/25000 [03:15<00:03, 123.34entry/s]
# Extracting entities:  98%|█████████▊| 24575/25000 [03:15<00:03, 117.09entry/s]
# Extracting entities:  98%|█████████▊| 24589/25000 [03:15<00:03, 120.93entry/s]
# Extracting entities:  98%|█████████▊| 24602/25000 [03:16<00:03, 123.15entry/s]
# Extracting entities:  98%|█████████▊| 24615/25000 [03:16<00:03, 122.74entry/s]
# Extracting entities:  99%|█████████▊| 24628/25000 [03:16<00:03, 123.78entry/s]
# Extracting entities:  99%|█████████▊| 24641/25000 [03:16<00:02, 125.17entry/s]
# Extracting entities:  99%|█████████▊| 24654/25000 [03:16<00:02, 125.27entry/s]
# Extracting entities:  99%|█████████▊| 24667/25000 [03:16<00:02, 122.95entry/s]
# Extracting entities:  99%|█████████▊| 24680/25000 [03:16<00:02, 122.76entry/s]
# Extracting entities:  99%|█████████▉| 24694/25000 [03:16<00:02, 125.54entry/s]
# Extracting entities:  99%|█████████▉| 24707/25000 [03:16<00:02, 125.79entry/s]
# Extracting entities:  99%|█████████▉| 24720/25000 [03:16<00:02, 125.87entry/s]
# Extracting entities:  99%|█████████▉| 24733/25000 [03:17<00:02, 121.77entry/s]
# Extracting entities:  99%|█████████▉| 24746/25000 [03:17<00:02, 123.90entry/s]
# Extracting entities:  99%|█████████▉| 24759/25000 [03:17<00:01, 123.85entry/s]
# Extracting entities:  99%|█████████▉| 24772/25000 [03:17<00:01, 123.47entry/s]
# Extracting entities:  99%|█████████▉| 24785/25000 [03:17<00:01, 123.17entry/s]
# Extracting entities:  99%|█████████▉| 24798/25000 [03:17<00:01, 122.37entry/s]
# Extracting entities:  99%|█████████▉| 24811/25000 [03:17<00:01, 120.21entry/s]
# Extracting entities:  99%|█████████▉| 24824/25000 [03:17<00:01, 119.50entry/s]
# Extracting entities:  99%|█████████▉| 24837/25000 [03:17<00:01, 122.12entry/s]
# Extracting entities:  99%|█████████▉| 24850/25000 [03:18<00:01, 123.23entry/s]
# Extracting entities:  99%|█████████▉| 24863/25000 [03:18<00:01, 123.70entry/s]
# Extracting entities: 100%|█████████▉| 24876/25000 [03:18<00:01, 123.61entry/s]
# Extracting entities: 100%|█████████▉| 24889/25000 [03:18<00:00, 123.72entry/s]
# Extracting entities: 100%|█████████▉| 24903/25000 [03:18<00:00, 125.88entry/s]
# Extracting entities: 100%|█████████▉| 24916/25000 [03:18<00:00, 125.31entry/s]
# Extracting entities: 100%|█████████▉| 24929/25000 [03:18<00:00, 126.38entry/s]
# Extracting entities: 100%|█████████▉| 24942/25000 [03:18<00:00, 125.11entry/s]
# Extracting entities: 100%|█████████▉| 24955/25000 [03:18<00:00, 124.67entry/s]
# Extracting entities: 100%|█████████▉| 24968/25000 [03:18<00:00, 125.88entry/s]
# Extracting entities: 100%|█████████▉| 24981/25000 [03:19<00:00, 125.90entry/s]
# Extracting entities: 100%|█████████▉| 24994/25000 [03:19<00:00, 125.90entry/s]
# Processing rows in twitter: 100%|██████████| 25000/25000 [03:20<00:00, 124.86row/s]
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.shape
# Out:
# (64729, 11)

# %% [markdown]
# ##  [Reddit: /r/NotTheOnion](https://www.kaggle.com/datasets/thedevastator/discovering-fact-through-humor-investigating-r-n)

# %%
nottheonion = pd.read_csv('./Datasets/Overall_news/nottheonion.csv')

# %%
nottheonion.head()
# Out:
#                                                title  score      id  \
# 0  Human heart found in TDOT salt pile in Humphre...     49  znmpf0
# 1  [TwinsDaily] Twins Announce Best Efforts and P...      1  znly7o
# 2  Another driver loses control, crashes into Pha...     18  znly28
# 3  Reporter ‘alarmed at the intelligence level of...   1898  znlmte
# 4  Aromatherapy spray that killed two people in a...    159  znllto
#
#                                                  url  comms_num       created  \
# 0  https://www.wkrn.com/news/local-news/human-hea...          5  1.671219e+09
# 1  https://twinsdaily.com/news-rumors/just-for-fu...          0  1.671217e+09
# 2  https://www.fox35orlando.com/news/another-driv...         11  1.671217e+09
# 3  https://www.msnbc.com/katie-phang/watch/report...        109  1.671216e+09
# 4  https://www.nbcnews.com/news/us-news/aromather...         14  1.671216e+09
#
#   body            timestamp
# 0  NaN  2022-12-16 21:22:06
# 1  NaN  2022-12-16 20:49:01
# 2  NaN  2022-12-16 20:48:50
# 3  NaN  2022-12-16 20:34:52
# 4  NaN  2022-12-16 20:33:36

# %%
global_df.head(1)
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
#
#    subtopic entities Polarization_flag
# 0  Vaccines      NaN              None

# %%
global_df = pd.read_csv('global_dataset.csv')
# Out:
# <ipython-input-29-07264a2067b1>:1: DtypeWarning: Columns (1,5,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   global_df = pd.read_csv('global_dataset.csv')

# %%
 process_and_add_to_global(
    nottheonion,
    dataset_name="reddit",
    column_mapping={"title": "title",'timestamp':'timestamp'},
    topic="All_news",

    additional_columns={
        'Misinfo_flag': 1,
        'type_of_misinfo':'Onion'


    }
)
# Out:
# Processing dataset: reddit
# Processing rows in reddit:   0%|          | 0/1627 [00:00<?, ?row/s]
# Extracting entities:   0%|          | 0/1627 [00:00<?, ?entry/s]
# Extracting entities:   1%|          | 16/1627 [00:00<00:10, 154.70entry/s]
# Extracting entities:  83%|████████▎ | 1347/1627 [00:07<00:01, 201.54entry/s]
# Extracting entities:  84%|████████▍ | 1368/1627 [00:07<00:01, 202.87entry/s]
# Extracting entities:  85%|████████▌ | 1389/1627 [00:08<00:01, 203.38entry/s]
# Extracting entities:  87%|████████▋ | 1411/1627 [00:08<00:01, 205.88entry/s]
# Extracting entities:  88%|████████▊ | 1433/1627 [00:08<00:00, 207.41entry/s]
# Extracting entities:  89%|████████▉ | 1454/1627 [00:08<00:00, 207.56entry/s]
# Extracting entities:  91%|█████████ | 1475/1627 [00:08<00:00, 207.86entry/s]
# Extracting entities:  92%|█████████▏| 1497/1627 [00:08<00:00, 208.92entry/s]
# Extracting entities:  93%|█████████▎| 1518/1627 [00:08<00:00, 208.35entry/s]
# Extracting entities:  95%|█████████▍| 1539/1627 [00:08<00:00, 208.82entry/s]
# Extracting entities:  96%|█████████▌| 1560/1627 [00:08<00:00, 208.83entry/s]
# Extracting entities:  97%|█████████▋| 1581/1627 [00:08<00:00, 208.21entry/s]
# Extracting entities:  99%|█████████▊| 1603/1627 [00:09<00:00, 209.43entry/s]
# Extracting entities: 100%|█████████▉| 1624/1627 [00:09<00:00, 208.82entry/s]
# Processing rows in reddit: 100%|██████████| 1627/1627 [00:09<00:00, 175.87row/s]
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ## Political and gender bias

# %% [markdown]
# ## Abortion and pro-choice
# add code from R later to repo to not forget how to parse the files

# %%
# !pip install pyreadr
# !pip install rdata
# Out:
# Requirement already satisfied: pyreadr in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyreadr) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.16.0)
# Requirement already satisfied: rdata in /usr/local/lib/python3.10/dist-packages (0.11.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdata) (1.26.4)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from rdata) (2024.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rdata) (2.2.2)
# Requirement already satisfied: typing-extensions>4.4 in /usr/local/lib/python3.10/dist-packages (from rdata) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->rdata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rdata) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->rdata) (2024.2)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from xarray->rdata) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->rdata) (1.16.0)

# %%
gender_abortions = pd.read_csv('./Datasets/Gender_bias/genderwithna_abo_botp_subset.csv')

# %%
gender_abortions.head()
# Out:
#             created_at                                               text  \
# 0  2017-11-01 15:15:14  RT @PPact: Doubling down on health attacks, ex...
# 1  2017-11-03 02:30:37  RT @EmmarKirwan: It's almost 2018 and people s...
# 2  2017-11-03 14:31:31  RT @EmmarKirwan: It's almost 2018 and people s...
# 3  2017-12-17 03:56:30  @AGSchneiderman Republicans are against aborti...
# 4  2018-02-20 05:13:38  RT @RealKyleMorris: How do Democrats expect cr...
#
#     gender  is_quote hashtags quoted_text
# 0  unknown     False      NaN         NaN
# 1     male     False      NaN         NaN
# 2  unknown     False      NaN         NaN
# 3   female     False      NaN         NaN
# 4     male     False      NaN         NaN

# %% [markdown]
# We will make two datasets here - one of just tweets (whatever) + one with re tweets for possible prompting

# %% [markdown]
# ## dataset 1 (without quotes)

# %%
global_df.head(1)
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
#
#    subtopic entities Polarization_flag  \tMisinfo_flag type_of_content  \
# 0  Vaccines      NaN               NaN             NaN             NaN
#
#   potential_prompt0 hashtags gender
# 0               NaN      NaN    NaN

# %%
global_df.shape
# Out:
# (122989, 16)

# %%
abortion_1 = gender_abortions[['created_at','text','hashtags','gender']]

# %%
# prompt: rewrite abortion 1 to include those where is_quoto is false

# ... (Your existing code)

# ## dataset 1 (without quotes)
abortion_1 = gender_abortions[~gender_abortions['is_quote']] [['created_at','text','hashtags','gender']]

# %%
abortion_1
# Out:
#                 created_at                                               text  \
# 0      2017-11-01 15:15:14  RT @PPact: Doubling down on health attacks, ex...
# 1      2017-11-03 02:30:37  RT @EmmarKirwan: It's almost 2018 and people s...
# 2      2017-11-03 14:31:31  RT @EmmarKirwan: It's almost 2018 and people s...
# 3      2017-12-17 03:56:30  @AGSchneiderman Republicans are against aborti...
# 4      2018-02-20 05:13:38  RT @RealKyleMorris: How do Democrats expect cr...
# ...                    ...                                                ...
# 49995  2018-01-04 19:08:24  March for Life Chicago 2018 to be Largest Midw...
# 49996  2017-11-03 15:24:58  RT @benwikler: Today, the party that wants to ...
# 49997  2017-11-03 12:40:29  RT @benwikler: Today, the party that wants to ...
# 49998  2017-12-11 17:55:35  RT @SouthernKeeks: I see certain people I resp...
# 49999  2018-01-04 23:06:07  @IronStache @SpeakerRyan Let’s talk about gett...
#
#       hashtags   gender
# 0          NaN  unknown
# 1          NaN     male
# 2          NaN  unknown
# 3          NaN   female
# 4          NaN     male
# ...        ...      ...
# 49995      NaN     male
# 49996      NaN   female
# 49997      NaN  unknown
# 49998      NaN  unknown
# 49999      NaN  unknown
#
# [48894 rows x 4 columns]

# %%
sample_abortion1 = abortion_1.sample(10000)
# Process and add abortion_1 to the global dataset
process_and_add_to_global(
    sample_abortion1,
    dataset_name="twitter",
    column_mapping={"timestamp": "created_at", "body": "text"},
    topic="Abortion",
    additional_columns={
        "hashtags": sample_abortion1["hashtags"],
        "gender": sample_abortion1["gender"],
    }
)
# Out:
# Processing dataset: twitter
# Processing rows in twitter:   0%|          | 0/10000 [00:00<?, ?row/s]
#
# Extracting entities:   0%|          | 0/10000 [00:00<?, ?entry/s]
#
# Extracting entities:   0%|          | 11/10000 [00:00<01:33, 106.35entry/s]
#
# Extracting entities:   0%|          | 22/10000 [00:00<01:33, 106.89entry/s]
#
# Extracting entities:   0%|          | 34/10000 [00:00<01:31, 109.43entry/s]
#
# Extracting entities:   0%|          | 46/10000 [00:00<01:29, 110.87entry/s]
#
# Extracting entities:   1%|          | 58/10000 [00:00<01:32, 108.01entry/s]
#
# Extracting entities:   1%|          | 70/10000 [00:00<01:30, 109.76entry/s]
#
# Extracting entities:   1%|          | 82/10000 [00:00<01:28, 112.03entry/s]
#
# Extracting entities:   1%|          | 94/10000 [00:00<01:27, 112.79entry/s]
#
# Extracting entities:   1%|          | 106/10000 [00:00<01:27, 112.46entry/s]
#
# Extracting entities:   1%|          | 118/10000 [00:01<01:28, 111.87entry/s]
#
# Extracting entities:   1%|▏         | 130/10000 [00:01<01:27, 112.38entry/s]
#
# Extracting entities:   1%|▏         | 142/10000 [00:01<01:28, 111.10entry/s]
#
# Extracting entities:   2%|▏         | 154/10000 [00:01<01:28, 111.05entry/s]
#
# Extracting entities:   2%|▏         | 166/10000 [00:01<01:28, 111.25entry/s]
#
# Extracting entities:   2%|▏         | 178/10000 [00:01<01:28, 111.47entry/s]
#
# Extracting entities:   2%|▏         | 190/10000 [00:01<01:27, 112.67entry/s]
#
# Extracting entities:   2%|▏         | 202/10000 [00:01<01:26, 113.00entry/s]
#
# Extracting entities:   2%|▏         | 214/10000 [00:01<01:27, 112.34entry/s]
#
# Extracting entities:   2%|▏         | 226/10000 [00:02<01:27, 111.71entry/s]
#
# Extracting entities:   2%|▏         | 238/10000 [00:02<01:28, 109.96entry/s]
#
# Extracting entities:   2%|▎         | 250/10000 [00:02<01:30, 107.55entry/s]
#
# Extracting entities:   3%|▎         | 261/10000 [00:02<01:30, 107.06entry/s]
#
# Extracting entities:   3%|▎         | 272/10000 [00:02<01:31, 106.26entry/s]
#
# Extracting entities:   3%|▎         | 283/10000 [00:02<01:32, 105.41entry/s]
#
# Extracting entities:   3%|▎         | 294/10000 [00:02<01:32, 105.07entry/s]
#
# Extracting entities:   3%|▎         | 306/10000 [00:02<01:30, 107.41entry/s]
#
# Extracting entities:   3%|▎         | 317/10000 [00:02<01:32, 104.49entry/s]
#
# Extracting entities:   3%|▎         | 328/10000 [00:03<01:31, 105.37entry/s]
#
# Extracting entities:   3%|▎         | 339/10000 [00:03<01:31, 105.34entry/s]
#
# Extracting entities:   4%|▎         | 351/10000 [00:03<01:29, 107.54entry/s]
#
# Extracting entities:   4%|▎         | 363/10000 [00:03<01:28, 108.79entry/s]
#
# Extracting entities:   4%|▍         | 375/10000 [00:03<01:27, 110.41entry/s]
#
# Extracting entities:   4%|▍         | 387/10000 [00:03<01:30, 106.26entry/s]
#
# Extracting entities:   4%|▍         | 398/10000 [00:03<01:30, 106.47entry/s]
#
# Extracting entities:   4%|▍         | 409/10000 [00:03<01:30, 106.31entry/s]
#
# Extracting entities:   4%|▍         | 420/10000 [00:03<01:32, 104.08entry/s]
#
# Extracting entities:   4%|▍         | 431/10000 [00:03<01:32, 103.98entry/s]
#
# Extracting entities:   4%|▍         | 443/10000 [00:04<01:29, 106.66entry/s]
#
# Extracting entities:   5%|▍         | 455/10000 [00:04<01:27, 108.90entry/s]
#
# Extracting entities:   5%|▍         | 467/10000 [00:04<01:27, 109.34entry/s]
#
# Extracting entities:   5%|▍         | 478/10000 [00:04<01:27, 109.40entry/s]
#
# Extracting entities:   5%|▍         | 490/10000 [00:04<01:26, 109.72entry/s]
#
# Extracting entities:   5%|▌         | 502/10000 [00:04<01:25, 111.60entry/s]
#
# Extracting entities:   5%|▌         | 514/10000 [00:04<01:24, 112.80entry/s]
#
# Extracting entities:   5%|▌         | 526/10000 [00:04<01:24, 111.99entry/s]
#
# Extracting entities:   5%|▌         | 538/10000 [00:04<01:25, 110.08entry/s]
#
# Extracting entities:   6%|▌         | 550/10000 [00:05<01:27, 107.76entry/s]
#
# Extracting entities:   6%|▌         | 561/10000 [00:05<01:28, 106.64entry/s]
#
# Extracting entities:   6%|▌         | 572/10000 [00:05<01:28, 106.28entry/s]
#
# Extracting entities:   6%|▌         | 583/10000 [00:05<01:27, 107.25entry/s]
#
# Extracting entities:   6%|▌         | 594/10000 [00:05<01:28, 106.89entry/s]
#
# Extracting entities:   6%|▌         | 605/10000 [00:05<01:27, 107.77entry/s]
#
# Extracting entities:   6%|▌         | 616/10000 [00:05<01:28, 106.41entry/s]
#
# Extracting entities:   6%|▋         | 627/10000 [00:05<01:28, 106.26entry/s]
#
# Extracting entities:   6%|▋         | 639/10000 [00:05<01:26, 108.82entry/s]
#
# Extracting entities:   6%|▋         | 650/10000 [00:05<01:27, 107.22entry/s]
#
# Extracting entities:   7%|▋         | 661/10000 [00:06<01:26, 107.35entry/s]
#
# Extracting entities:   7%|▋         | 672/10000 [00:06<01:29, 104.41entry/s]
#
# Extracting entities:   7%|▋         | 683/10000 [00:06<01:29, 104.10entry/s]
#
# Extracting entities:   7%|▋         | 695/10000 [00:06<01:26, 107.28entry/s]
#
# Extracting entities:   7%|▋         | 707/10000 [00:06<01:25, 109.04entry/s]
#
# Extracting entities:   7%|▋         | 719/10000 [00:06<01:24, 110.05entry/s]
#
# Extracting entities:   7%|▋         | 731/10000 [00:06<01:25, 108.05entry/s]
#
# Extracting entities:   7%|▋         | 743/10000 [00:06<01:23, 110.60entry/s]
#
# Extracting entities:   8%|▊         | 755/10000 [00:06<01:24, 108.84entry/s]
#
# Extracting entities:   8%|▊         | 767/10000 [00:07<01:25, 108.24entry/s]
#
# Extracting entities:   8%|▊         | 778/10000 [00:07<01:25, 108.30entry/s]
#
# Extracting entities:   8%|▊         | 790/10000 [00:07<01:24, 108.55entry/s]
#
# Extracting entities:   8%|▊         | 801/10000 [00:07<01:25, 107.23entry/s]
#
# Extracting entities:   8%|▊         | 813/10000 [00:07<01:23, 109.88entry/s]
#
# Extracting entities:   8%|▊         | 825/10000 [00:07<01:21, 111.98entry/s]
#
# Extracting entities:   8%|▊         | 837/10000 [00:07<01:22, 110.60entry/s]
#
# Extracting entities:   8%|▊         | 849/10000 [00:07<01:21, 111.77entry/s]
#
# Extracting entities:   9%|▊         | 861/10000 [00:07<01:20, 113.79entry/s]
#
# Extracting entities:   9%|▊         | 874/10000 [00:08<01:18, 116.00entry/s]
#
# Extracting entities:   9%|▉         | 886/10000 [00:08<01:20, 113.77entry/s]
#
# Extracting entities:   9%|▉         | 898/10000 [00:08<01:20, 113.40entry/s]
#
# Extracting entities:   9%|▉         | 910/10000 [00:08<01:20, 113.10entry/s]
#
# Extracting entities:   9%|▉         | 922/10000 [00:08<01:19, 114.34entry/s]
#
# Extracting entities:   9%|▉         | 934/10000 [00:08<01:19, 114.23entry/s]
#
# Extracting entities:   9%|▉         | 946/10000 [00:08<01:19, 114.40entry/s]
#
# Extracting entities:  10%|▉         | 958/10000 [00:08<01:20, 111.90entry/s]
#
# Extracting entities:  10%|▉         | 970/10000 [00:08<01:19, 113.97entry/s]
#
# Extracting entities:  10%|▉         | 982/10000 [00:08<01:20, 112.60entry/s]
#
# Extracting entities:  10%|▉         | 994/10000 [00:09<01:20, 112.34entry/s]
#
# Extracting entities:  10%|█         | 1006/10000 [00:09<01:20, 111.95entry/s]
#
# Extracting entities:  10%|█         | 1018/10000 [00:09<01:20, 111.59entry/s]
#
# Extracting entities:  10%|█         | 1030/10000 [00:09<01:19, 113.20entry/s]
#
# Extracting entities:  10%|█         | 1042/10000 [00:09<01:20, 111.25entry/s]
#
# Extracting entities:  11%|█         | 1054/10000 [00:09<01:19, 112.00entry/s]
#
# Extracting entities:  11%|█         | 1066/10000 [00:09<01:19, 112.01entry/s]
#
# Extracting entities:  11%|█         | 1078/10000 [00:09<01:21, 109.59entry/s]
#
# Extracting entities:  11%|█         | 1089/10000 [00:09<01:21, 109.35entry/s]
#
# Extracting entities:  11%|█         | 1101/10000 [00:10<01:20, 111.21entry/s]
#
# Extracting entities:  11%|█         | 1113/10000 [00:10<01:20, 110.03entry/s]
#
# Extracting entities:  11%|█▏        | 1125/10000 [00:10<01:19, 111.63entry/s]
#
# Extracting entities:  11%|█▏        | 1137/10000 [00:10<01:19, 111.08entry/s]
#
# Extracting entities:  11%|█▏        | 1149/10000 [00:10<01:19, 111.87entry/s]
#
# Extracting entities:  12%|█▏        | 1161/10000 [00:10<01:20, 110.43entry/s]
#
# Extracting entities:  12%|█▏        | 1173/10000 [00:10<01:19, 111.03entry/s]
#
# Extracting entities:  12%|█▏        | 1186/10000 [00:10<01:16, 114.48entry/s]
#
# Extracting entities:  12%|█▏        | 1198/10000 [00:10<01:16, 115.18entry/s]
#
# Extracting entities:  12%|█▏        | 1210/10000 [00:11<01:16, 115.66entry/s]
#
# Extracting entities:  12%|█▏        | 1222/10000 [00:11<01:16, 114.26entry/s]
#
# Extracting entities:  12%|█▏        | 1234/10000 [00:11<01:19, 110.95entry/s]
#
# Extracting entities:  12%|█▏        | 1246/10000 [00:11<01:19, 109.89entry/s]
#
# Extracting entities:  13%|█▎        | 1258/10000 [00:11<01:18, 110.89entry/s]
#
# Extracting entities:  13%|█▎        | 1270/10000 [00:11<01:19, 110.36entry/s]
#
# Extracting entities:  13%|█▎        | 1282/10000 [00:11<01:19, 109.80entry/s]
#
# Extracting entities:  13%|█▎        | 1293/10000 [00:11<01:19, 109.80entry/s]
#
# Extracting entities:  13%|█▎        | 1306/10000 [00:11<01:17, 112.54entry/s]
#
# Extracting entities:  13%|█▎        | 1319/10000 [00:11<01:15, 114.65entry/s]
#
# Extracting entities:  13%|█▎        | 1331/10000 [00:12<01:16, 113.02entry/s]
#
# Extracting entities:  13%|█▎        | 1343/10000 [00:12<01:17, 111.11entry/s]
#
# Extracting entities:  14%|█▎        | 1355/10000 [00:12<01:16, 113.11entry/s]
#
# Extracting entities:  14%|█▎        | 1367/10000 [00:12<01:16, 112.29entry/s]
#
# Extracting entities:  14%|█▍        | 1379/10000 [00:12<01:17, 111.29entry/s]
#
# Extracting entities:  14%|█▍        | 1391/10000 [00:12<01:19, 108.76entry/s]
#
# Extracting entities:  14%|█▍        | 1403/10000 [00:12<01:18, 109.76entry/s]
#
# Extracting entities:  14%|█▍        | 1414/10000 [00:12<01:18, 109.51entry/s]
#
# Extracting entities:  14%|█▍        | 1426/10000 [00:12<01:18, 109.83entry/s]
#
# Extracting entities:  14%|█▍        | 1437/10000 [00:13<01:18, 109.09entry/s]
#
# Extracting entities:  14%|█▍        | 1448/10000 [00:13<01:18, 108.99entry/s]
#
# Extracting entities:  15%|█▍        | 1459/10000 [00:13<01:18, 108.79entry/s]
#
# Extracting entities:  15%|█▍        | 1470/10000 [00:13<01:18, 108.06entry/s]
#
# Extracting entities:  15%|█▍        | 1481/10000 [00:13<01:18, 108.08entry/s]
#
# Extracting entities:  15%|█▍        | 1492/10000 [00:13<01:20, 105.75entry/s]
#
# Extracting entities:  15%|█▌        | 1504/10000 [00:13<01:18, 108.23entry/s]
#
# Extracting entities:  15%|█▌        | 1516/10000 [00:13<01:17, 109.43entry/s]
#
# Extracting entities:  15%|█▌        | 1527/10000 [00:13<01:19, 106.04entry/s]
#
# Extracting entities:  15%|█▌        | 1540/10000 [00:14<01:16, 110.37entry/s]
#
# Extracting entities:  16%|█▌        | 1552/10000 [00:14<01:16, 110.03entry/s]
#
# Extracting entities:  16%|█▌        | 1564/10000 [00:14<01:19, 106.26entry/s]
#
# Extracting entities:  16%|█▌        | 1575/10000 [00:14<01:19, 106.56entry/s]
#
# Extracting entities:  16%|█▌        | 1587/10000 [00:14<01:17, 108.51entry/s]
#
# Extracting entities:  16%|█▌        | 1598/10000 [00:14<01:18, 107.53entry/s]
#
# Extracting entities:  16%|█▌        | 1610/10000 [00:14<01:16, 109.11entry/s]
#
# Extracting entities:  16%|█▌        | 1622/10000 [00:14<01:15, 111.39entry/s]
#
# Extracting entities:  16%|█▋        | 1634/10000 [00:14<01:14, 112.30entry/s]
#
# Extracting entities:  16%|█▋        | 1646/10000 [00:14<01:16, 108.99entry/s]
#
# Extracting entities:  17%|█▋        | 1658/10000 [00:15<01:15, 109.90entry/s]
#
# Extracting entities:  17%|█▋        | 1670/10000 [00:15<01:17, 108.03entry/s]
#
# Extracting entities:  17%|█▋        | 1682/10000 [00:15<01:15, 110.52entry/s]
#
# Extracting entities:  17%|█▋        | 1695/10000 [00:15<01:12, 113.79entry/s]
#
# Extracting entities:  17%|█▋        | 1707/10000 [00:15<01:14, 112.04entry/s]
#
# Extracting entities:  17%|█▋        | 1719/10000 [00:15<01:12, 113.60entry/s]
#
# Extracting entities:  17%|█▋        | 1731/10000 [00:15<01:13, 113.04entry/s]
#
# Extracting entities:  17%|█▋        | 1743/10000 [00:15<01:14, 111.37entry/s]
#
# Extracting entities:  18%|█▊        | 1755/10000 [00:15<01:15, 109.44entry/s]
#
# Extracting entities:  18%|█▊        | 1766/10000 [00:16<01:15, 108.72entry/s]
#
# Extracting entities:  18%|█▊        | 1777/10000 [00:16<01:36, 85.27entry/s]
#
# Extracting entities:  18%|█▊        | 1788/10000 [00:16<01:32, 89.03entry/s]
#
# Extracting entities:  18%|█▊        | 1799/10000 [00:16<01:27, 94.02entry/s]
#
# Extracting entities:  18%|█▊        | 1810/10000 [00:16<01:23, 98.09entry/s]
#
# Extracting entities:  18%|█▊        | 1822/10000 [00:16<01:18, 103.73entry/s]
#
# Extracting entities:  18%|█▊        | 1834/10000 [00:16<01:17, 105.77entry/s]
#
# Extracting entities:  18%|█▊        | 1845/10000 [00:16<01:17, 104.74entry/s]
#
# Extracting entities:  19%|█▊        | 1856/10000 [00:16<01:16, 106.05entry/s]
#
# Extracting entities:  19%|█▊        | 1867/10000 [00:17<01:17, 104.73entry/s]
#
# Extracting entities:  19%|█▉        | 1879/10000 [00:17<01:16, 106.27entry/s]
#
# Extracting entities:  19%|█▉        | 1890/10000 [00:17<01:16, 105.52entry/s]
#
# Extracting entities:  19%|█▉        | 1901/10000 [00:17<01:17, 103.97entry/s]
#
# Extracting entities:  19%|█▉        | 1913/10000 [00:17<01:16, 106.15entry/s]
#
# Extracting entities:  19%|█▉        | 1925/10000 [00:17<01:14, 108.61entry/s]
#
# Extracting entities:  19%|█▉        | 1936/10000 [00:17<01:14, 108.60entry/s]
#
# Extracting entities:  19%|█▉        | 1947/10000 [00:17<01:14, 108.78entry/s]
#
# Extracting entities:  20%|█▉        | 1959/10000 [00:17<01:12, 111.50entry/s]
#
# Extracting entities:  20%|█▉        | 1971/10000 [00:18<01:12, 111.11entry/s]
#
# Extracting entities:  20%|█▉        | 1983/10000 [00:18<01:13, 109.14entry/s]
#
# Extracting entities:  20%|█▉        | 1994/10000 [00:18<01:13, 109.16entry/s]
#
# Extracting entities:  20%|██        | 2005/10000 [00:18<01:13, 109.26entry/s]
#
# Extracting entities:  20%|██        | 2016/10000 [00:18<01:12, 109.46entry/s]
#
# Extracting entities:  20%|██        | 2027/10000 [00:18<01:13, 108.93entry/s]
#
# Extracting entities:  20%|██        | 2039/10000 [00:18<01:11, 110.72entry/s]
#
# Extracting entities:  21%|██        | 2051/10000 [00:18<01:11, 111.05entry/s]
#
# Extracting entities:  21%|██        | 2063/10000 [00:18<01:09, 113.50entry/s]
#
# Extracting entities:  21%|██        | 2075/10000 [00:18<01:11, 111.47entry/s]
#
# Extracting entities:  21%|██        | 2087/10000 [00:19<01:11, 110.57entry/s]
#
# Extracting entities:  21%|██        | 2099/10000 [00:19<01:11, 110.61entry/s]
#
# Extracting entities:  21%|██        | 2111/10000 [00:19<01:11, 110.33entry/s]
#
# Extracting entities:  21%|██        | 2123/10000 [00:19<01:10, 111.72entry/s]
#
# Extracting entities:  21%|██▏       | 2135/10000 [00:19<01:10, 111.77entry/s]
#
# Extracting entities:  21%|██▏       | 2147/10000 [00:19<01:09, 113.08entry/s]
#
# Extracting entities:  22%|██▏       | 2159/10000 [00:19<01:10, 110.90entry/s]
#
# Extracting entities:  22%|██▏       | 2171/10000 [00:19<01:09, 112.07entry/s]
#
# Extracting entities:  22%|██▏       | 2184/10000 [00:19<01:08, 114.43entry/s]
#
# Extracting entities:  22%|██▏       | 2196/10000 [00:20<01:07, 115.05entry/s]
#
# Extracting entities:  22%|██▏       | 2208/10000 [00:20<01:08, 113.58entry/s]
#
# Extracting entities:  22%|██▏       | 2220/10000 [00:20<01:08, 114.18entry/s]
#
# Extracting entities:  22%|██▏       | 2232/10000 [00:20<01:07, 115.00entry/s]
#
# Extracting entities:  22%|██▏       | 2244/10000 [00:20<01:07, 114.11entry/s]
#
# Extracting entities:  23%|██▎       | 2256/10000 [00:20<01:07, 114.12entry/s]
#
# Extracting entities:  23%|██▎       | 2268/10000 [00:20<01:07, 114.06entry/s]
#
# Extracting entities:  23%|██▎       | 2280/10000 [00:20<01:08, 112.41entry/s]
#
# Extracting entities:  23%|██▎       | 2292/10000 [00:20<01:08, 113.21entry/s]
#
# Extracting entities:  23%|██▎       | 2304/10000 [00:21<01:07, 114.26entry/s]
#
# Extracting entities:  23%|██▎       | 2316/10000 [00:21<01:07, 113.75entry/s]
#
# Extracting entities:  23%|██▎       | 2328/10000 [00:21<01:10, 109.11entry/s]
#
# Extracting entities:  23%|██▎       | 2340/10000 [00:21<01:09, 110.32entry/s]
#
# Extracting entities:  24%|██▎       | 2352/10000 [00:21<01:08, 112.41entry/s]
#
# Extracting entities:  24%|██▎       | 2364/10000 [00:21<01:07, 112.81entry/s]
#
# Extracting entities:  24%|██▍       | 2376/10000 [00:21<01:08, 110.55entry/s]
#
# Extracting entities:  24%|██▍       | 2388/10000 [00:21<01:08, 110.64entry/s]
#
# Extracting entities:  24%|██▍       | 2400/10000 [00:21<01:09, 108.85entry/s]
#
# Extracting entities:  24%|██▍       | 2411/10000 [00:21<01:09, 108.57entry/s]
#
# Extracting entities:  24%|██▍       | 2423/10000 [00:22<01:08, 110.83entry/s]
#
# Extracting entities:  24%|██▍       | 2436/10000 [00:22<01:06, 113.93entry/s]
#
# Extracting entities:  24%|██▍       | 2448/10000 [00:22<01:07, 111.81entry/s]
#
# Extracting entities:  25%|██▍       | 2460/10000 [00:22<01:06, 113.53entry/s]
#
# Extracting entities:  25%|██▍       | 2472/10000 [00:22<01:07, 111.92entry/s]
#
# Extracting entities:  25%|██▍       | 2484/10000 [00:22<01:08, 109.13entry/s]
#
# Extracting entities:  25%|██▍       | 2496/10000 [00:22<01:06, 112.13entry/s]
#
# Extracting entities:  25%|██▌       | 2508/10000 [00:22<01:07, 110.87entry/s]
#
# Extracting entities:  25%|██▌       | 2520/10000 [00:22<01:05, 113.37entry/s]
#
# Extracting entities:  25%|██▌       | 2532/10000 [00:23<01:06, 111.59entry/s]
#
# Extracting entities:  25%|██▌       | 2544/10000 [00:23<01:06, 112.20entry/s]
#
# Extracting entities:  26%|██▌       | 2556/10000 [00:23<01:09, 107.83entry/s]
#
# Extracting entities:  26%|██▌       | 2568/10000 [00:23<01:08, 108.35entry/s]
#
# Extracting entities:  26%|██▌       | 2579/10000 [00:23<01:08, 108.32entry/s]
#
# Extracting entities:  26%|██▌       | 2591/10000 [00:23<01:08, 108.26entry/s]
#
# Extracting entities:  26%|██▌       | 2603/10000 [00:23<01:06, 110.95entry/s]
#
# Extracting entities:  26%|██▌       | 2615/10000 [00:23<01:07, 108.72entry/s]
#
# Extracting entities:  26%|██▋       | 2627/10000 [00:23<01:07, 109.65entry/s]
#
# Extracting entities:  26%|██▋       | 2638/10000 [00:24<01:07, 109.12entry/s]
#
# Extracting entities:  26%|██▋       | 2649/10000 [00:24<01:07, 108.14entry/s]
#
# Extracting entities:  27%|██▋       | 2660/10000 [00:24<01:08, 106.59entry/s]
#
# Extracting entities:  27%|██▋       | 2671/10000 [00:24<01:09, 105.07entry/s]
#
# Extracting entities:  27%|██▋       | 2682/10000 [00:24<01:08, 106.44entry/s]
#
# Extracting entities:  27%|██▋       | 2694/10000 [00:24<01:07, 108.20entry/s]
#
# Extracting entities:  27%|██▋       | 2706/10000 [00:24<01:06, 109.76entry/s]
#
# Extracting entities:  27%|██▋       | 2718/10000 [00:24<01:05, 111.03entry/s]
#
# Extracting entities:  27%|██▋       | 2730/10000 [00:24<01:06, 109.58entry/s]
#
# Extracting entities:  27%|██▋       | 2741/10000 [00:25<01:07, 108.02entry/s]
#
# Extracting entities:  28%|██▊       | 2753/10000 [00:25<01:07, 108.14entry/s]
#
# Extracting entities:  28%|██▊       | 2765/10000 [00:25<01:05, 110.31entry/s]
#
# Extracting entities:  28%|██▊       | 2777/10000 [00:25<01:05, 110.53entry/s]
#
# Extracting entities:  28%|██▊       | 2789/10000 [00:25<01:05, 110.06entry/s]
#
# Extracting entities:  28%|██▊       | 2801/10000 [00:25<01:06, 108.69entry/s]
#
# Extracting entities:  28%|██▊       | 2813/10000 [00:25<01:04, 110.64entry/s]
#
# Extracting entities:  28%|██▊       | 2825/10000 [00:25<01:04, 111.53entry/s]
#
# Extracting entities:  28%|██▊       | 2837/10000 [00:25<01:03, 111.92entry/s]
#
# Extracting entities:  28%|██▊       | 2849/10000 [00:25<01:04, 111.23entry/s]
#
# Extracting entities:  29%|██▊       | 2861/10000 [00:26<01:03, 112.17entry/s]
#
# Extracting entities:  29%|██▊       | 2873/10000 [00:26<01:04, 110.27entry/s]
#
# Extracting entities:  29%|██▉       | 2885/10000 [00:26<01:03, 111.58entry/s]
#
# Extracting entities:  29%|██▉       | 2897/10000 [00:26<01:02, 113.86entry/s]
#
# Extracting entities:  29%|██▉       | 2909/10000 [00:26<01:02, 114.20entry/s]
#
# Extracting entities:  29%|██▉       | 2921/10000 [00:26<01:02, 113.02entry/s]
#
# Extracting entities:  29%|██▉       | 2933/10000 [00:26<01:02, 112.44entry/s]
#
# Extracting entities:  29%|██▉       | 2945/10000 [00:26<01:01, 114.17entry/s]
#
# Extracting entities:  30%|██▉       | 2957/10000 [00:26<01:01, 114.01entry/s]
#
# Extracting entities:  30%|██▉       | 2969/10000 [00:27<01:01, 113.62entry/s]
#
# Extracting entities:  30%|██▉       | 2981/10000 [00:27<01:01, 114.85entry/s]
#
# Extracting entities:  30%|██▉       | 2993/10000 [00:27<01:02, 111.23entry/s]
#
# Extracting entities:  30%|███       | 3005/10000 [00:27<01:04, 108.61entry/s]
#
# Extracting entities:  30%|███       | 3017/10000 [00:27<01:03, 110.00entry/s]
#
# Extracting entities:  30%|███       | 3029/10000 [00:27<01:03, 109.68entry/s]
#
# Extracting entities:  30%|███       | 3041/10000 [00:27<01:03, 109.44entry/s]
#
# Extracting entities:  31%|███       | 3052/10000 [00:27<01:03, 109.22entry/s]
#
# Extracting entities:  31%|███       | 3064/10000 [00:27<01:02, 110.31entry/s]
#
# Extracting entities:  31%|███       | 3076/10000 [00:28<01:02, 110.86entry/s]
#
# Extracting entities:  31%|███       | 3088/10000 [00:28<01:01, 112.01entry/s]
#
# Extracting entities:  31%|███       | 3100/10000 [00:28<01:04, 107.43entry/s]
#
# Extracting entities:  31%|███       | 3111/10000 [00:28<01:04, 106.57entry/s]
#
# Extracting entities:  31%|███       | 3122/10000 [00:28<01:04, 105.93entry/s]
#
# Extracting entities:  31%|███▏      | 3133/10000 [00:28<01:04, 106.00entry/s]
#
# Extracting entities:  31%|███▏      | 3144/10000 [00:28<01:04, 106.08entry/s]
#
# Extracting entities:  32%|███▏      | 3155/10000 [00:28<01:04, 106.29entry/s]
#
# Extracting entities:  32%|███▏      | 3167/10000 [00:28<01:03, 107.81entry/s]
#
# Extracting entities:  32%|███▏      | 3178/10000 [00:28<01:04, 106.33entry/s]
#
# Extracting entities:  32%|███▏      | 3189/10000 [00:29<01:05, 103.41entry/s]
#
# Extracting entities:  32%|███▏      | 3200/10000 [00:29<01:07, 101.05entry/s]
#
# Extracting entities:  32%|███▏      | 3211/10000 [00:29<01:07, 100.00entry/s]
#
# Extracting entities:  32%|███▏      | 3222/10000 [00:29<01:06, 101.42entry/s]
#
# Extracting entities:  32%|███▏      | 3233/10000 [00:29<01:05, 103.18entry/s]
#
# Extracting entities:  32%|███▏      | 3245/10000 [00:29<01:03, 106.11entry/s]
#
# Extracting entities:  33%|███▎      | 3256/10000 [00:29<01:03, 106.88entry/s]
#
# Extracting entities:  33%|███▎      | 3267/10000 [00:29<01:03, 105.96entry/s]
#
# Extracting entities:  33%|███▎      | 3278/10000 [00:29<01:03, 105.81entry/s]
#
# Extracting entities:  33%|███▎      | 3290/10000 [00:30<01:02, 107.94entry/s]
#
# Extracting entities:  33%|███▎      | 3302/10000 [00:30<01:00, 109.82entry/s]
#
# Extracting entities:  33%|███▎      | 3314/10000 [00:30<01:00, 109.96entry/s]
#
# Extracting entities:  33%|███▎      | 3325/10000 [00:30<01:02, 107.47entry/s]
#
# Extracting entities:  33%|███▎      | 3337/10000 [00:30<01:00, 110.76entry/s]
#
# Extracting entities:  33%|███▎      | 3349/10000 [00:30<01:00, 109.86entry/s]
#
# Extracting entities:  38%|███▊      | 3765/10000 [00:34<00:56, 110.34entry/s]
#
# Extracting entities:  38%|███▊      | 3777/10000 [00:34<00:56, 109.52entry/s]
#
# Extracting entities:  38%|███▊      | 3788/10000 [00:34<00:56, 109.02entry/s]
#
# Extracting entities:  38%|███▊      | 3800/10000 [00:34<00:55, 110.95entry/s]
#
# Extracting entities:  38%|███▊      | 3812/10000 [00:34<00:55, 111.96entry/s]
#
# Extracting entities:  38%|███▊      | 3824/10000 [00:34<00:55, 111.02entry/s]
#
# Extracting entities:  38%|███▊      | 3836/10000 [00:34<00:55, 110.20entry/s]
#
# Extracting entities:  38%|███▊      | 3848/10000 [00:35<00:57, 107.66entry/s]
#
# Extracting entities:  39%|███▊      | 3859/10000 [00:35<00:57, 107.31entry/s]
#
# Extracting entities:  39%|███▊      | 3870/10000 [00:35<00:57, 106.72entry/s]
#
# Extracting entities:  39%|███▉      | 3882/10000 [00:35<00:57, 107.20entry/s]
#
# Extracting entities:  39%|███▉      | 3894/10000 [00:35<00:55, 109.63entry/s]
#
# Extracting entities:  39%|███▉      | 3906/10000 [00:35<00:54, 111.38entry/s]
#
# Extracting entities:  39%|███▉      | 3918/10000 [00:35<00:54, 110.76entry/s]
#
# Extracting entities:  39%|███▉      | 3930/10000 [00:35<00:55, 109.34entry/s]
#
# Extracting entities:  39%|███▉      | 3941/10000 [00:35<00:56, 107.82entry/s]
#
# Extracting entities:  40%|███▉      | 3953/10000 [00:36<00:54, 111.05entry/s]
#
# Extracting entities:  40%|███▉      | 3965/10000 [00:36<00:54, 110.84entry/s]
#
# Extracting entities:  40%|███▉      | 3977/10000 [00:36<00:53, 112.56entry/s]
#
# Extracting entities:  40%|███▉      | 3989/10000 [00:36<00:55, 108.77entry/s]
#
# Extracting entities:  40%|████      | 4002/10000 [00:36<00:53, 112.52entry/s]
#
# Extracting entities:  40%|████      | 4014/10000 [00:36<00:53, 112.56entry/s]
#
# Extracting entities:  40%|████      | 4026/10000 [00:36<00:53, 110.79entry/s]
#
# Extracting entities:  40%|████      | 4038/10000 [00:36<00:55, 107.16entry/s]
#
# Extracting entities:  40%|████      | 4050/10000 [00:36<00:54, 109.60entry/s]
#
# Extracting entities:  41%|████      | 4062/10000 [00:37<00:53, 110.77entry/s]
#
# Extracting entities:  41%|████      | 4074/10000 [00:37<00:53, 111.32entry/s]
#
# Extracting entities:  41%|████      | 4086/10000 [00:37<00:52, 112.22entry/s]
#
# Extracting entities:  41%|████      | 4098/10000 [00:37<00:54, 109.08entry/s]
#
# Extracting entities:  41%|████      | 4109/10000 [00:37<00:54, 108.97entry/s]
#
# Extracting entities:  41%|████      | 4120/10000 [00:37<00:54, 107.84entry/s]
#
# Extracting entities:  41%|████▏     | 4132/10000 [00:37<00:54, 108.59entry/s]
#
# Extracting entities:  41%|████▏     | 4143/10000 [00:37<00:54, 107.39entry/s]
#
# Extracting entities:  42%|████▏     | 4154/10000 [00:37<00:54, 107.66entry/s]
#
# Extracting entities:  42%|████▏     | 4166/10000 [00:38<00:52, 110.13entry/s]
#
# Extracting entities:  50%|████▉     | 4984/10000 [00:45<00:44, 111.79entry/s]
#
# Extracting entities:  50%|████▉     | 4996/10000 [00:45<00:44, 111.90entry/s]
#
# Extracting entities:  50%|█████     | 5008/10000 [00:45<00:43, 114.09entry/s]
#
# Extracting entities:  50%|█████     | 5020/10000 [00:45<00:43, 113.68entry/s]
#
# Extracting entities:  50%|█████     | 5032/10000 [00:45<00:44, 110.62entry/s]
#
# Extracting entities:  50%|█████     | 5044/10000 [00:45<00:45, 109.54entry/s]
#
# Extracting entities:  51%|█████     | 5056/10000 [00:46<00:44, 112.22entry/s]
#
# Extracting entities:  51%|█████     | 5068/10000 [00:46<00:44, 111.10entry/s]
#
# Extracting entities:  51%|█████     | 5080/10000 [00:46<00:47, 102.95entry/s]
#
# Extracting entities:  51%|█████     | 5091/10000 [00:46<00:47, 104.39entry/s]
#
# Extracting entities:  51%|█████     | 5103/10000 [00:46<00:45, 107.68entry/s]
#
# Extracting entities:  51%|█████     | 5115/10000 [00:46<00:44, 110.58entry/s]
#
# Extracting entities:  51%|█████▏    | 5127/10000 [00:46<00:44, 110.61entry/s]
#
# Extracting entities:  51%|█████▏    | 5139/10000 [00:46<00:43, 111.95entry/s]
#
# Extracting entities:  52%|█████▏    | 5151/10000 [00:46<00:43, 111.83entry/s]
#
# Extracting entities:  52%|█████▏    | 5163/10000 [00:47<00:43, 110.67entry/s]
#
# Extracting entities:  52%|█████▏    | 5176/10000 [00:47<00:42, 114.03entry/s]
#
# Extracting entities:  52%|█████▏    | 5188/10000 [00:47<00:44, 108.56entry/s]
#
# Extracting entities:  52%|█████▏    | 5200/10000 [00:47<00:43, 109.80entry/s]
#
# Extracting entities:  52%|█████▏    | 5212/10000 [00:47<00:42, 111.92entry/s]
#
# Extracting entities:  52%|█████▏    | 5224/10000 [00:47<00:42, 113.60entry/s]
#
# Extracting entities:  52%|█████▏    | 5236/10000 [00:47<00:41, 113.74entry/s]
#
# Extracting entities:  52%|█████▏    | 5248/10000 [00:47<00:42, 112.99entry/s]
#
# Extracting entities:  53%|█████▎    | 5260/10000 [00:47<00:42, 110.90entry/s]
#
# Extracting entities:  53%|█████▎    | 5272/10000 [00:48<00:41, 112.73entry/s]
#
# Extracting entities:  53%|█████▎    | 5284/10000 [00:48<00:41, 112.31entry/s]
#
# Extracting entities:  53%|█████▎    | 5296/10000 [00:48<00:42, 111.02entry/s]
#
# Extracting entities:  53%|█████▎    | 5308/10000 [00:48<00:42, 110.43entry/s]
#
# Extracting entities:  53%|█████▎    | 5320/10000 [00:48<00:42, 110.47entry/s]
#
# Extracting entities:  53%|█████▎    | 5332/10000 [00:48<00:43, 108.54entry/s]
#
# Extracting entities:  53%|█████▎    | 5344/10000 [00:48<00:41, 111.55entry/s]
#
# Extracting entities:  54%|█████▎    | 5356/10000 [00:48<00:42, 110.40entry/s]
#
# Extracting entities:  54%|█████▎    | 5368/10000 [00:48<00:41, 110.88entry/s]
#
# Extracting entities:  54%|█████▍    | 5380/10000 [00:48<00:41, 110.32entry/s]
#
# Extracting entities:  54%|█████▍    | 5392/10000 [00:49<00:41, 110.07entry/s]
#
# Extracting entities:  54%|█████▍    | 5404/10000 [00:49<00:41, 109.56entry/s]
#
# Extracting entities:  54%|█████▍    | 5416/10000 [00:49<00:41, 111.43entry/s]
#
# Extracting entities:  54%|█████▍    | 5428/10000 [00:49<00:41, 110.13entry/s]
#
# Extracting entities:  54%|█████▍    | 5440/10000 [00:49<00:41, 110.93entry/s]
#
# Extracting entities:  55%|█████▍    | 5452/10000 [00:49<00:40, 111.12entry/s]
#
# Extracting entities:  55%|█████▍    | 5464/10000 [00:49<00:40, 112.51entry/s]
#
# Extracting entities:  55%|█████▍    | 5476/10000 [00:49<00:40, 112.28entry/s]
#
# Extracting entities:  55%|█████▍    | 5488/10000 [00:49<00:39, 113.05entry/s]
#
# Extracting entities:  55%|█████▌    | 5500/10000 [00:50<00:40, 110.61entry/s]
#
# Extracting entities:  55%|█████▌    | 5512/10000 [00:50<00:41, 108.91entry/s]
#
# Extracting entities:  55%|█████▌    | 5523/10000 [00:50<00:42, 104.48entry/s]
#
# Extracting entities:  55%|█████▌    | 5535/10000 [00:50<00:42, 105.04entry/s]
#
# Extracting entities:  55%|█████▌    | 5548/10000 [00:50<00:40, 110.53entry/s]
#
# Extracting entities:  56%|█████▌    | 5561/10000 [00:50<00:39, 113.53entry/s]
#
# Extracting entities:  56%|█████▌    | 5573/10000 [00:50<00:39, 112.56entry/s]
#
# Extracting entities:  56%|█████▌    | 5585/10000 [00:50<00:39, 112.15entry/s]
#
# Extracting entities:  56%|█████▌    | 5597/10000 [00:50<00:39, 111.03entry/s]
#
# Extracting entities:  56%|█████▌    | 5609/10000 [00:51<00:40, 109.38entry/s]
#
# Extracting entities:  56%|█████▌    | 5621/10000 [00:51<00:40, 108.58entry/s]
#
# Extracting entities:  56%|█████▋    | 5632/10000 [00:51<00:41, 104.27entry/s]
#
# Extracting entities:  56%|█████▋    | 5643/10000 [00:51<00:41, 104.68entry/s]
#
# Extracting entities:  57%|█████▋    | 5654/10000 [00:51<00:41, 103.51entry/s]
#
# Extracting entities:  57%|█████▋    | 5665/10000 [00:51<00:41, 105.15entry/s]
#
# Extracting entities:  57%|█████▋    | 5677/10000 [00:51<00:40, 107.11entry/s]
#
# Extracting entities:  57%|█████▋    | 5688/10000 [00:51<00:40, 105.29entry/s]
#
# Extracting entities:  57%|█████▋    | 5699/10000 [00:51<00:40, 106.16entry/s]
#
# Extracting entities:  57%|█████▋    | 5710/10000 [00:52<00:40, 107.10entry/s]
#
# Extracting entities:  57%|█████▋    | 5722/10000 [00:52<00:39, 108.62entry/s]
#
# Extracting entities:  57%|█████▋    | 5733/10000 [00:52<00:39, 108.02entry/s]
#
# Extracting entities:  57%|█████▋    | 5744/10000 [00:52<00:39, 107.70entry/s]
#
# Extracting entities:  58%|█████▊    | 5756/10000 [00:52<00:38, 109.34entry/s]
#
# Extracting entities:  58%|█████▊    | 5767/10000 [00:52<00:39, 106.44entry/s]
#
# Extracting entities:  58%|█████▊    | 5779/10000 [00:52<00:39, 108.08entry/s]
#
# Extracting entities:  58%|█████▊    | 5790/10000 [00:52<00:39, 106.79entry/s]
#
# Extracting entities:  58%|█████▊    | 5802/10000 [00:52<00:38, 108.42entry/s]
#
# Extracting entities:  58%|█████▊    | 5813/10000 [00:52<00:38, 107.48entry/s]
#
# Extracting entities:  58%|█████▊    | 5824/10000 [00:53<00:39, 105.03entry/s]
#
# Extracting entities:  58%|█████▊    | 5835/10000 [00:53<00:39, 106.10entry/s]
#
# Extracting entities:  58%|█████▊    | 5846/10000 [00:53<00:40, 102.36entry/s]
#
# Extracting entities:  59%|█████▊    | 5858/10000 [00:53<00:39, 106.20entry/s]
#
# Extracting entities:  59%|█████▊    | 5869/10000 [00:53<00:39, 104.82entry/s]
#
# Extracting entities:  59%|█████▉    | 5882/10000 [00:53<00:37, 110.11entry/s]
#
# Extracting entities:  59%|█████▉    | 5894/10000 [00:53<00:36, 111.38entry/s]
#
# Extracting entities:  59%|█████▉    | 5906/10000 [00:53<00:37, 110.01entry/s]
#
# Extracting entities:  59%|█████▉    | 5918/10000 [00:53<00:37, 109.61entry/s]
#
# Extracting entities:  59%|█████▉    | 5929/10000 [00:54<00:37, 108.25entry/s]
#
# Extracting entities:  59%|█████▉    | 5941/10000 [00:54<00:37, 109.41entry/s]
#
# Extracting entities:  60%|█████▉    | 5952/10000 [00:54<00:37, 107.05entry/s]
#
# Extracting entities:  60%|█████▉    | 5963/10000 [00:54<00:39, 103.29entry/s]
#
# Extracting entities:  60%|█████▉    | 5974/10000 [00:54<00:39, 101.51entry/s]
#
# Extracting entities:  60%|█████▉    | 5985/10000 [00:54<00:38, 103.64entry/s]
#
# Extracting entities:  60%|█████▉    | 5997/10000 [00:54<00:37, 106.62entry/s]
#
# Extracting entities:  60%|██████    | 6008/10000 [00:54<00:37, 106.72entry/s]
#
# Extracting entities:  60%|██████    | 6020/10000 [00:54<00:36, 110.41entry/s]
#
# Extracting entities:  60%|██████    | 6033/10000 [00:55<00:34, 113.80entry/s]
#
# Extracting entities:  60%|██████    | 6045/10000 [00:55<00:34, 115.24entry/s]
#
# Extracting entities:  61%|██████    | 6057/10000 [00:55<00:35, 110.89entry/s]
#
# Extracting entities:  61%|██████    | 6069/10000 [00:55<00:36, 107.52entry/s]
#
# Extracting entities:  61%|██████    | 6080/10000 [00:55<00:37, 104.29entry/s]
#
# Extracting entities:  61%|██████    | 6092/10000 [00:55<00:36, 107.39entry/s]
#
# Extracting entities:  61%|██████    | 6104/10000 [00:55<00:35, 110.39entry/s]
#
# Extracting entities:  61%|██████    | 6116/10000 [00:55<00:35, 109.28entry/s]
#
# Extracting entities:  61%|██████▏   | 6129/10000 [00:55<00:34, 112.56entry/s]
#
# Extracting entities:  61%|██████▏   | 6141/10000 [00:56<00:34, 113.25entry/s]
#
# Extracting entities:  62%|██████▏   | 6153/10000 [00:56<00:33, 114.93entry/s]
#
# Extracting entities:  62%|██████▏   | 6165/10000 [00:56<00:34, 112.54entry/s]
#
# Extracting entities:  82%|████████▏ | 8215/10000 [01:14<00:16, 107.74entry/s]
#
# Extracting entities:  82%|████████▏ | 8227/10000 [01:14<00:16, 108.71entry/s]
#
# Extracting entities:  82%|████████▏ | 8239/10000 [01:14<00:15, 110.60entry/s]
#
# Extracting entities:  83%|████████▎ | 8252/10000 [01:14<00:15, 114.50entry/s]
#
# Extracting entities:  83%|████████▎ | 8264/10000 [01:15<00:15, 112.31entry/s]
#
# Extracting entities:  83%|████████▎ | 8276/10000 [01:15<00:15, 112.74entry/s]
#
# Extracting entities:  83%|████████▎ | 8288/10000 [01:15<00:15, 112.92entry/s]
#
# Extracting entities:  83%|████████▎ | 8300/10000 [01:15<00:15, 112.56entry/s]
#
# Extracting entities:  83%|████████▎ | 8312/10000 [01:15<00:15, 111.47entry/s]
#
# Extracting entities:  83%|████████▎ | 8324/10000 [01:15<00:15, 111.60entry/s]
#
# Extracting entities:  83%|████████▎ | 8337/10000 [01:15<00:14, 114.46entry/s]
#
# Extracting entities:  83%|████████▎ | 8349/10000 [01:15<00:14, 113.21entry/s]
#
# Extracting entities:  84%|████████▎ | 8361/10000 [01:15<00:14, 112.71entry/s]
#
# Extracting entities:  84%|████████▎ | 8374/10000 [01:15<00:14, 115.71entry/s]
#
# Extracting entities:  84%|████████▍ | 8386/10000 [01:16<00:13, 115.88entry/s]
#
# Extracting entities:  84%|████████▍ | 8398/10000 [01:16<00:14, 112.92entry/s]
#
# Extracting entities:  84%|████████▍ | 8410/10000 [01:16<00:13, 114.14entry/s]
#
# Extracting entities:  84%|████████▍ | 8423/10000 [01:16<00:13, 116.93entry/s]
#
# Extracting entities:  84%|████████▍ | 8435/10000 [01:16<00:13, 114.54entry/s]
#
# Extracting entities:  84%|████████▍ | 8447/10000 [01:16<00:13, 111.77entry/s]
#
# Extracting entities:  85%|████████▍ | 8460/10000 [01:16<00:13, 114.22entry/s]
#
# Extracting entities:  85%|████████▍ | 8472/10000 [01:16<00:13, 113.59entry/s]
#
# Extracting entities:  85%|████████▍ | 8484/10000 [01:16<00:13, 113.11entry/s]
#
# Extracting entities:  85%|████████▍ | 8497/10000 [01:17<00:12, 116.65entry/s]
#
# Extracting entities:  85%|████████▌ | 8509/10000 [01:17<00:12, 116.21entry/s]
#
# Extracting entities:  85%|████████▌ | 8521/10000 [01:17<00:12, 115.08entry/s]
#
# Extracting entities:  85%|████████▌ | 8533/10000 [01:17<00:13, 112.81entry/s]
#
# Extracting entities:  85%|████████▌ | 8545/10000 [01:17<00:13, 111.17entry/s]
#
# Extracting entities:  86%|████████▌ | 8557/10000 [01:17<00:14, 102.62entry/s]
#
# Extracting entities:  86%|████████▌ | 8568/10000 [01:17<00:13, 103.24entry/s]
#
# Extracting entities:  86%|████████▌ | 8580/10000 [01:17<00:13, 105.41entry/s]
#
# Extracting entities:  86%|████████▌ | 8592/10000 [01:17<00:12, 108.47entry/s]
#
# Extracting entities:  86%|████████▌ | 8604/10000 [01:18<00:12, 110.96entry/s]
#
# Extracting entities:  86%|████████▌ | 8616/10000 [01:18<00:12, 110.04entry/s]
#
# Extracting entities:  86%|████████▋ | 8628/10000 [01:18<00:12, 107.83entry/s]
#
# Extracting entities:  86%|████████▋ | 8639/10000 [01:18<00:12, 107.95entry/s]
#
# Extracting entities:  87%|████████▋ | 8651/10000 [01:18<00:12, 110.20entry/s]
#
# Extracting entities:  87%|████████▋ | 8663/10000 [01:18<00:12, 109.57entry/s]
#
# Extracting entities:  87%|████████▋ | 8675/10000 [01:18<00:11, 110.63entry/s]
#
# Extracting entities:  87%|████████▋ | 8687/10000 [01:18<00:11, 110.42entry/s]
#
# Extracting entities:  87%|████████▋ | 8699/10000 [01:18<00:11, 109.52entry/s]
#
# Extracting entities:  87%|████████▋ | 8710/10000 [01:19<00:11, 108.86entry/s]
#
# Extracting entities:  87%|████████▋ | 8721/10000 [01:19<00:11, 108.81entry/s]
#
# Extracting entities:  87%|████████▋ | 8732/10000 [01:19<00:11, 106.92entry/s]
#
# Extracting entities:  87%|████████▋ | 8744/10000 [01:19<00:11, 108.49entry/s]
#
# Extracting entities:  88%|████████▊ | 8756/10000 [01:19<00:11, 111.74entry/s]
#
# Extracting entities:  88%|████████▊ | 8769/10000 [01:19<00:10, 115.00entry/s]
#
# Extracting entities:  88%|████████▊ | 8781/10000 [01:19<00:10, 115.99entry/s]
#
# Extracting entities:  88%|████████▊ | 8793/10000 [01:19<00:10, 113.57entry/s]
#
# Extracting entities:  88%|████████▊ | 8805/10000 [01:19<00:10, 111.35entry/s]
#
# Extracting entities:  88%|████████▊ | 8817/10000 [01:19<00:10, 112.54entry/s]
#
# Extracting entities:  88%|████████▊ | 8829/10000 [01:20<00:10, 113.10entry/s]
#
# Extracting entities:  88%|████████▊ | 8841/10000 [01:20<00:10, 110.86entry/s]
#
# Extracting entities:  89%|████████▊ | 8853/10000 [01:20<00:10, 109.06entry/s]
#
# Extracting entities:  89%|████████▊ | 8865/10000 [01:20<00:10, 111.53entry/s]
#
# Extracting entities:  89%|████████▉ | 8877/10000 [01:20<00:09, 112.96entry/s]
#
# Extracting entities:  89%|████████▉ | 8889/10000 [01:20<00:09, 111.92entry/s]
#
# Extracting entities:  89%|████████▉ | 8901/10000 [01:20<00:09, 112.07entry/s]
#
# Extracting entities:  89%|████████▉ | 8913/10000 [01:20<00:09, 111.60entry/s]
#
# Extracting entities:  89%|████████▉ | 8926/10000 [01:20<00:09, 114.59entry/s]
#
# Extracting entities:  89%|████████▉ | 8938/10000 [01:21<00:09, 114.23entry/s]
#
# Extracting entities:  90%|████████▉ | 8950/10000 [01:21<00:09, 113.73entry/s]
#
# Extracting entities:  90%|████████▉ | 8962/10000 [01:21<00:09, 110.29entry/s]
#
# Extracting entities:  90%|████████▉ | 8974/10000 [01:21<00:09, 111.70entry/s]
#
# Extracting entities:  90%|████████▉ | 8986/10000 [01:21<00:09, 111.50entry/s]
#
# Extracting entities:  90%|████████▉ | 8999/10000 [01:21<00:08, 114.15entry/s]
#
# Extracting entities:  90%|█████████ | 9012/10000 [01:21<00:08, 115.63entry/s]
#
# Extracting entities:  90%|█████████ | 9024/10000 [01:21<00:08, 115.92entry/s]
#
# Extracting entities:  90%|█████████ | 9036/10000 [01:21<00:08, 114.09entry/s]
#
# Extracting entities:  90%|█████████ | 9048/10000 [01:22<00:08, 111.07entry/s]
#
# Extracting entities:  91%|█████████ | 9061/10000 [01:22<00:08, 115.34entry/s]
#
# Extracting entities:  91%|█████████ | 9073/10000 [01:22<00:08, 113.47entry/s]
#
# Extracting entities:  91%|█████████ | 9085/10000 [01:22<00:08, 114.01entry/s]
#
# Extracting entities:  91%|█████████ | 9097/10000 [01:22<00:07, 115.59entry/s]
#
# Extracting entities:  91%|█████████ | 9109/10000 [01:22<00:07, 113.60entry/s]
#
# Extracting entities:  91%|█████████ | 9122/10000 [01:22<00:07, 116.04entry/s]
#
# Extracting entities:  91%|█████████▏| 9134/10000 [01:22<00:07, 111.07entry/s]
#
# Extracting entities:  91%|█████████▏| 9146/10000 [01:22<00:07, 112.28entry/s]
#
# Extracting entities:  92%|█████████▏| 9159/10000 [01:22<00:07, 115.39entry/s]
#
# Extracting entities:  92%|█████████▏| 9171/10000 [01:23<00:07, 114.23entry/s]
#
# Extracting entities:  92%|█████████▏| 9183/10000 [01:23<00:07, 111.93entry/s]
#
# Extracting entities:  92%|█████████▏| 9195/10000 [01:23<00:07, 109.09entry/s]
#
# Extracting entities:  92%|█████████▏| 9207/10000 [01:23<00:07, 111.72entry/s]
#
# Extracting entities:  92%|█████████▏| 9219/10000 [01:23<00:06, 113.12entry/s]
#
# Extracting entities:  92%|█████████▏| 9231/10000 [01:23<00:06, 112.22entry/s]
#
# Extracting entities:  92%|█████████▏| 9243/10000 [01:23<00:06, 114.18entry/s]
#
# Extracting entities:  93%|█████████▎| 9255/10000 [01:23<00:06, 113.24entry/s]
#
# Extracting entities:  93%|█████████▎| 9267/10000 [01:23<00:06, 112.42entry/s]
#
# Extracting entities:  93%|█████████▎| 9279/10000 [01:24<00:06, 112.49entry/s]
#
# Extracting entities:  93%|█████████▎| 9291/10000 [01:24<00:06, 110.20entry/s]
#
# Extracting entities:  93%|█████████▎| 9303/10000 [01:24<00:06, 105.08entry/s]
#
# Extracting entities:  93%|█████████▎| 9315/10000 [01:24<00:06, 108.26entry/s]
#
# Extracting entities:  93%|█████████▎| 9326/10000 [01:24<00:06, 108.56entry/s]
#
# Extracting entities:  93%|█████████▎| 9338/10000 [01:24<00:05, 110.95entry/s]
#
# Extracting entities:  94%|█████████▎| 9351/10000 [01:24<00:05, 114.19entry/s]
#
# Extracting entities:  94%|█████████▎| 9363/10000 [01:24<00:05, 109.08entry/s]
#
# Extracting entities:  94%|█████████▍| 9375/10000 [01:24<00:05, 110.87entry/s]
#
# Extracting entities:  94%|█████████▍| 9387/10000 [01:25<00:05, 110.22entry/s]
#
# Extracting entities:  94%|█████████▍| 9399/10000 [01:25<00:05, 109.57entry/s]
#
# Extracting entities:  94%|█████████▍| 9410/10000 [01:25<00:05, 108.73entry/s]
#
# Extracting entities:  94%|█████████▍| 9422/10000 [01:25<00:05, 110.07entry/s]
#
# Extracting entities:  94%|█████████▍| 9434/10000 [01:25<00:05, 111.00entry/s]
#
# Extracting entities:  94%|█████████▍| 9446/10000 [01:25<00:04, 110.97entry/s]
#
# Extracting entities:  95%|█████████▍| 9458/10000 [01:25<00:04, 109.81entry/s]
#
# Extracting entities:  95%|█████████▍| 9469/10000 [01:25<00:04, 108.58entry/s]
#
# Extracting entities:  95%|█████████▍| 9481/10000 [01:25<00:04, 110.47entry/s]
#
# Extracting entities:  95%|█████████▍| 9493/10000 [01:26<00:04, 112.55entry/s]
#
# Extracting entities:  95%|█████████▌| 9505/10000 [01:26<00:04, 111.32entry/s]
#
# Extracting entities:  95%|█████████▌| 9517/10000 [01:26<00:04, 108.96entry/s]
#
# Extracting entities:  95%|█████████▌| 9528/10000 [01:26<00:04, 105.35entry/s]
#
# Extracting entities:  95%|█████████▌| 9540/10000 [01:26<00:04, 108.80entry/s]
#
# Extracting entities:  96%|█████████▌| 9552/10000 [01:26<00:04, 110.08entry/s]
#
# Extracting entities:  96%|█████████▌| 9564/10000 [01:26<00:03, 111.06entry/s]
#
# Extracting entities:  96%|█████████▌| 9576/10000 [01:26<00:03, 111.36entry/s]
#
# Extracting entities:  96%|█████████▌| 9588/10000 [01:26<00:03, 112.64entry/s]
#
# Extracting entities:  96%|█████████▌| 9600/10000 [01:26<00:03, 113.47entry/s]
#
# Extracting entities:  96%|█████████▌| 9613/10000 [01:27<00:03, 115.41entry/s]
#
# Extracting entities:  96%|█████████▋| 9625/10000 [01:27<00:03, 112.41entry/s]
#
# Extracting entities:  96%|█████████▋| 9637/10000 [01:27<00:03, 113.11entry/s]
#
# Extracting entities:  96%|█████████▋| 9649/10000 [01:27<00:03, 114.21entry/s]
#
# Extracting entities:  97%|█████████▋| 9661/10000 [01:27<00:03, 112.56entry/s]
#
# Extracting entities:  97%|█████████▋| 9673/10000 [01:27<00:02, 113.00entry/s]
#
# Extracting entities:  97%|█████████▋| 9685/10000 [01:27<00:02, 112.44entry/s]
#
# Extracting entities:  97%|█████████▋| 9697/10000 [01:27<00:02, 112.15entry/s]
#
# Extracting entities:  97%|█████████▋| 9709/10000 [01:27<00:02, 112.77entry/s]
#
# Extracting entities:  97%|█████████▋| 9721/10000 [01:28<00:02, 113.17entry/s]
#
# Extracting entities:  97%|█████████▋| 9733/10000 [01:28<00:02, 113.88entry/s]
#
# Extracting entities:  97%|█████████▋| 9745/10000 [01:28<00:02, 109.10entry/s]
#
# Extracting entities:  98%|█████████▊| 9756/10000 [01:28<00:02, 107.98entry/s]
#
# Extracting entities:  98%|█████████▊| 9768/10000 [01:28<00:02, 109.84entry/s]
#
# Extracting entities:  98%|█████████▊| 9780/10000 [01:28<00:01, 111.23entry/s]
#
# Extracting entities:  98%|█████████▊| 9792/10000 [01:28<00:01, 112.48entry/s]
#
# Extracting entities:  98%|█████████▊| 9805/10000 [01:28<00:01, 116.13entry/s]
#
# Extracting entities:  98%|█████████▊| 9817/10000 [01:28<00:01, 114.31entry/s]
#
# Extracting entities:  98%|█████████▊| 9829/10000 [01:29<00:01, 111.76entry/s]
#
# Extracting entities:  98%|█████████▊| 9841/10000 [01:29<00:01, 113.13entry/s]
#
# Extracting entities:  99%|█████████▊| 9854/10000 [01:29<00:01, 117.35entry/s]
#
# Extracting entities:  99%|█████████▊| 9866/10000 [01:29<00:01, 113.06entry/s]
#
# Extracting entities:  99%|█████████▉| 9878/10000 [01:29<00:01, 110.29entry/s]
#
# Extracting entities:  99%|█████████▉| 9890/10000 [01:29<00:00, 110.42entry/s]
#
# Extracting entities:  99%|█████████▉| 9902/10000 [01:29<00:00, 109.50entry/s]
#
# Extracting entities:  99%|█████████▉| 9913/10000 [01:29<00:00, 109.51entry/s]
#
# Extracting entities:  99%|█████████▉| 9924/10000 [01:29<00:00, 108.11entry/s]
#
# Extracting entities:  99%|█████████▉| 9935/10000 [01:29<00:00, 105.16entry/s]
#
# Extracting entities:  99%|█████████▉| 9946/10000 [01:30<00:00, 104.40entry/s]
#
# Extracting entities: 100%|█████████▉| 9957/10000 [01:30<00:00, 103.27entry/s]
#
# Extracting entities: 100%|█████████▉| 9968/10000 [01:30<00:00, 102.49entry/s]
#
# Extracting entities: 100%|█████████▉| 9980/10000 [01:30<00:00, 105.53entry/s]
#
# Extracting entities: 100%|█████████▉| 9991/10000 [01:30<00:00, 105.39entry/s]
#
# Processing rows in twitter: 100%|██████████| 10000/10000 [01:31<00:00, 109.79row/s]
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.sample(1)
# Out:
#       title                                               body   source  \
# 91921   NaN  RT @mercatus: "Regardless of how one feels abo...  twitter
#
#       timestamp  Misinfo_flag type_of_misinfo type_reddit         topic  \
# 91921      None           NaN             NaN         NaN  Polarization
#
#       subtopic                                           entities  \
# 91921     None  {'people': [], 'organizations': [], 'locations...
#
#       Polarization_flag  \tMisinfo_flag type_of_content potential_prompt0  \
# 91921        Republican             NaN            None              None
#
#       hashtags gender
# 91921     None   None

# %%
# prompt: filter gender_abortions to those where is_guote is true

# ... (Your existing code)

# Filter gender_abortions where 'is_quote' is True
abortion_with_quotes = gender_abortions[gender_abortions['is_quote']]

process_and_add_to_global(
    abortion_with_quotes,
    dataset_name="twitter",
    column_mapping={"timestamp": "created_at", "body": "text", 'title':'quoted_text'},
    topic="Abortion",
    additional_columns={
        "hashtags": abortion_with_quotes["hashtags"],
        "gender": abortion_with_quotes["gender"],
        "potential_prompt0": abortion_with_quotes['quoted_text']
    }
)
# Out:
# Processing dataset: twitter
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
# prompt: filter abortion_1 where hashtags are non Nan
abortion_with_quotes
# Out:
#                 created_at                                               text  \
# 50     2018-01-27 15:56:02  You're gonna lose, abortion Ken. https://t.co/...
# 53     2017-11-18 19:47:59  If our Governments vote massive money for weap...
# 79     2017-12-17 21:08:45  It's also a good case for #abortion. https://t...
# 86     2017-11-09 02:34:52  Just imagine how many babies are aborted at th...
# 107    2017-12-19 17:55:07  Easy...they're not really pro-life. https://t....
# ...                    ...                                                ...
# 49795  2018-01-04 20:31:56  "...so should abortion..".\n\nBut here we are....
# 49839  2017-12-17 19:49:37  Abortion is a choice Lee, just like murder, st...
# 49891  2018-02-20 03:03:46  I wonder when @scooterbraun and @justinbieber ...
# 49987  2018-01-27 09:06:02  This is a must read! Nails the Rights take on ...
# 49993  2017-11-18 02:49:30  Lmfaoooo!!!! The "if she don't have kids, she ...
#
#         gender  is_quote                                    hashtags  \
# 50     unknown      True                                         NaN
# 53        male      True                                         NaN
# 79        male      True                                    abortion
# 86      female      True                                     prolife
# 107     female      True                                         NaN
# ...        ...       ...                                         ...
# 49795     male      True                                         NaN
# 49839  unknown      True                                         NaN
# 49891     male      True  PlannedParenthood, MarchForOurLives, fraud
# 49987   female      True                                         NaN
# 49993     male      True                                         NaN
#
#                                              quoted_text
# 50     You gotta see my view! Garland, TX https://t.c...
# 53     Anyone would think these high profile Shinners...
# 79     There was once an orange #fetus who grew into ...
# 86     Born before 22 weeks, 'most premature' baby is...
# 107    Serious question:  how can anyone who identifi...
# ...                                                  ...
# 49795  Campaign Trump: "Marijuana and legalization .....
# 49839  @Maximus_4EVR -Alabama had the highest Infant ...
# 49891  Cameron we heard your call... On March 24, we ...
# 49987  When Slavery Won’t Die: The Oppressive Biblica...
# 49993  People on Facebook mad cuz I said I want my fi...
#
# [1106 rows x 6 columns]

# %% [markdown]
# ## Gender and climate

# %%
gender_climate = pd.read_csv('./Datasets/Gender_bias/gender_climate.csv')

gender_climate = gender_climate.sample(20000)

# %%
gender_climate
# Out:
#                 created_at                                               text  \
# 0      2017-11-01 15:15:14  RT @PPact: Doubling down on health attacks, ex...
# 1      2017-11-03 02:30:37  RT @EmmarKirwan: It's almost 2018 and people s...
# 2      2017-11-03 14:31:31  RT @EmmarKirwan: It's almost 2018 and people s...
# 3      2017-12-17 03:56:30  @AGSchneiderman Republicans are against aborti...
# 4      2018-02-20 05:13:38  RT @RealKyleMorris: How do Democrats expect cr...
# ...                    ...                                                ...
# 49995  2018-01-04 19:08:24  March for Life Chicago 2018 to be Largest Midw...
# 49996  2017-11-03 15:24:58  RT @benwikler: Today, the party that wants to ...
# 49997  2017-11-03 12:40:29  RT @benwikler: Today, the party that wants to ...
# 49998  2017-12-11 17:55:35  RT @SouthernKeeks: I see certain people I resp...
# 49999  2018-01-04 23:06:07  @IronStache @SpeakerRyan Let’s talk about gett...
#
#         gender  is_quote hashtags quoted_text
# 0      unknown     False      NaN         NaN
# 1         male     False      NaN         NaN
# 2      unknown     False      NaN         NaN
# 3       female     False      NaN         NaN
# 4         male     False      NaN         NaN
# ...        ...       ...      ...         ...
# 49995     male     False      NaN         NaN
# 49996   female     False      NaN         NaN
# 49997  unknown     False      NaN         NaN
# 49998  unknown     False      NaN         NaN
# 49999  unknown     False      NaN         NaN
#
# [50000 rows x 6 columns]

# %%
process_and_add_to_global(
    gender_climate,
    dataset_name="twitter",
    column_mapping={"timestamp": "created_at", "body": "text", 'title':'quoted_text'},
    topic="Abortion",
    additional_columns={
        "hashtags": gender_climate["hashtags"],
        "gender": gender_climate["gender"],
        "potential_prompt0": gender_climate['quoted_text']
    }
)
# Out:
# Processing dataset: twitter
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ## All around Climate datasets to balance off the dimensions

# %% [markdown]
# ### Climate change and sentiment

# %%
climate_sentiment = pd.read_csv('./Datasets/Climate_change/twitter_sentiment_data.csv')

# %%
climate_sentiment.shape
# Out:
# (43943, 3)

# %%
climate_sentiment = climate_sentiment.sample(20000)

# %%
climate_sentiment.head()
# Out:
#        sentiment                                            message  \
# 2955           1  RT @Oxfam: Last year, 190+ countries signed th...
# 31636          1  RT @OMGno2trump: Hey #MAGA, think about this. ...
# 39268          1  Cop21 in Paris: Commit to climate change and P...
# 35150          1  RT @NGO_Reporting: What are the implications o...
# 3757           1  The #ParisAgreement enters into force! Learn m...
#
#                   tweetid
# 2955   796476782216146945
# 31636  959541827551428609
# 39268  667895923876343808
# 35150  957251467466829824
# 3757   797018604046843904

# %%
# prompt: recode sentiment column 2(News): the tweet links to factual news about climate change
# 1(Pro): the tweet supports the belief of man-made climate change
# 0(Neutral: the tweet neither supports nor refutes the belief of man-made climate change
# -1(Anti): the tweet does not believe in man-made climate change

def recode_sentiment(sentiment):
    if sentiment == 2:
        return "News"  # Assuming 2 represents factual news
    elif sentiment == 1:
        return "Pro"
    elif sentiment == 0:
        return "Neutral"
    elif sentiment == -1:
        return "Anti"
    else:
        return "Unknown"  # Handle cases with unexpected sentiment values

# Apply the function to the 'sentiment' column
climate_sentiment['sentiment_category'] = climate_sentiment['sentiment'].apply(recode_sentiment)

# %%
climate_sentiment.head()
# Out:
#        sentiment                                            message  \
# 2955           1  RT @Oxfam: Last year, 190+ countries signed th...
# 31636          1  RT @OMGno2trump: Hey #MAGA, think about this. ...
# 39268          1  Cop21 in Paris: Commit to climate change and P...
# 35150          1  RT @NGO_Reporting: What are the implications o...
# 3757           1  The #ParisAgreement enters into force! Learn m...
#
#                   tweetid sentiment_category
# 2955   796476782216146945                Pro
# 31636  959541827551428609                Pro
# 39268  667895923876343808                Pro
# 35150  957251467466829824                Pro
# 3757   797018604046843904                Pro

# %%
global_df.head(1)
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
#
#    subtopic entities Polarization_flag  \tMisinfo_flag type_of_content  \
# 0  Vaccines      NaN               NaN             NaN             NaN
#
#   potential_prompt0 hashtags gender
# 0               NaN      NaN    NaN

# %%
process_and_add_to_global(
    climate_sentiment,
    dataset_name="twitter",
    column_mapping={ "body": "message"},
    topic="Climate Change",
    additional_columns={
        "sentiment_category": climate_sentiment['sentiment_category']
    }
)
# Out:
# Processing dataset: twitter
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ## climate reddit data
# https://www.kaggle.com/datasets/pavellexyr/the-reddit-climate-change-dataset?select=the-reddit-climate-change-dataset-comments.csv
#
# ## Normal news about climate
# https://www.kaggle.com/datasets/beridzeg45/guardian-environment-related-news

# %%
## get more data here

reddit_climate =

# %%
normal_climate = pd.read_csv('./Datasets/Climate_change/guardian_environment_news.csv')

# %%
normal_climate = normal_climate.sample(10000)

# %%
process_and_add_to_global(
    normal_climate,
    dataset_name="news",
    column_mapping={"title":"Title",
                    "body":"Article Text",
                    "timestamp":'Date Published'},
    topic="Climate Change",
    additional_columns={
        'subtitle': normal_climate['Intro Text']
    }
)
# Out:
# Processing dataset: news
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ## Datasets on abortions different news
#
# https://www.kaggle.com/datasets/mcantoni81/twitter-supervised-dataset-prochoice-vs-prolife
#
# answer to roe v vade. https://www.kaggle.com/datasets/hamiltonwhite/twitter-response-to-roe-v-wade-scotus

# %% [markdown]
# ## pro choice vs pro-life

# %%
pro_choice = pd.read_csv('./Datasets/prochoice_prolife.csv')

# %%
pro_choice = pro_choice.sample(10000)
process_and_add_to_global(
    pro_choice,
    dataset_name="twitter",
    column_mapping={
                    "body":"text",
                    "timestamp":'created_at'},
    topic="Abortion",
    additional_columns={
        'prochoice_prolife': pro_choice['target'].map({0:'prochoice',1:'prolife'})
    }
)
# Out:
# Processing dataset: twitter
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ### Baseline News and News with titles

# %% [markdown]
# ## Political Emails

# %%
global_df.shape
# Out:
# (92983, 12)

# %%
##
political_emails = pd.read_csv('./Datasets/political-emails.csv')

# %%
political_emails.head()
# Out:
#    Unnamed: 0                  sender_name                    email  \
# 0           0    Indiana Republican Party          info@indiana.gop
# 1           1                         DWS   info@dwsforcongress.com
# 2           2  midnight-deadline@dscc.org             info@dscc.org
# 3           3             Hillary Clinton         info@timkaine.com
# 4           4                   Team Ryan      info@speakerryan.com
#
#                                              subject             datetime  \
# 0  Next Level Roads / Congress of Counties Survey...  2017-07-14 13:17:52
# 1            Time to turn up the heat on Republicans  2017-07-14 12:04:50
# 2        Your impact QUADRUPLED (limited time only!)  2017-09-30 15:57:03
# 3                                  Will you join me?  2017-09-29 10:46:22
# 4                  Do you live paycheck to paycheck?  2017-10-10 16:31:15
#
#                                      cleaned_content
# 0  Next Level Roads / Congress of Counties Survey...
# 1  I know it's Friday, friends.But before you hea...
# 2  Time is almost up...deadline: MIDNIGHT!Pitch i...
# 3  Kaine for VirginiaWhen I was running for presi...
# 4    Friend,Do you live paycheck to paycheck? It'...

# %%
political_emails.shape
# Out:
# (86517, 6)

# %%
political_emails = political_emails.sample(10000)

process_and_add_to_global(
    political_emails,
    dataset_name="political emails",
    column_mapping={"title": "subject",'timestamp':'datetime','body':'cleaned_content'},
    topic="Polarization",

    additional_columns={

        'type_of_content': 'political email',
        'potential_prompt0': (political_emails['sender_name']+ ": " + political_emails['subject'])


    }
)
# Out:
# Processing dataset: political emails
# Processing rows in political emails:   0%|          | 0/10000 [00:00<?, ?row/s]
# Extracting entities:   0%|          | 0/10000 [00:00<?, ?entry/s]
# Extracting entities:   0%|          | 2/10000 [00:00<09:44, 17.11entry/s]
# Extracting entities:   0%|          | 5/10000 [00:00<08:30, 19.58entry/s]
# Extracting entities:   0%|          | 7/10000 [00:00<09:24, 17.71entry/s]
# Extracting entities:   0%|          | 9/10000 [00:00<09:57, 16.71entry/s]
# Extracting entities:   0%|          | 12/10000 [00:00<08:36, 19.34entry/s]
# Extracting entities:   0%|          | 14/10000 [00:00<12:47, 13.01entry/s]
# Extracting entities:   0%|          | 16/10000 [00:01<11:34, 14.37entry/s]
# Extracting entities:   0%|          | 18/10000 [00:01<11:27, 14.51entry/s]
# Extracting entities:   0%|          | 20/10000 [00:01<11:04, 15.01entry/s]
# Extracting entities:   0%|          | 22/10000 [00:01<13:30, 12.31entry/s]
# Extracting entities:   0%|          | 25/10000 [00:01<11:53, 13.98entry/s]
# Extracting entities:   0%|          | 28/10000 [00:01<09:51, 16.86entry/s]
# Extracting entities:   0%|          | 30/10000 [00:01<10:07, 16.41entry/s]
# Extracting entities:   0%|          | 32/10000 [00:02<09:52, 16.83entry/s]
# Extracting entities:   0%|          | 34/10000 [00:02<10:10, 16.32entry/s]
# Extracting entities:   0%|          | 36/10000 [00:02<10:44, 15.47entry/s]
# Extracting entities:   0%|          | 38/10000 [00:02<11:44, 14.15entry/s]
# Extracting entities:   0%|          | 40/10000 [00:02<12:49, 12.94entry/s]
# Extracting entities:   0%|          | 42/10000 [00:02<15:15, 10.88entry/s]
# Extracting entities:   0%|          | 45/10000 [00:03<12:18, 13.48entry/s]
# Extracting entities:   0%|          | 48/10000 [00:03<12:17, 13.49entry/s]
# Extracting entities:   1%|          | 51/10000 [00:03<10:51, 15.27entry/s]
# Extracting entities:   1%|          | 54/10000 [00:03<09:45, 16.98entry/s]
# Extracting entities:   1%|          | 56/10000 [00:03<09:51, 16.82entry/s]
# Extracting entities:   1%|          | 58/10000 [00:03<09:27, 17.50entry/s]
# Extracting entities:   1%|          | 61/10000 [00:03<08:10, 20.26entry/s]
# Extracting entities:   1%|          | 64/10000 [00:04<10:12, 16.22entry/s]
# Extracting entities:   1%|          | 67/10000 [00:04<09:13, 17.96entry/s]
# Extracting entities:   1%|          | 69/10000 [00:04<09:13, 17.95entry/s]
# Extracting entities:   1%|          | 73/10000 [00:04<09:44, 16.97entry/s]
# Extracting entities:   1%|          | 75/10000 [00:04<09:41, 17.07entry/s]
# Extracting entities:   1%|          | 77/10000 [00:04<09:47, 16.90entry/s]
# Extracting entities:   1%|          | 79/10000 [00:05<10:06, 16.36entry/s]
# Extracting entities:   1%|          | 81/10000 [00:05<09:39, 17.11entry/s]
# Extracting entities:   1%|          | 83/10000 [00:05<11:18, 14.62entry/s]
# Extracting entities:   1%|          | 85/10000 [00:05<10:54, 15.14entry/s]
# Extracting entities:   1%|          | 87/10000 [00:05<15:35, 10.60entry/s]
# Extracting entities:   1%|          | 89/10000 [00:05<15:11, 10.87entry/s]
# Extracting entities:   1%|          | 91/10000 [00:06<15:00, 11.00entry/s]
# Extracting entities:   1%|          | 94/10000 [00:06<12:39, 13.04entry/s]
# Extracting entities:   1%|          | 96/10000 [00:06<11:47, 14.01entry/s]
# Extracting entities:   1%|          | 98/10000 [00:06<12:20, 13.37entry/s]
# Extracting entities:   1%|          | 101/10000 [00:06<10:21, 15.92entry/s]
# Extracting entities:   1%|          | 103/10000 [00:06<10:30, 15.70entry/s]
# Extracting entities:   1%|          | 105/10000 [00:07<14:02, 11.74entry/s]
# Extracting entities:   1%|          | 108/10000 [00:07<14:43, 11.20entry/s]
# Extracting entities:   1%|          | 111/10000 [00:07<12:11, 13.51entry/s]
# Extracting entities:   1%|          | 113/10000 [00:07<11:28, 14.36entry/s]
# Extracting entities:   1%|          | 115/10000 [00:07<11:41, 14.09entry/s]
# Extracting entities:   1%|          | 117/10000 [00:07<11:27, 14.38entry/s]
# Extracting entities:   1%|          | 120/10000 [00:08<09:43, 16.94entry/s]
# Extracting entities:   1%|          | 123/10000 [00:08<08:38, 19.05entry/s]
# Extracting entities:   1%|▏         | 126/10000 [00:08<08:12, 20.04entry/s]
# Extracting entities:   1%|▏         | 129/10000 [00:08<08:20, 19.70entry/s]
# Extracting entities:   1%|▏         | 132/10000 [00:08<09:41, 16.98entry/s]
# Extracting entities:   1%|▏         | 134/10000 [00:08<10:58, 14.98entry/s]
# Extracting entities:   1%|▏         | 137/10000 [00:08<09:23, 17.50entry/s]
# Extracting entities:   1%|▏         | 140/10000 [00:09<08:17, 19.84entry/s]
# Extracting entities:   1%|▏         | 143/10000 [00:09<09:41, 16.95entry/s]
# Extracting entities:   1%|▏         | 145/10000 [00:09<12:48, 12.82entry/s]
# Extracting entities:   1%|▏         | 147/10000 [00:09<12:17, 13.36entry/s]
# Extracting entities:   1%|▏         | 149/10000 [00:09<12:00, 13.68entry/s]
# Extracting entities:   2%|▏         | 151/10000 [00:09<11:00, 14.90entry/s]
# Extracting entities:   2%|▏         | 153/10000 [00:10<10:25, 15.73entry/s]
# Extracting entities:   2%|▏         | 155/10000 [00:10<09:48, 16.72entry/s]
# Extracting entities:   2%|▏         | 157/10000 [00:10<10:16, 15.97entry/s]
# Extracting entities:   2%|▏         | 159/10000 [00:10<10:22, 15.81entry/s]
# Extracting entities:   2%|▏         | 162/10000 [00:10<09:06, 18.02entry/s]
# Extracting entities:   2%|▏         | 164/10000 [00:10<09:16, 17.67entry/s]
# Extracting entities:   2%|▏         | 166/10000 [00:10<11:53, 13.78entry/s]
# Extracting entities:   2%|▏         | 169/10000 [00:11<10:28, 15.65entry/s]
# Extracting entities:   2%|▏         | 172/10000 [00:11<09:47, 16.74entry/s]
# Extracting entities:   2%|▏         | 174/10000 [00:11<09:33, 17.14entry/s]
# Extracting entities:   2%|▏         | 176/10000 [00:11<15:38, 10.47entry/s]
# Extracting entities:   2%|▏         | 178/10000 [00:11<16:05, 10.18entry/s]
# Extracting entities:   2%|▏         | 181/10000 [00:12<19:02,  8.60entry/s]
# Extracting entities:   2%|▏         | 183/10000 [00:12<16:31,  9.90entry/s]
# Extracting entities:   2%|▏         | 185/10000 [00:12<15:45, 10.38entry/s]
# Extracting entities:   2%|▏         | 187/10000 [00:12<16:05, 10.17entry/s]
# Extracting entities:   2%|▏         | 189/10000 [00:12<13:56, 11.73entry/s]
# Extracting entities:   2%|▏         | 191/10000 [00:13<14:03, 11.63entry/s]
# Extracting entities:   2%|▏         | 193/10000 [00:13<12:37, 12.95entry/s]
# Extracting entities:   2%|▏         | 195/10000 [00:13<13:55, 11.74entry/s]
# Extracting entities:   2%|▏         | 197/10000 [00:13<12:58, 12.60entry/s]
# Extracting entities:   2%|▏         | 199/10000 [00:13<12:19, 13.25entry/s]
# Extracting entities:   2%|▏         | 202/10000 [00:13<10:00, 16.31entry/s]
# Extracting entities:   2%|▏         | 204/10000 [00:13<10:00, 16.32entry/s]
# Extracting entities:   2%|▏         | 206/10000 [00:14<09:35, 17.02entry/s]
# Extracting entities:   2%|▏         | 208/10000 [00:14<10:49, 15.07entry/s]
# Extracting entities:   2%|▏         | 210/10000 [00:14<12:39, 12.90entry/s]
# Extracting entities:   2%|▏         | 212/10000 [00:14<17:26,  9.36entry/s]
# Extracting entities:   2%|▏         | 214/10000 [00:14<15:33, 10.48entry/s]
# Extracting entities:   2%|▏         | 216/10000 [00:15<13:45, 11.86entry/s]
# Extracting entities:   2%|▏         | 219/10000 [00:15<12:20, 13.20entry/s]
# Extracting entities:   2%|▏         | 221/10000 [00:15<14:41, 11.10entry/s]
# Extracting entities:   2%|▏         | 224/10000 [00:15<11:42, 13.92entry/s]
# Extracting entities:   2%|▏         | 227/10000 [00:15<10:25, 15.63entry/s]
# Extracting entities:   2%|▏         | 230/10000 [00:15<09:49, 16.58entry/s]
# Extracting entities:   2%|▏         | 234/10000 [00:16<08:32, 19.04entry/s]
# Extracting entities:   2%|▏         | 237/10000 [00:16<07:49, 20.78entry/s]
# Extracting entities:   2%|▏         | 240/10000 [00:16<10:47, 15.06entry/s]
# Extracting entities:   2%|▏         | 243/10000 [00:16<11:45, 13.83entry/s]
# Extracting entities:   2%|▏         | 245/10000 [00:17<13:14, 12.28entry/s]
# Extracting entities:   2%|▏         | 247/10000 [00:17<12:09, 13.37entry/s]
# Extracting entities:   2%|▏         | 249/10000 [00:17<11:37, 13.98entry/s]
# Extracting entities:   3%|▎         | 251/10000 [00:17<12:57, 12.54entry/s]
# Extracting entities:   3%|▎         | 253/10000 [00:17<14:12, 11.44entry/s]
# Extracting entities:   3%|▎         | 255/10000 [00:17<13:50, 11.73entry/s]
# Extracting entities:   3%|▎         | 257/10000 [00:17<12:20, 13.16entry/s]
# Extracting entities:   3%|▎         | 259/10000 [00:18<15:50, 10.25entry/s]
# Extracting entities:   4%|▎         | 350/10000 [00:24<10:20, 15.55entry/s]
# Extracting entities:   4%|▎         | 352/10000 [00:24<09:56, 16.19entry/s]
# Extracting entities:   4%|▎         | 354/10000 [00:24<09:39, 16.65entry/s]
# Extracting entities:   4%|▎         | 356/10000 [00:24<09:35, 16.76entry/s]
# Extracting entities:   4%|▎         | 358/10000 [00:24<10:12, 15.75entry/s]
# Extracting entities:   4%|▎         | 360/10000 [00:24<12:22, 12.98entry/s]
# Extracting entities:   4%|▎         | 363/10000 [00:25<10:54, 14.72entry/s]
# Extracting entities:   4%|▎         | 365/10000 [00:25<10:44, 14.95entry/s]
# Extracting entities:   4%|▎         | 367/10000 [00:25<10:13, 15.70entry/s]
# Extracting entities:   4%|▎         | 371/10000 [00:25<07:59, 20.10entry/s]
# Extracting entities:   4%|▎         | 374/10000 [00:25<09:18, 17.24entry/s]
# Extracting entities:   4%|▍         | 377/10000 [00:25<08:49, 18.17entry/s]
# Extracting entities:   4%|▍         | 380/10000 [00:25<08:33, 18.75entry/s]
# Extracting entities:   4%|▍         | 382/10000 [00:26<08:58, 17.87entry/s]
# Extracting entities:   4%|▍         | 384/10000 [00:26<09:06, 17.60entry/s]
# Extracting entities:   4%|▍         | 386/10000 [00:26<10:09, 15.77entry/s]
# Extracting entities:   4%|▍         | 388/10000 [00:26<09:49, 16.31entry/s]
# Extracting entities:   4%|▍         | 391/10000 [00:26<11:54, 13.45entry/s]
# Extracting entities:   4%|▍         | 393/10000 [00:27<13:25, 11.93entry/s]
# Extracting entities:   4%|▍         | 395/10000 [00:27<15:09, 10.56entry/s]
# Extracting entities:   4%|▍         | 398/10000 [00:27<11:59, 13.35entry/s]
# Extracting entities:   4%|▍         | 400/10000 [00:27<11:52, 13.48entry/s]
# Extracting entities:   4%|▍         | 402/10000 [00:27<11:34, 13.81entry/s]
# Extracting entities:   4%|▍         | 404/10000 [00:27<11:14, 14.22entry/s]
# Extracting entities:   4%|▍         | 406/10000 [00:27<11:12, 14.26entry/s]
# Extracting entities:   4%|▍         | 408/10000 [00:28<10:22, 15.40entry/s]
# Extracting entities:   4%|▍         | 410/10000 [00:28<12:58, 12.32entry/s]
# Extracting entities:   4%|▍         | 412/10000 [00:28<11:58, 13.35entry/s]
# Extracting entities:   4%|▍         | 414/10000 [00:28<10:52, 14.70entry/s]
# Extracting entities:   4%|▍         | 416/10000 [00:28<12:07, 13.18entry/s]
# Extracting entities:   4%|▍         | 418/10000 [00:28<11:41, 13.65entry/s]
# Extracting entities:   4%|▍         | 420/10000 [00:28<10:39, 14.98entry/s]
# Extracting entities:   4%|▍         | 423/10000 [00:29<09:21, 17.07entry/s]
# Extracting entities:   4%|▍         | 426/10000 [00:29<09:58, 16.01entry/s]
# Extracting entities:   4%|▍         | 428/10000 [00:29<09:37, 16.58entry/s]
# Extracting entities:   4%|▍         | 430/10000 [00:29<09:54, 16.09entry/s]
# Extracting entities:   4%|▍         | 433/10000 [00:29<08:30, 18.73entry/s]
# Extracting entities:   4%|▍         | 437/10000 [00:29<08:50, 18.03entry/s]
# Extracting entities:   4%|▍         | 440/10000 [00:30<08:21, 19.05entry/s]
# Extracting entities:   4%|▍         | 442/10000 [00:30<10:24, 15.30entry/s]
# Extracting entities:   4%|▍         | 444/10000 [00:30<12:17, 12.96entry/s]
# Extracting entities:   4%|▍         | 446/10000 [00:30<14:30, 10.97entry/s]
# Extracting entities:   4%|▍         | 448/10000 [00:30<13:08, 12.11entry/s]
# Extracting entities:   4%|▍         | 450/10000 [00:31<13:42, 11.62entry/s]
# Extracting entities:   5%|▍         | 452/10000 [00:31<12:33, 12.67entry/s]
# Extracting entities:   5%|▍         | 454/10000 [00:31<12:27, 12.77entry/s]
# Extracting entities:   5%|▍         | 456/10000 [00:31<13:50, 11.49entry/s]
# Extracting entities:   5%|▍         | 459/10000 [00:31<10:41, 14.88entry/s]
# Extracting entities:   5%|▍         | 462/10000 [00:31<10:51, 14.64entry/s]
# Extracting entities:   5%|▍         | 464/10000 [00:32<11:32, 13.76entry/s]
# Extracting entities:   5%|▍         | 466/10000 [00:32<13:09, 12.08entry/s]
# Extracting entities:   5%|▍         | 468/10000 [00:32<12:19, 12.89entry/s]
# Extracting entities:   5%|▍         | 470/10000 [00:32<11:29, 13.81entry/s]
# Extracting entities:   5%|▍         | 472/10000 [00:32<13:51, 11.46entry/s]
# Extracting entities:   5%|▍         | 475/10000 [00:32<12:17, 12.92entry/s]
# Extracting entities:   5%|▍         | 477/10000 [00:33<11:29, 13.82entry/s]
# Extracting entities:   5%|▍         | 480/10000 [00:33<10:01, 15.83entry/s]
# Extracting entities:   5%|▍         | 482/10000 [00:33<09:50, 16.11entry/s]
# Extracting entities:   5%|▍         | 484/10000 [00:33<10:52, 14.59entry/s]
# Extracting entities:   5%|▍         | 486/10000 [00:33<14:21, 11.05entry/s]
# Extracting entities:   5%|▍         | 488/10000 [00:33<13:20, 11.88entry/s]
# Extracting entities:   5%|▍         | 490/10000 [00:34<13:14, 11.97entry/s]
# Extracting entities:   5%|▍         | 492/10000 [00:34<14:29, 10.94entry/s]
# Extracting entities:   5%|▍         | 495/10000 [00:34<12:36, 12.56entry/s]
# Extracting entities:   5%|▍         | 498/10000 [00:34<11:27, 13.83entry/s]
# Extracting entities:   5%|▌         | 500/10000 [00:34<12:00, 13.19entry/s]
# Extracting entities:   5%|▌         | 502/10000 [00:34<11:49, 13.38entry/s]
# Extracting entities:   5%|▌         | 504/10000 [00:35<11:17, 14.01entry/s]
# Extracting entities:   5%|▌         | 506/10000 [00:35<12:30, 12.65entry/s]
# Extracting entities:   5%|▌         | 508/10000 [00:35<12:07, 13.04entry/s]
# Extracting entities:   5%|▌         | 511/10000 [00:35<10:05, 15.66entry/s]
# Extracting entities:   5%|▌         | 513/10000 [00:35<10:03, 15.72entry/s]
# Extracting entities:   5%|▌         | 515/10000 [00:35<11:02, 14.32entry/s]
# Extracting entities:   5%|▌         | 517/10000 [00:35<11:17, 14.00entry/s]
# Extracting entities:   5%|▌         | 520/10000 [00:36<10:15, 15.39entry/s]
# Extracting entities:   5%|▌         | 523/10000 [00:36<09:12, 17.14entry/s]
# Extracting entities:   5%|▌         | 526/10000 [00:36<09:04, 17.38entry/s]
# Extracting entities:   5%|▌         | 529/10000 [00:36<10:19, 15.28entry/s]
# Extracting entities:   5%|▌         | 532/10000 [00:36<09:16, 17.00entry/s]
# Extracting entities:   5%|▌         | 535/10000 [00:36<08:25, 18.72entry/s]
# Extracting entities:   5%|▌         | 537/10000 [00:37<08:19, 18.95entry/s]
# Extracting entities:   5%|▌         | 539/10000 [00:37<09:14, 17.07entry/s]
# Extracting entities:   5%|▌         | 541/10000 [00:37<09:33, 16.50entry/s]
# Extracting entities:   5%|▌         | 544/10000 [00:37<08:38, 18.23entry/s]
# Extracting entities:   5%|▌         | 547/10000 [00:37<08:01, 19.63entry/s]
# Extracting entities:   6%|▌         | 550/10000 [00:37<08:00, 19.65entry/s]
# Extracting entities:   6%|▌         | 553/10000 [00:37<08:40, 18.15entry/s]
# Extracting entities:   6%|▌         | 555/10000 [00:38<08:55, 17.65entry/s]
# Extracting entities:   6%|▌         | 557/10000 [00:38<08:46, 17.92entry/s]
# Extracting entities:   6%|▌         | 559/10000 [00:38<12:04, 13.04entry/s]
# Extracting entities:   6%|▌         | 562/10000 [00:38<11:45, 13.37entry/s]
# Extracting entities:   6%|▌         | 564/10000 [00:38<13:59, 11.24entry/s]
# Extracting entities:   6%|▌         | 567/10000 [00:39<12:00, 13.09entry/s]
# Extracting entities:   6%|▌         | 569/10000 [00:39<13:14, 11.86entry/s]
# Extracting entities:   6%|▌         | 572/10000 [00:39<11:13, 14.01entry/s]
# Extracting entities:   6%|▌         | 575/10000 [00:39<09:27, 16.61entry/s]
# Extracting entities:   6%|▌         | 577/10000 [00:39<09:59, 15.72entry/s]
# Extracting entities:   6%|▌         | 580/10000 [00:39<11:11, 14.03entry/s]
# Extracting entities:   6%|▌         | 582/10000 [00:40<15:26, 10.16entry/s]
# Extracting entities:   6%|▌         | 584/10000 [00:40<15:52,  9.89entry/s]
# Extracting entities:   6%|▌         | 586/10000 [00:40<14:57, 10.49entry/s]
# Extracting entities:   6%|▌         | 589/10000 [00:40<11:36, 13.52entry/s]
# Extracting entities:   6%|▌         | 591/10000 [00:40<11:55, 13.16entry/s]
# Extracting entities:   6%|▌         | 593/10000 [00:41<11:35, 13.53entry/s]
# Extracting entities:   6%|▌         | 595/10000 [00:41<12:49, 12.22entry/s]
# Extracting entities:   6%|▌         | 598/10000 [00:41<11:49, 13.25entry/s]
# Extracting entities:   6%|▌         | 600/10000 [00:41<11:30, 13.62entry/s]
# Extracting entities:   6%|▌         | 603/10000 [00:41<09:34, 16.36entry/s]
# Extracting entities:   6%|▌         | 605/10000 [00:42<12:31, 12.49entry/s]
# Extracting entities:   6%|▌         | 607/10000 [00:42<11:21, 13.79entry/s]
# Extracting entities:   6%|▌         | 609/10000 [00:42<11:25, 13.69entry/s]
# Extracting entities:   6%|▌         | 611/10000 [00:42<11:23, 13.73entry/s]
# Extracting entities:   6%|▌         | 613/10000 [00:42<15:42,  9.96entry/s]
# Extracting entities:   6%|▌         | 616/10000 [00:42<12:30, 12.51entry/s]
# Extracting entities:   6%|▌         | 618/10000 [00:43<11:29, 13.62entry/s]
# Extracting entities:   6%|▌         | 620/10000 [00:43<11:24, 13.71entry/s]
# Extracting entities:   6%|▌         | 623/10000 [00:43<10:22, 15.07entry/s]
# Extracting entities:   6%|▋         | 625/10000 [00:43<09:54, 15.76entry/s]
# Extracting entities:   6%|▋         | 627/10000 [00:43<10:01, 15.57entry/s]
# Extracting entities:   6%|▋         | 629/10000 [00:43<09:42, 16.09entry/s]
# Extracting entities:   6%|▋         | 631/10000 [00:43<12:38, 12.36entry/s]
# Extracting entities:   6%|▋         | 633/10000 [00:44<11:23, 13.71entry/s]
# Extracting entities:   6%|▋         | 635/10000 [00:44<12:17, 12.71entry/s]
# Extracting entities:   6%|▋         | 638/10000 [00:44<10:38, 14.65entry/s]
# Extracting entities:   6%|▋         | 640/10000 [00:44<12:18, 12.68entry/s]
# Extracting entities:   6%|▋         | 642/10000 [00:44<11:30, 13.55entry/s]
# Extracting entities:   6%|▋         | 645/10000 [00:44<11:52, 13.13entry/s]
# Extracting entities:   6%|▋         | 647/10000 [00:45<14:07, 11.04entry/s]
# Extracting entities:   6%|▋         | 649/10000 [00:45<19:15,  8.09entry/s]
# Extracting entities:   7%|▋         | 652/10000 [00:45<16:54,  9.21entry/s]
# Extracting entities:   7%|▋         | 654/10000 [00:46<14:40, 10.61entry/s]
# Extracting entities:   7%|▋         | 656/10000 [00:46<15:16, 10.19entry/s]
# Extracting entities:   7%|▋         | 659/10000 [00:46<11:36, 13.41entry/s]
# Extracting entities:   7%|▋         | 661/10000 [00:46<10:41, 14.56entry/s]
# Extracting entities:   7%|▋         | 663/10000 [00:46<11:08, 13.97entry/s]
# Extracting entities:   7%|▋         | 666/10000 [00:46<09:22, 16.58entry/s]
# Extracting entities:   7%|▋         | 668/10000 [00:46<11:13, 13.85entry/s]
# Extracting entities:   7%|▋         | 670/10000 [00:47<10:22, 14.98entry/s]
# Extracting entities:   7%|▋         | 672/10000 [00:47<09:47, 15.89entry/s]
# Extracting entities:   7%|▋         | 674/10000 [00:47<09:42, 16.00entry/s]
# Extracting entities:   7%|▋         | 676/10000 [00:47<10:12, 15.23entry/s]
# Extracting entities:   7%|▋         | 680/10000 [00:47<08:37, 18.00entry/s]
# Extracting entities:   7%|▋         | 682/10000 [00:47<11:24, 13.62entry/s]
# Extracting entities:   7%|▋         | 685/10000 [00:47<09:44, 15.95entry/s]
# Extracting entities:   7%|▋         | 687/10000 [00:48<11:31, 13.47entry/s]
# Extracting entities:   7%|▋         | 689/10000 [00:48<10:40, 14.53entry/s]
# Extracting entities:   7%|▋         | 691/10000 [00:48<12:50, 12.09entry/s]
# Extracting entities:   7%|▋         | 693/10000 [00:48<12:15, 12.66entry/s]
# Extracting entities:   7%|▋         | 695/10000 [00:48<11:29, 13.50entry/s]
# Extracting entities:   7%|▋         | 697/10000 [00:48<11:23, 13.60entry/s]
# Extracting entities:   7%|▋         | 699/10000 [00:49<11:08, 13.91entry/s]
# Extracting entities:   7%|▋         | 702/10000 [00:49<09:45, 15.88entry/s]
# Extracting entities:   7%|▋         | 704/10000 [00:49<10:06, 15.34entry/s]
# Extracting entities:   7%|▋         | 706/10000 [00:49<10:51, 14.27entry/s]
# Extracting entities:   7%|▋         | 708/10000 [00:49<11:33, 13.39entry/s]
# Extracting entities:   7%|▋         | 711/10000 [00:49<10:08, 15.26entry/s]
# Extracting entities:   7%|▋         | 713/10000 [00:49<09:50, 15.73entry/s]
# Extracting entities:   7%|▋         | 716/10000 [00:50<09:29, 16.30entry/s]
# Extracting entities:   7%|▋         | 718/10000 [00:50<12:11, 12.69entry/s]
# Extracting entities:   7%|▋         | 720/10000 [00:50<11:54, 12.99entry/s]
# Extracting entities:   7%|▋         | 722/10000 [00:50<11:37, 13.30entry/s]
# Extracting entities:   7%|▋         | 724/10000 [00:50<11:09, 13.86entry/s]
# Extracting entities:   7%|▋         | 726/10000 [00:51<12:29, 12.37entry/s]
# Extracting entities:   7%|▋         | 728/10000 [00:51<11:39, 13.25entry/s]
# Extracting entities:   7%|▋         | 730/10000 [00:51<11:26, 13.50entry/s]
# Extracting entities:   7%|▋         | 733/10000 [00:51<10:31, 14.67entry/s]
# Extracting entities:   7%|▋         | 735/10000 [00:51<10:05, 15.30entry/s]
# Extracting entities:   7%|▋         | 737/10000 [00:51<10:26, 14.79entry/s]
# Extracting entities:   7%|▋         | 739/10000 [00:51<11:02, 13.98entry/s]
# Extracting entities:   7%|▋         | 741/10000 [00:52<11:49, 13.05entry/s]
# Extracting entities:   7%|▋         | 743/10000 [00:52<11:18, 13.63entry/s]
# Extracting entities:   7%|▋         | 745/10000 [00:52<10:48, 14.28entry/s]
# Extracting entities:   7%|▋         | 747/10000 [00:52<10:07, 15.23entry/s]
# Extracting entities:   7%|▋         | 749/10000 [00:52<09:45, 15.79entry/s]
# Extracting entities:   8%|▊         | 751/10000 [00:52<11:37, 13.26entry/s]
# Extracting entities:   8%|▊         | 753/10000 [00:52<11:25, 13.50entry/s]
# Extracting entities:   8%|▊         | 755/10000 [00:53<10:30, 14.66entry/s]
# Extracting entities:   8%|▊         | 757/10000 [00:53<11:13, 13.72entry/s]
# Extracting entities:   8%|▊         | 759/10000 [00:53<10:26, 14.74entry/s]
# Extracting entities:   8%|▊         | 761/10000 [00:53<10:49, 14.22entry/s]
# Extracting entities:   8%|▊         | 763/10000 [00:53<10:47, 14.25entry/s]
# Extracting entities:   8%|▊         | 765/10000 [00:53<11:09, 13.79entry/s]
# Extracting entities:   8%|▊         | 767/10000 [00:53<13:15, 11.60entry/s]
# Extracting entities:   8%|▊         | 770/10000 [00:54<10:34, 14.55entry/s]
# Extracting entities:   8%|▊         | 773/10000 [00:54<09:02, 17.01entry/s]
# Extracting entities:   8%|▊         | 775/10000 [00:54<11:36, 13.24entry/s]
# Extracting entities:   8%|▊         | 777/10000 [00:54<10:45, 14.29entry/s]
# Extracting entities:   8%|▊         | 780/10000 [00:54<09:18, 16.50entry/s]
# Extracting entities:   8%|▊         | 782/10000 [00:54<12:20, 12.45entry/s]
# Extracting entities:   8%|▊         | 784/10000 [00:55<11:08, 13.79entry/s]
# Extracting entities:   8%|▊         | 787/10000 [00:55<09:32, 16.08entry/s]
# Extracting entities:   8%|▊         | 789/10000 [00:55<09:07, 16.83entry/s]
# Extracting entities:   8%|▊         | 791/10000 [00:55<08:54, 17.22entry/s]
# Extracting entities:   8%|▊         | 794/10000 [00:55<10:38, 14.42entry/s]
# Extracting entities:   8%|▊         | 797/10000 [00:55<09:20, 16.43entry/s]
# Extracting entities:   8%|▊         | 800/10000 [00:55<08:30, 18.01entry/s]
# Extracting entities:   8%|▊         | 803/10000 [00:56<07:44, 19.81entry/s]
# Extracting entities:   8%|▊         | 806/10000 [00:56<09:31, 16.09entry/s]
# Extracting entities:   8%|▊         | 808/10000 [00:56<11:09, 13.72entry/s]
# Extracting entities:   8%|▊         | 811/10000 [00:56<09:26, 16.23entry/s]
# Extracting entities:   8%|▊         | 813/10000 [00:56<09:22, 16.32entry/s]
# Extracting entities:   8%|▊         | 816/10000 [00:56<08:55, 17.16entry/s]
# Extracting entities:   8%|▊         | 818/10000 [00:57<10:10, 15.03entry/s]
# Extracting entities:   8%|▊         | 820/10000 [00:57<09:55, 15.42entry/s]
# Extracting entities:   8%|▊         | 822/10000 [00:57<10:13, 14.97entry/s]
# Extracting entities:   8%|▊         | 824/10000 [00:57<10:52, 14.06entry/s]
# Extracting entities:   8%|▊         | 826/10000 [00:57<12:16, 12.46entry/s]
# Extracting entities:   8%|▊         | 829/10000 [00:57<09:42, 15.75entry/s]
# Extracting entities:   8%|▊         | 832/10000 [00:58<08:45, 17.45entry/s]
# Extracting entities:   8%|▊         | 834/10000 [00:58<08:40, 17.61entry/s]
# Extracting entities:   8%|▊         | 837/10000 [00:58<07:59, 19.13entry/s]
# Extracting entities:   8%|▊         | 839/10000 [00:58<11:46, 12.96entry/s]
# Extracting entities:   8%|▊         | 841/10000 [00:58<11:10, 13.66entry/s]
# Extracting entities:   8%|▊         | 843/10000 [00:58<10:51, 14.05entry/s]
# Extracting entities:   8%|▊         | 845/10000 [00:59<16:18,  9.35entry/s]
# Extracting entities:   8%|▊         | 848/10000 [00:59<12:47, 11.92entry/s]
# Extracting entities:   8%|▊         | 850/10000 [00:59<12:24, 12.29entry/s]
# Extracting entities:   9%|▊         | 852/10000 [00:59<12:51, 11.85entry/s]
# Extracting entities:   9%|▊         | 854/10000 [00:59<11:53, 12.81entry/s]
# Extracting entities:   9%|▊         | 856/10000 [00:59<11:39, 13.07entry/s]
# Extracting entities:   9%|▊         | 858/10000 [01:00<13:27, 11.32entry/s]
# Extracting entities:   9%|▊         | 860/10000 [01:00<12:29, 12.19entry/s]
# Extracting entities:   9%|▊         | 862/10000 [01:00<12:51, 11.84entry/s]
# Extracting entities:   9%|▊         | 864/10000 [01:00<13:50, 11.00entry/s]
# Extracting entities:   9%|▊         | 867/10000 [01:00<11:01, 13.80entry/s]
# Extracting entities:   9%|▊         | 869/10000 [01:01<10:59, 13.84entry/s]
# Extracting entities:   9%|▊         | 871/10000 [01:01<10:11, 14.94entry/s]
# Extracting entities:   9%|▊         | 873/10000 [01:01<09:40, 15.74entry/s]
# Extracting entities:   9%|▉         | 875/10000 [01:01<09:45, 15.59entry/s]
# Extracting entities:   9%|▉         | 877/10000 [01:01<09:56, 15.29entry/s]
# Extracting entities:   9%|▉         | 879/10000 [01:01<10:55, 13.91entry/s]
# Extracting entities:   9%|▉         | 881/10000 [01:01<12:39, 12.00entry/s]
# Extracting entities:   9%|▉         | 883/10000 [01:01<11:21, 13.38entry/s]
# Extracting entities:   9%|▉         | 885/10000 [01:02<10:15, 14.80entry/s]
# Extracting entities:   9%|▉         | 887/10000 [01:02<12:29, 12.15entry/s]
# Extracting entities:   9%|▉         | 890/10000 [01:02<10:16, 14.78entry/s]
# Extracting entities:   9%|▉         | 893/10000 [01:02<08:56, 16.97entry/s]
# Extracting entities:   9%|▉         | 896/10000 [01:02<10:59, 13.80entry/s]
# Extracting entities:   9%|▉         | 899/10000 [01:03<09:28, 16.01entry/s]
# Extracting entities:   9%|▉         | 902/10000 [01:03<08:27, 17.93entry/s]
# Extracting entities:   9%|▉         | 905/10000 [01:03<08:54, 17.03entry/s]
# Extracting entities:   9%|▉         | 907/10000 [01:03<08:58, 16.88entry/s]
# Extracting entities:   9%|▉         | 909/10000 [01:03<09:14, 16.41entry/s]
# Extracting entities:   9%|▉         | 911/10000 [01:03<09:28, 15.98entry/s]
# Extracting entities:   9%|▉         | 913/10000 [01:03<09:14, 16.38entry/s]
# Extracting entities:   9%|▉         | 915/10000 [01:03<09:49, 15.41entry/s]
# Extracting entities:   9%|▉         | 918/10000 [01:04<09:10, 16.49entry/s]
# Extracting entities:   9%|▉         | 920/10000 [01:04<08:58, 16.86entry/s]
# Extracting entities:   9%|▉         | 922/10000 [01:04<09:14, 16.38entry/s]
# Extracting entities:   9%|▉         | 924/10000 [01:04<09:50, 15.37entry/s]
# Extracting entities:   9%|▉         | 927/10000 [01:04<08:20, 18.13entry/s]
# Extracting entities:   9%|▉         | 929/10000 [01:04<09:28, 15.96entry/s]
# Extracting entities:   9%|▉         | 931/10000 [01:04<09:18, 16.24entry/s]
# Extracting entities:   9%|▉         | 933/10000 [01:05<09:14, 16.35entry/s]
# Extracting entities:   9%|▉         | 935/10000 [01:05<08:57, 16.86entry/s]
# Extracting entities:   9%|▉         | 937/10000 [01:05<09:28, 15.95entry/s]
# Extracting entities:   9%|▉         | 939/10000 [01:05<08:56, 16.88entry/s]
# Extracting entities:   9%|▉         | 941/10000 [01:05<10:58, 13.75entry/s]
# Extracting entities:   9%|▉         | 944/10000 [01:05<08:48, 17.15entry/s]
# Extracting entities:   9%|▉         | 946/10000 [01:05<10:03, 15.00entry/s]
# Extracting entities:   9%|▉         | 948/10000 [01:06<11:45, 12.82entry/s]
# Extracting entities:  10%|▉         | 950/10000 [01:06<12:49, 11.76entry/s]
# Extracting entities:  96%|█████████▌| 9610/10000 [10:55<00:24, 15.62entry/s]
# Extracting entities:  96%|█████████▌| 9613/10000 [10:55<00:22, 17.47entry/s]
# Extracting entities:  96%|█████████▌| 9615/10000 [10:55<00:26, 14.63entry/s]
# Extracting entities:  96%|█████████▌| 9617/10000 [10:55<00:27, 13.72entry/s]
# Extracting entities:  96%|█████████▌| 9619/10000 [10:55<00:27, 13.75entry/s]
# Extracting entities:  96%|█████████▌| 9621/10000 [10:55<00:27, 13.85entry/s]
# Extracting entities:  96%|█████████▌| 9623/10000 [10:56<00:27, 13.94entry/s]
# Extracting entities:  96%|█████████▋| 9626/10000 [10:56<00:27, 13.80entry/s]
# Extracting entities:  96%|█████████▋| 9628/10000 [10:56<00:25, 14.57entry/s]
# Extracting entities:  96%|█████████▋| 9631/10000 [10:56<00:21, 16.82entry/s]
# Extracting entities:  96%|█████████▋| 9633/10000 [10:56<00:22, 16.17entry/s]
# Extracting entities:  96%|█████████▋| 9636/10000 [10:56<00:25, 14.31entry/s]
# Extracting entities:  96%|█████████▋| 9638/10000 [10:57<00:25, 14.07entry/s]
# Extracting entities:  96%|█████████▋| 9641/10000 [10:57<00:21, 16.54entry/s]
# Extracting entities:  96%|█████████▋| 9644/10000 [10:57<00:18, 19.10entry/s]
# Extracting entities:  96%|█████████▋| 9647/10000 [10:57<00:16, 21.11entry/s]
# Extracting entities:  96%|█████████▋| 9650/10000 [10:57<00:21, 16.38entry/s]
# Extracting entities:  97%|█████████▋| 9652/10000 [10:57<00:26, 13.23entry/s]
# Extracting entities:  97%|█████████▋| 9654/10000 [10:58<00:25, 13.82entry/s]
# Extracting entities:  97%|█████████▋| 9656/10000 [10:58<00:23, 14.58entry/s]
# Extracting entities:  97%|█████████▋| 9658/10000 [10:58<00:22, 15.36entry/s]
# Extracting entities:  97%|█████████▋| 9661/10000 [10:58<00:19, 17.49entry/s]
# Extracting entities:  97%|█████████▋| 9664/10000 [10:58<00:18, 18.57entry/s]
# Extracting entities:  97%|█████████▋| 9666/10000 [10:58<00:18, 17.81entry/s]
# Extracting entities:  97%|█████████▋| 9668/10000 [10:58<00:18, 17.64entry/s]
# Extracting entities:  97%|█████████▋| 9670/10000 [10:58<00:19, 17.11entry/s]
# Extracting entities:  97%|█████████▋| 9673/10000 [10:59<00:17, 18.27entry/s]
# Extracting entities:  97%|█████████▋| 9675/10000 [10:59<00:19, 16.71entry/s]
# Extracting entities:  97%|█████████▋| 9677/10000 [10:59<00:20, 15.94entry/s]
# Extracting entities:  97%|█████████▋| 9679/10000 [10:59<00:19, 16.38entry/s]
# Extracting entities:  97%|█████████▋| 9681/10000 [10:59<00:19, 16.12entry/s]
# Extracting entities:  97%|█████████▋| 9683/10000 [10:59<00:20, 15.17entry/s]
# Extracting entities:  97%|█████████▋| 9685/10000 [10:59<00:20, 15.63entry/s]
# Extracting entities:  97%|█████████▋| 9687/10000 [11:00<00:24, 12.82entry/s]
# Extracting entities:  97%|█████████▋| 9690/10000 [11:00<00:21, 14.70entry/s]
# Extracting entities:  97%|█████████▋| 9693/10000 [11:00<00:17, 17.67entry/s]
# Extracting entities:  97%|█████████▋| 9695/10000 [11:00<00:17, 17.90entry/s]
# Extracting entities:  97%|█████████▋| 9697/10000 [11:00<00:17, 17.74entry/s]
# Extracting entities:  97%|█████████▋| 9700/10000 [11:00<00:15, 19.66entry/s]
# Extracting entities:  97%|█████████▋| 9703/10000 [11:00<00:15, 19.25entry/s]
# Extracting entities:  97%|█████████▋| 9705/10000 [11:01<00:17, 16.96entry/s]
# Extracting entities:  97%|█████████▋| 9709/10000 [11:01<00:16, 17.73entry/s]
# Extracting entities:  97%|█████████▋| 9712/10000 [11:01<00:14, 19.79entry/s]
# Extracting entities:  97%|█████████▋| 9715/10000 [11:01<00:14, 20.17entry/s]
# Extracting entities:  97%|█████████▋| 9719/10000 [11:01<00:14, 18.74entry/s]
# Extracting entities:  97%|█████████▋| 9721/10000 [11:01<00:14, 18.83entry/s]
# Extracting entities:  97%|█████████▋| 9723/10000 [11:01<00:14, 18.90entry/s]
# Extracting entities:  97%|█████████▋| 9725/10000 [11:02<00:16, 16.58entry/s]
# Extracting entities:  97%|█████████▋| 9728/10000 [11:02<00:15, 18.11entry/s]
# Extracting entities:  97%|█████████▋| 9730/10000 [11:02<00:18, 14.89entry/s]
# Extracting entities:  97%|█████████▋| 9732/10000 [11:02<00:18, 14.87entry/s]
# Extracting entities:  97%|█████████▋| 9734/10000 [11:02<00:19, 13.59entry/s]
# Extracting entities:  97%|█████████▋| 9736/10000 [11:02<00:19, 13.79entry/s]
# Extracting entities:  97%|█████████▋| 9739/10000 [11:03<00:16, 16.01entry/s]
# Extracting entities:  97%|█████████▋| 9741/10000 [11:03<00:16, 15.80entry/s]
# Extracting entities:  97%|█████████▋| 9744/10000 [11:03<00:14, 17.60entry/s]
# Extracting entities:  97%|█████████▋| 9746/10000 [11:03<00:17, 14.33entry/s]
# Extracting entities:  97%|█████████▋| 9749/10000 [11:03<00:15, 16.26entry/s]
# Extracting entities:  98%|█████████▊| 9751/10000 [11:03<00:18, 13.43entry/s]
# Extracting entities:  98%|█████████▊| 9753/10000 [11:04<00:18, 13.60entry/s]
# Extracting entities:  98%|█████████▊| 9755/10000 [11:04<00:22, 11.12entry/s]
# Extracting entities:  98%|█████████▊| 9757/10000 [11:04<00:23, 10.55entry/s]
# Extracting entities:  98%|█████████▊| 9760/10000 [11:04<00:20, 11.59entry/s]
# Extracting entities:  98%|█████████▊| 9762/10000 [11:05<00:41,  5.80entry/s]
# Extracting entities:  98%|█████████▊| 9764/10000 [11:05<00:33,  6.98entry/s]
# Extracting entities:  98%|█████████▊| 9767/10000 [11:05<00:24,  9.36entry/s]
# Extracting entities:  98%|█████████▊| 9769/10000 [11:05<00:21, 10.57entry/s]
# Extracting entities:  98%|█████████▊| 9771/10000 [11:06<00:19, 11.93entry/s]
# Extracting entities:  98%|█████████▊| 9773/10000 [11:06<00:17, 13.02entry/s]
# Extracting entities:  98%|█████████▊| 9775/10000 [11:06<00:18, 12.01entry/s]
# Extracting entities:  98%|█████████▊| 9777/10000 [11:06<00:16, 13.26entry/s]
# Extracting entities:  98%|█████████▊| 9779/10000 [11:06<00:17, 12.46entry/s]
# Extracting entities:  98%|█████████▊| 9781/10000 [11:06<00:16, 13.04entry/s]
# Extracting entities:  98%|█████████▊| 9783/10000 [11:07<00:16, 12.94entry/s]
# Extracting entities:  98%|█████████▊| 9787/10000 [11:07<00:12, 16.60entry/s]
# Extracting entities:  98%|█████████▊| 9789/10000 [11:07<00:13, 16.16entry/s]
# Extracting entities:  98%|█████████▊| 9791/10000 [11:07<00:12, 16.69entry/s]
# Extracting entities:  98%|█████████▊| 9794/10000 [11:07<00:11, 18.09entry/s]
# Extracting entities:  98%|█████████▊| 9796/10000 [11:07<00:12, 16.81entry/s]
# Extracting entities:  98%|█████████▊| 9798/10000 [11:07<00:15, 13.35entry/s]
# Extracting entities:  98%|█████████▊| 9800/10000 [11:08<00:18, 10.90entry/s]
# Extracting entities:  98%|█████████▊| 9802/10000 [11:08<00:15, 12.48entry/s]
# Extracting entities:  98%|█████████▊| 9804/10000 [11:08<00:14, 13.87entry/s]
# Extracting entities:  98%|█████████▊| 9807/10000 [11:08<00:11, 16.10entry/s]
# Extracting entities:  98%|█████████▊| 9810/10000 [11:08<00:11, 16.59entry/s]
# Extracting entities:  98%|█████████▊| 9812/10000 [11:08<00:11, 15.89entry/s]
# Extracting entities:  98%|█████████▊| 9814/10000 [11:08<00:11, 16.17entry/s]
# Extracting entities:  98%|█████████▊| 9816/10000 [11:09<00:13, 14.13entry/s]
# Extracting entities:  98%|█████████▊| 9818/10000 [11:09<00:12, 15.14entry/s]
# Extracting entities:  98%|█████████▊| 9820/10000 [11:09<00:12, 14.60entry/s]
# Extracting entities:  98%|█████████▊| 9823/10000 [11:09<00:11, 15.20entry/s]
# Extracting entities:  98%|█████████▊| 9825/10000 [11:09<00:13, 12.67entry/s]
# Extracting entities:  98%|█████████▊| 9827/10000 [11:09<00:13, 12.73entry/s]
# Extracting entities:  98%|█████████▊| 9829/10000 [11:10<00:13, 12.90entry/s]
# Extracting entities:  98%|█████████▊| 9831/10000 [11:10<00:16, 10.45entry/s]
# Extracting entities:  98%|█████████▊| 9834/10000 [11:10<00:13, 12.37entry/s]
# Extracting entities:  98%|█████████▊| 9837/10000 [11:10<00:11, 14.57entry/s]
# Extracting entities:  98%|█████████▊| 9839/10000 [11:10<00:11, 14.54entry/s]
# Extracting entities:  98%|█████████▊| 9841/10000 [11:11<00:11, 14.43entry/s]
# Extracting entities:  98%|█████████▊| 9843/10000 [11:11<00:11, 13.83entry/s]
# Extracting entities:  98%|█████████▊| 9845/10000 [11:11<00:10, 14.39entry/s]
# Extracting entities:  98%|█████████▊| 9847/10000 [11:11<00:10, 14.72entry/s]
# Extracting entities:  98%|█████████▊| 9850/10000 [11:11<00:09, 16.29entry/s]
# Extracting entities:  99%|█████████▊| 9853/10000 [11:11<00:08, 17.67entry/s]
# Extracting entities:  99%|█████████▊| 9856/10000 [11:11<00:08, 16.24entry/s]
# Extracting entities:  99%|█████████▉| 9936/10000 [11:17<00:05, 11.79entry/s]
# Extracting entities:  99%|█████████▉| 9938/10000 [11:17<00:04, 12.50entry/s]
# Extracting entities:  99%|█████████▉| 9940/10000 [11:18<00:04, 13.70entry/s]
# Extracting entities:  99%|█████████▉| 9942/10000 [11:18<00:04, 13.85entry/s]
# Extracting entities:  99%|█████████▉| 9944/10000 [11:18<00:03, 14.02entry/s]
# Extracting entities:  99%|█████████▉| 9946/10000 [11:18<00:03, 15.17entry/s]
# Extracting entities:  99%|█████████▉| 9948/10000 [11:18<00:03, 15.76entry/s]
# Extracting entities: 100%|█████████▉| 9950/10000 [11:18<00:03, 14.46entry/s]
# Extracting entities: 100%|█████████▉| 9952/10000 [11:19<00:04, 10.57entry/s]
# Extracting entities: 100%|█████████▉| 9954/10000 [11:19<00:04, 11.45entry/s]
# Extracting entities: 100%|█████████▉| 9956/10000 [11:19<00:03, 12.99entry/s]
# Extracting entities: 100%|█████████▉| 9958/10000 [11:19<00:03, 13.69entry/s]
# Extracting entities: 100%|█████████▉| 9960/10000 [11:19<00:03, 12.85entry/s]
# Extracting entities: 100%|█████████▉| 9962/10000 [11:19<00:03, 12.46entry/s]
# Extracting entities: 100%|█████████▉| 9965/10000 [11:19<00:02, 15.00entry/s]
# Extracting entities: 100%|█████████▉| 9967/10000 [11:20<00:02, 15.85entry/s]
# Extracting entities: 100%|█████████▉| 9969/10000 [11:20<00:01, 15.64entry/s]
# Extracting entities: 100%|█████████▉| 9972/10000 [11:20<00:01, 16.85entry/s]
# Extracting entities: 100%|█████████▉| 9974/10000 [11:20<00:01, 16.30entry/s]
# Extracting entities: 100%|█████████▉| 9976/10000 [11:20<00:01, 12.35entry/s]
# Extracting entities: 100%|█████████▉| 9979/10000 [11:20<00:01, 14.72entry/s]
# Extracting entities: 100%|█████████▉| 9981/10000 [11:21<00:01, 12.97entry/s]
# Extracting entities: 100%|█████████▉| 9983/10000 [11:21<00:01, 12.61entry/s]
# Extracting entities: 100%|█████████▉| 9985/10000 [11:21<00:01, 13.93entry/s]
# Extracting entities: 100%|█████████▉| 9987/10000 [11:21<00:00, 14.78entry/s]
# Extracting entities: 100%|█████████▉| 9989/10000 [11:21<00:01, 10.54entry/s]
# Extracting entities: 100%|█████████▉| 9991/10000 [11:21<00:00, 11.97entry/s]
# Extracting entities: 100%|█████████▉| 9993/10000 [11:21<00:00, 13.40entry/s]
# Extracting entities: 100%|█████████▉| 9995/10000 [11:22<00:00, 13.25entry/s]
# Extracting entities: 100%|█████████▉| 9997/10000 [11:22<00:00, 10.86entry/s]
# Extracting entities: 100%|█████████▉| 9999/10000 [11:22<00:00, 11.12entry/s]
# Processing rows in political emails: 100%|██████████| 10000/10000 [11:23<00:00, 14.64row/s]
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.sample(10)
# Out:
#                                                     title  \
# 12437   Cherokee Nation set to receive first doses of ...
# 100512  Donald doesn't want you to know you can still ...
# 89958                                                 NaN
# 70294                                                 NaN
# 98283              Phase 3 guidance and plans for schools
# 90574                                                 NaN
# 48663                                                 NaN
# 22949   U.K. Will Start Immunizing People Against COVI...
# 102873                  MSNBC ANNOUNCED: devastating news
# 101140  Tonight: Join AOC, Jamaal, and organizers for ...
#
#                                                      body            source  \
# 12437   No, not really. But the rightwing is fucking *...            Reddit
# 100512  The Democratic PartyThe deadline to get covere...  political emails
# 89958   In the last year, the Trump Administration has...           twitter
# 70294   RT @HouseVetAffairs: House passes legislation ...           twitter
# 98283   Your RI COVID-19 News Update  Hello friend, I ...  political emails
# 90574   Walker's Community Hero Award Goes To Williams...           twitter
# 48663   RT @CourantPhotogs: At the Colt Armory, hundre...           twitter
# 22949   Vaccinate as soon as humanly possible.\n\nDo i...            Reddit
# 102873   I need your help right now. As I’m sure you’r...  political emails
# 101140  Tonight, AOC, Jamaal, and organizers from Hous...  political emails
#
#                   timestamp  Misinfo_flag type_of_misinfo     type_reddit  \
# 12437   2020-12-11 16:39:32           NaN             NaN  post_and_title
# 100512  2017-01-30 05:33:00           NaN             NaN             NaN
# 89958                  None           NaN             NaN             NaN
# 70294                  None           NaN             NaN             NaN
# 98283   2020-06-19 18:50:56           NaN             NaN             NaN
# 90574                  None           NaN             NaN             NaN
# 48663                   NaN           NaN             NaN             NaN
# 22949   2020-12-05 01:51:03           NaN             NaN  post_and_title
# 102873  2019-11-21 01:18:00           NaN             NaN             NaN
# 101140  2020-07-15 19:31:00           NaN             NaN             NaN
#
#                topic  subtopic  \
# 12437          COVID  Vaccines
# 100512  Polarization      None
# 89958   Polarization      None
# 70294   Polarization      None
# 98283   Polarization      None
# 90574   Polarization      None
# 48663   Polarization       NaN
# 22949          COVID  Vaccines
# 102873  Polarization      None
# 101140  Polarization      None
#
#                                                  entities Polarization_flag  \
# 12437   {'people': [], 'organizations': [], 'locations...               NaN
# 100512  {'people': ['Trump'], 'organizations': ['Party...               NaN
# 89958   {'people': [], 'organizations': ['the Trump Ad...          Democrat
# 70294   {'people': [], 'organizations': ['House'], 'lo...        Republican
# 98283   {'people': [], 'organizations': ['the Departme...               NaN
# 90574   {'people': [], 'organizations': ['Walker's'], ...        Republican
# 48663   {'people': [], 'organizations': ['RT @CourantP...          Democrat
# 22949   {'people': [], 'organizations': ['Vaccinate'],...               NaN
# 102873  {'people': ['Julián Paid', 'Julián', 'Julián C...               NaN
# 101140  {'people': ['John', 'Jamaal Bowman', 'John', '...               NaN
#
#         \tMisinfo_flag  type_of_content  \
# 12437              NaN             None
# 100512             NaN  political email
# 89958              NaN             None
# 70294              NaN             None
# 98283              NaN  political email
# 90574              NaN             None
# 48663              NaN             None
# 22949              NaN             None
# 102873             NaN  political email
# 101140             NaN  political email
#
#                                         potential_prompt0
# 12437                                                None
# 100512  Democrats.org: Donald doesn't want you to know...
# 89958                                                None
# 70294                                                None
# 98283   Gina Raimondo : Phase 3 guidance and plans for...
# 90574                                                None
# 48663                                                None
# 22949                                                None
# 102873   Julián Castro: MSNBC ANNOUNCED: devastating news
# 101140  Team Bowman: Tonight: Join AOC, Jamaal, and or...

# %% [markdown]
# ## Political Ads on Facebook

# %% [markdown]
# # Gaza Conflict (optional)

# %% [markdown]
# ### Environmental differnt issues

# %% [markdown]
# ### youtube commentary

# %% [markdown]
# ## News headlines with outlet political labels
#
# https://www.kaggle.com/datasets/diegoexe/2024-us-presidential-elections-top-news?select=fox-news_articles.txt
#
# can guess political affiliation by the outlet
#
# putin carlson sentiment - https://www.kaggle.com/datasets/kanchana1990/social-media-sentiments-putin-and-carlson-interview
#
# political sentiment youtube comments - https://www.kaggle.com/datasets/rashidul0/political-sentiment-analysis-comments-from-youtube

# %% [markdown]
# ## Google War news
#
# https://www.kaggle.com/datasets/armitaraz/google-war-news

# %%
global_df.shape
# Out:
# (164095, 17)

# %%
war_news = pd.read_csv('./Datasets/war-news.csv', encoding='latin-1') # Try 'latin-1' encoding

# %%
war_news.head()
# Out:
#   Unnamed: 0                                          Headlines  \
# 0          0  I served in Iraq and Afghanistan but the horro...
# 1          1  The forever war in Afghanistan is nowhere near...
# 2          2  Hell at Abbey Gate: Chaos, Confusion and Death...
# 3          3  A second Afghanistan: Doubts over Russias w...
# 4          4  Afghanistan: Former army general vows new war ...
#
#                                              Summary       Press         Date  \
# 0  A WAR hero traumatised by the horrors of comba...     The Sun    1 day ago
# 1  Islamic State is seeking to overthrow the Tali...    ThePrint  2 weeks ago
# 2  In firsthand accounts, Afghan civilians and U....  ProPublica  1 month ago
# 3  Russia's lack of progress in its war against U...  Al Jazeera   5 days ago
# 4  Lt Gen Sami Sadat tells the BBC of planned ope...         BBC   1 week ago
#
#        Keyword
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
war_news.shape
# Out:
# (5654, 6)

# %%
global_df.head(1)
# Out:
#                                                title body  source  \
# 0  Health Canada approves AstraZeneca COVID-19 va...  NaN  Reddit
#
#              timestamp  Misinfo_flag type_of_misinfo type_reddit  topic  \
# 0  2021-02-27 06:33:45           1.0            myth  post_title  COVID
#
#    subtopic entities Polarization_flag  \tMisinfo_flag type_of_content  \
# 0  Vaccines      NaN               NaN             NaN             NaN
#
#   potential_prompt0 hashtags gender sentiment_category
# 0               NaN      NaN    NaN               None

# %%
process_and_add_to_global(
    war_news,
    dataset_name="news",
    column_mapping={ "title":"Headlines",
                    "body":"Summary"},
    topic="War",

    additional_columns={
        "Publisher": war_news['Press'],
        "subtopic" : war_news['Keyword'],
        "type_of_content": "War news"

    }
)
# Out:
# Processing dataset: news
# Extracting entities:   0%|          | 0/5654 [00:00<?, ?entry/s]
#
#
# Extracting entities:   0%|          | 13/5654 [00:00<00:46, 121.16entry/s]
#
#
# Extracting entities:   0%|          | 26/5654 [00:00<00:44, 125.48entry/s]
#
#
# Extracting entities:   1%|          | 39/5654 [00:00<00:44, 124.79entry/s]
#
#
# Extracting entities:   1%|          | 52/5654 [00:00<00:46, 120.36entry/s]
#
#
# Extracting entities:   1%|          | 65/5654 [00:00<00:47, 118.77entry/s]
#
#
# Extracting entities:   1%|▏         | 78/5654 [00:00<00:46, 120.04entry/s]
#
#
# Extracting entities:   2%|▏         | 91/5654 [00:00<00:45, 122.12entry/s]
#
#
# Extracting entities:   2%|▏         | 104/5654 [00:00<00:48, 115.34entry/s]
#
#
# Extracting entities:   2%|▏         | 117/5654 [00:00<00:47, 117.40entry/s]
#
#
# Extracting entities:   2%|▏         | 130/5654 [00:01<00:45, 120.99entry/s]
#
#
# Extracting entities:   3%|▎         | 144/5654 [00:01<00:44, 124.11entry/s]
#
#
# Extracting entities:   3%|▎         | 157/5654 [00:01<00:44, 124.39entry/s]
#
#
# Extracting entities:   3%|▎         | 170/5654 [00:01<00:43, 125.43entry/s]
#
#
# Extracting entities:   3%|▎         | 183/5654 [00:01<00:43, 124.75entry/s]
#
#
# Extracting entities:   3%|▎         | 196/5654 [00:01<00:44, 123.02entry/s]
#
#
# Extracting entities:   4%|▎         | 209/5654 [00:01<00:43, 124.62entry/s]
#
#
# Extracting entities:   4%|▍         | 222/5654 [00:01<00:43, 124.35entry/s]
#
#
# Extracting entities:   4%|▍         | 235/5654 [00:01<00:44, 122.72entry/s]
#
#
# Extracting entities:   4%|▍         | 248/5654 [00:02<00:43, 123.38entry/s]
#
#
# Extracting entities:   5%|▍         | 261/5654 [00:02<00:43, 124.45entry/s]
#
#
# Extracting entities:   5%|▍         | 274/5654 [00:02<00:43, 122.61entry/s]
#
#
# Extracting entities:   5%|▌         | 287/5654 [00:02<00:43, 122.62entry/s]
#
#
# Extracting entities:   5%|▌         | 300/5654 [00:02<00:43, 123.76entry/s]
#
#
# Extracting entities:   6%|▌         | 314/5654 [00:02<00:42, 126.04entry/s]
#
#
# Extracting entities:   6%|▌         | 327/5654 [00:02<00:41, 126.96entry/s]
#
#
# Extracting entities:   6%|▌         | 340/5654 [00:02<00:42, 126.22entry/s]
#
#
# Extracting entities:   6%|▌         | 353/5654 [00:02<00:43, 121.67entry/s]
#
#
# Extracting entities:   6%|▋         | 366/5654 [00:02<00:42, 124.01entry/s]
#
#
# Extracting entities:   7%|▋         | 379/5654 [00:03<00:42, 124.05entry/s]
#
#
# Extracting entities:   7%|▋         | 392/5654 [00:03<00:42, 124.01entry/s]
#
#
# Extracting entities:   7%|▋         | 406/5654 [00:03<00:41, 126.33entry/s]
#
#
# Extracting entities:   7%|▋         | 420/5654 [00:03<00:40, 127.84entry/s]
#
#
# Extracting entities:   8%|▊         | 433/5654 [00:03<00:40, 128.12entry/s]
#
#
# Extracting entities:   8%|▊         | 447/5654 [00:03<00:40, 129.68entry/s]
#
#
# Extracting entities:   8%|▊         | 460/5654 [00:03<00:40, 128.37entry/s]
#
#
# Extracting entities:   8%|▊         | 474/5654 [00:03<00:39, 130.58entry/s]
#
#
# Extracting entities:   9%|▊         | 488/5654 [00:03<00:39, 131.97entry/s]
#
#
# Extracting entities:   9%|▉         | 502/5654 [00:04<00:39, 131.80entry/s]
#
#
# Extracting entities:   9%|▉         | 516/5654 [00:04<00:39, 131.24entry/s]
#
#
# Extracting entities:   9%|▉         | 530/5654 [00:04<00:39, 130.80entry/s]
#
#
# Extracting entities:  10%|▉         | 544/5654 [00:04<00:39, 130.46entry/s]
#
#
# Extracting entities:  10%|▉         | 558/5654 [00:04<00:39, 130.56entry/s]
#
#
# Extracting entities:  10%|█         | 572/5654 [00:04<00:39, 129.21entry/s]
#
#
# Extracting entities:  10%|█         | 585/5654 [00:04<00:39, 129.28entry/s]
#
#
# Extracting entities:  11%|█         | 599/5654 [00:04<00:38, 131.29entry/s]
#
#
# Extracting entities:  11%|█         | 613/5654 [00:04<00:38, 131.17entry/s]
#
#
# Extracting entities:  11%|█         | 627/5654 [00:04<00:38, 130.98entry/s]
#
#
# Extracting entities:  11%|█▏        | 641/5654 [00:05<00:38, 130.98entry/s]
#
#
# Extracting entities:  12%|█▏        | 655/5654 [00:05<00:38, 130.34entry/s]
#
#
# Extracting entities:  12%|█▏        | 669/5654 [00:05<00:38, 130.82entry/s]
#
#
# Extracting entities:  12%|█▏        | 683/5654 [00:05<00:38, 130.45entry/s]
#
#
# Extracting entities:  12%|█▏        | 697/5654 [00:05<00:38, 129.43entry/s]
#
#
# Extracting entities:  13%|█▎        | 710/5654 [00:05<00:38, 129.53entry/s]
#
#
# Extracting entities:  13%|█▎        | 723/5654 [00:05<00:40, 121.88entry/s]
#
#
# Extracting entities:  13%|█▎        | 736/5654 [00:05<00:41, 118.41entry/s]
#
#
# Extracting entities:  13%|█▎        | 748/5654 [00:05<00:41, 117.82entry/s]
#
#
# Extracting entities:  13%|█▎        | 761/5654 [00:06<00:40, 120.35entry/s]
#
#
# Extracting entities:  14%|█▎        | 774/5654 [00:06<00:40, 121.13entry/s]
#
#
# Extracting entities:  14%|█▍        | 787/5654 [00:06<00:40, 120.73entry/s]
#
#
# Extracting entities:  14%|█▍        | 800/5654 [00:06<00:41, 117.63entry/s]
#
#
# Extracting entities:  14%|█▍        | 813/5654 [00:06<00:40, 120.32entry/s]
#
#
# Extracting entities:  15%|█▍        | 826/5654 [00:06<00:39, 120.72entry/s]
#
#
# Extracting entities:  15%|█▍        | 839/5654 [00:06<00:40, 119.81entry/s]
#
# Extracting entities:  35%|███▌      | 1998/5654 [00:35<00:29, 124.42entry/s]
#
#
# Extracting entities:  15%|█▌        | 852/5654 [00:06<00:41, 116.17entry/s]
#
#
# Extracting entities:  15%|█▌        | 865/5654 [00:06<00:40, 117.60entry/s]
#
#
# Extracting entities:  16%|█▌        | 877/5654 [00:07<00:40, 116.66entry/s]
#
#
# Extracting entities:  16%|█▌        | 889/5654 [00:07<00:41, 114.24entry/s]
#
#
# Extracting entities:  16%|█▌        | 901/5654 [00:07<00:43, 110.49entry/s]
#
#
# Extracting entities:  16%|█▌        | 913/5654 [00:07<00:43, 110.09entry/s]
#
#
# Extracting entities:  16%|█▋        | 925/5654 [00:07<00:42, 111.67entry/s]
#
#
# Extracting entities:  17%|█▋        | 937/5654 [00:07<00:41, 113.86entry/s]
#
#
# Extracting entities:  17%|█▋        | 950/5654 [00:07<00:39, 118.46entry/s]
#
#
# Extracting entities:  17%|█▋        | 963/5654 [00:07<00:39, 119.83entry/s]
#
#
# Extracting entities:  17%|█▋        | 976/5654 [00:07<00:40, 114.94entry/s]
#
#
# Extracting entities:  17%|█▋        | 988/5654 [00:08<00:40, 115.09entry/s]
#
#
# Extracting entities:  18%|█▊        | 1001/5654 [00:08<00:39, 117.81entry/s]
#
#
# Extracting entities:  18%|█▊        | 1014/5654 [00:08<00:38, 119.59entry/s]
#
#
# Extracting entities:  18%|█▊        | 1027/5654 [00:08<00:37, 121.87entry/s]
#
#
# Extracting entities:  18%|█▊        | 1041/5654 [00:08<00:36, 124.98entry/s]
#
#
# Extracting entities:  19%|█▊        | 1054/5654 [00:08<00:36, 125.09entry/s]
#
#
# Extracting entities:  19%|█▉        | 1068/5654 [00:08<00:36, 127.02entry/s]
#
#
# Extracting entities:  19%|█▉        | 1081/5654 [00:08<00:36, 126.26entry/s]
#
#
# Extracting entities:  19%|█▉        | 1094/5654 [00:08<00:36, 124.86entry/s]
#
#
# Extracting entities:  20%|█▉        | 1107/5654 [00:08<00:36, 125.80entry/s]
#
#
# Extracting entities:  20%|█▉        | 1120/5654 [00:09<00:35, 126.11entry/s]
#
#
# Extracting entities:  20%|██        | 1133/5654 [00:09<00:35, 126.07entry/s]
#
#
# Extracting entities:  20%|██        | 1146/5654 [00:09<00:35, 125.76entry/s]
#
#
# Extracting entities:  20%|██        | 1159/5654 [00:09<00:35, 126.84entry/s]
#
#
# Extracting entities:  21%|██        | 1172/5654 [00:09<00:35, 126.59entry/s]
#
#
# Extracting entities:  21%|██        | 1186/5654 [00:09<00:34, 127.88entry/s]
#
#
# Extracting entities:  21%|██        | 1199/5654 [00:09<00:34, 127.53entry/s]
#
#
# Extracting entities:  21%|██▏       | 1212/5654 [00:09<00:36, 123.26entry/s]
#
#
# Extracting entities:  22%|██▏       | 1225/5654 [00:09<00:36, 120.01entry/s]
#
#
# Extracting entities:  22%|██▏       | 1238/5654 [00:10<00:36, 119.85entry/s]
#
#
# Extracting entities:  22%|██▏       | 1251/5654 [00:10<00:36, 120.51entry/s]
#
#
# Extracting entities:  22%|██▏       | 1264/5654 [00:10<00:36, 120.29entry/s]
#
#
# Extracting entities:  23%|██▎       | 1277/5654 [00:10<00:36, 120.16entry/s]
#
#
# Extracting entities:  23%|██▎       | 1290/5654 [00:10<00:36, 120.53entry/s]
#
#
# Extracting entities:  23%|██▎       | 1303/5654 [00:10<00:35, 121.10entry/s]
#
#
# Extracting entities:  23%|██▎       | 1316/5654 [00:10<00:35, 122.07entry/s]
#
#
# Extracting entities:  24%|██▎       | 1329/5654 [00:10<00:35, 121.32entry/s]
#
#
# Extracting entities:  24%|██▎       | 1342/5654 [00:10<00:36, 117.28entry/s]
#
#
# Extracting entities:  24%|██▍       | 1355/5654 [00:10<00:35, 120.35entry/s]
#
#
# Extracting entities:  24%|██▍       | 1368/5654 [00:11<00:35, 121.54entry/s]
#
#
# Extracting entities:  24%|██▍       | 1381/5654 [00:11<00:34, 122.24entry/s]
#
#
# Extracting entities:  25%|██▍       | 1394/5654 [00:11<00:34, 123.70entry/s]
#
#
# Extracting entities:  25%|██▍       | 1407/5654 [00:11<00:34, 122.87entry/s]
#
#
# Extracting entities:  25%|██▌       | 1420/5654 [00:11<00:34, 122.86entry/s]
#
#
# Extracting entities:  25%|██▌       | 1434/5654 [00:11<00:33, 125.05entry/s]
#
#
# Extracting entities:  26%|██▌       | 1448/5654 [00:11<00:32, 127.48entry/s]
#
#
# Extracting entities:  26%|██▌       | 1461/5654 [00:11<00:33, 124.62entry/s]
#
#
# Extracting entities:  26%|██▌       | 1474/5654 [00:11<00:34, 121.34entry/s]
#
#
# Extracting entities:  26%|██▋       | 1487/5654 [00:12<00:34, 120.99entry/s]
#
#
# Extracting entities:  27%|██▋       | 1500/5654 [00:12<00:34, 121.02entry/s]
#
#
# Extracting entities:  27%|██▋       | 1514/5654 [00:12<00:33, 124.32entry/s]
#
#
# Extracting entities:  27%|██▋       | 1528/5654 [00:12<00:32, 126.06entry/s]
#
#
# Extracting entities:  27%|██▋       | 1541/5654 [00:12<00:32, 125.31entry/s]
#
#
# Extracting entities:  27%|██▋       | 1554/5654 [00:12<00:32, 126.14entry/s]
#
#
# Extracting entities:  28%|██▊       | 1567/5654 [00:12<00:32, 125.08entry/s]
#
#
# Extracting entities:  28%|██▊       | 1580/5654 [00:12<00:32, 124.80entry/s]
#
#
# Extracting entities:  28%|██▊       | 1593/5654 [00:12<00:32, 125.10entry/s]
#
#
# Extracting entities:  28%|██▊       | 1606/5654 [00:13<00:32, 125.13entry/s]
#
#
# Extracting entities:  29%|██▊       | 1619/5654 [00:13<00:32, 124.87entry/s]
#
#
# Extracting entities:  29%|██▉       | 1633/5654 [00:13<00:31, 127.29entry/s]
#
#
# Extracting entities:  29%|██▉       | 1646/5654 [00:13<00:31, 127.65entry/s]
#
#
# Extracting entities:  29%|██▉       | 1659/5654 [00:13<00:31, 127.98entry/s]
#
#
# Extracting entities:  30%|██▉       | 1673/5654 [00:13<00:30, 129.23entry/s]
#
#
# Extracting entities:  30%|██▉       | 1686/5654 [00:13<00:30, 129.14entry/s]
#
#
# Extracting entities:  30%|███       | 1699/5654 [00:13<00:30, 128.88entry/s]
#
#
# Extracting entities:  30%|███       | 1712/5654 [00:13<00:30, 127.96entry/s]
#
#
# Extracting entities:  31%|███       | 1725/5654 [00:13<00:30, 127.46entry/s]
#
#
# Extracting entities:  31%|███       | 1738/5654 [00:14<00:31, 125.80entry/s]
#
#
# Extracting entities:  31%|███       | 1751/5654 [00:14<00:31, 124.22entry/s]
#
#
# Extracting entities:  31%|███       | 1765/5654 [00:14<00:30, 126.05entry/s]
#
#
# Extracting entities:  31%|███▏      | 1778/5654 [00:14<00:30, 127.14entry/s]
#
#
# Extracting entities:  32%|███▏      | 1792/5654 [00:14<00:30, 128.22entry/s]
#
#
# Extracting entities:  32%|███▏      | 1805/5654 [00:14<00:30, 126.22entry/s]
#
#
# Extracting entities:  32%|███▏      | 1818/5654 [00:14<00:30, 125.93entry/s]
#
#
# Extracting entities:  32%|███▏      | 1831/5654 [00:14<00:30, 126.35entry/s]
#
#
# Extracting entities:  33%|███▎      | 1844/5654 [00:14<00:30, 122.98entry/s]
#
#
# Extracting entities:  33%|███▎      | 1857/5654 [00:14<00:30, 124.36entry/s]
#
#
# Extracting entities:  33%|███▎      | 1871/5654 [00:15<00:30, 126.05entry/s]
#
#
# Extracting entities:  33%|███▎      | 1884/5654 [00:15<00:30, 125.33entry/s]
#
#
# Extracting entities:  34%|███▎      | 1898/5654 [00:15<00:29, 127.45entry/s]
#
#
# Extracting entities:  34%|███▍      | 1911/5654 [00:15<00:29, 126.18entry/s]
#
#
# Extracting entities:  34%|███▍      | 1924/5654 [00:15<00:29, 124.49entry/s]
#
#
# Extracting entities:  34%|███▍      | 1937/5654 [00:15<00:29, 124.54entry/s]
#
#
# Extracting entities:  34%|███▍      | 1950/5654 [00:15<00:29, 124.85entry/s]
#
#
# Extracting entities:  35%|███▍      | 1963/5654 [00:15<00:30, 122.17entry/s]
#
#
# Extracting entities:  35%|███▍      | 1976/5654 [00:15<00:30, 121.92entry/s]
#
#
# Extracting entities:  35%|███▌      | 1989/5654 [00:16<00:29, 123.05entry/s]
#
#
# Extracting entities:  35%|███▌      | 2002/5654 [00:16<00:29, 122.73entry/s]
#
#
# Extracting entities:  36%|███▌      | 2015/5654 [00:16<00:29, 124.51entry/s]
#
#
# Extracting entities:  36%|███▌      | 2029/5654 [00:16<00:28, 126.22entry/s]
#
#
# Extracting entities:  36%|███▌      | 2042/5654 [00:16<00:28, 125.95entry/s]
#
#
# Extracting entities:  36%|███▋      | 2055/5654 [00:16<00:28, 125.95entry/s]
#
#
# Extracting entities:  37%|███▋      | 2068/5654 [00:16<00:28, 124.68entry/s]
#
#
# Extracting entities:  37%|███▋      | 2081/5654 [00:16<00:28, 123.92entry/s]
#
#
# Extracting entities:  37%|███▋      | 2094/5654 [00:16<00:28, 125.40entry/s]
#
#
# Extracting entities:  37%|███▋      | 2107/5654 [00:16<00:28, 125.19entry/s]
#
#
# Extracting entities:  37%|███▋      | 2120/5654 [00:17<00:28, 123.52entry/s]
#
#
# Extracting entities:  38%|███▊      | 2133/5654 [00:17<00:28, 123.36entry/s]
#
#
# Extracting entities:  38%|███▊      | 2146/5654 [00:17<00:28, 124.99entry/s]
#
#
# Extracting entities:  38%|███▊      | 2159/5654 [00:17<00:27, 126.03entry/s]
#
#
# Extracting entities:  38%|███▊      | 2172/5654 [00:17<00:27, 126.43entry/s]
#
#
# Extracting entities:  39%|███▊      | 2185/5654 [00:17<00:27, 127.00entry/s]
#
#
# Extracting entities:  39%|███▉      | 2198/5654 [00:17<00:27, 127.72entry/s]
#
#
# Extracting entities:  39%|███▉      | 2211/5654 [00:17<00:27, 123.12entry/s]
#
#
# Extracting entities:  39%|███▉      | 2224/5654 [00:17<00:28, 121.40entry/s]
#
#
# Extracting entities:  40%|███▉      | 2237/5654 [00:18<00:28, 120.49entry/s]
#
#
# Extracting entities:  40%|███▉      | 2250/5654 [00:18<00:28, 119.54entry/s]
#
#
# Extracting entities:  40%|████      | 2263/5654 [00:18<00:28, 120.28entry/s]
#
#
# Extracting entities:  40%|████      | 2276/5654 [00:18<00:28, 119.34entry/s]
#
#
# Extracting entities:  40%|████      | 2288/5654 [00:18<00:28, 117.75entry/s]
#
#
# Extracting entities:  41%|████      | 2302/5654 [00:18<00:27, 121.48entry/s]
#
#
# Extracting entities:  41%|████      | 2315/5654 [00:18<00:27, 123.05entry/s]
#
#
# Extracting entities:  41%|████      | 2328/5654 [00:18<00:27, 119.99entry/s]
#
#
# Extracting entities:  41%|████▏     | 2341/5654 [00:18<00:27, 119.64entry/s]
#
#
# Extracting entities:  42%|████▏     | 2354/5654 [00:19<00:27, 120.63entry/s]
#
#
# Extracting entities:  42%|████▏     | 2367/5654 [00:19<00:27, 121.62entry/s]
#
#
# Extracting entities:  42%|████▏     | 2380/5654 [00:19<00:27, 121.18entry/s]
#
#
# Extracting entities:  42%|████▏     | 2393/5654 [00:19<00:26, 121.09entry/s]
#
#
# Extracting entities:  43%|████▎     | 2406/5654 [00:19<00:27, 116.95entry/s]
#
#
# Extracting entities:  43%|████▎     | 2418/5654 [00:19<00:28, 115.40entry/s]
#
#
# Extracting entities:  43%|████▎     | 2430/5654 [00:19<00:28, 114.71entry/s]
#
#
# Extracting entities:  43%|████▎     | 2442/5654 [00:19<00:28, 113.55entry/s]
#
#
# Extracting entities:  43%|████▎     | 2454/5654 [00:19<00:28, 111.93entry/s]
#
#
# Extracting entities:  44%|████▎     | 2466/5654 [00:20<00:29, 109.65entry/s]
#
#
# Extracting entities:  44%|████▍     | 2477/5654 [00:20<00:30, 104.33entry/s]
#
#
# Extracting entities:  44%|████▍     | 2489/5654 [00:20<00:29, 107.73entry/s]
#
#
# Extracting entities:  44%|████▍     | 2502/5654 [00:20<00:27, 112.73entry/s]
#
#
# Extracting entities:  44%|████▍     | 2515/5654 [00:20<00:26, 116.61entry/s]
#
#
# Extracting entities:  45%|████▍     | 2528/5654 [00:20<00:26, 120.22entry/s]
#
#
# Extracting entities:  45%|████▍     | 2541/5654 [00:20<00:25, 120.51entry/s]
#
#
# Extracting entities:  45%|████▌     | 2554/5654 [00:20<00:27, 112.18entry/s]
#
#
# Extracting entities:  45%|████▌     | 2567/5654 [00:20<00:26, 114.98entry/s]
#
#
# Extracting entities:  46%|████▌     | 2580/5654 [00:20<00:26, 118.15entry/s]
#
#
# Extracting entities:  46%|████▌     | 2593/5654 [00:21<00:25, 120.09entry/s]
#
#
# Extracting entities:  46%|████▌     | 2606/5654 [00:21<00:25, 120.21entry/s]
#
#
# Extracting entities:  46%|████▋     | 2619/5654 [00:21<00:24, 121.56entry/s]
#
#
# Extracting entities:  47%|████▋     | 2632/5654 [00:21<00:26, 112.92entry/s]
#
#
# Extracting entities:  47%|████▋     | 2645/5654 [00:21<00:25, 116.97entry/s]
#
#
# Extracting entities:  47%|████▋     | 2658/5654 [00:21<00:25, 119.37entry/s]
#
#
# Extracting entities:  47%|████▋     | 2671/5654 [00:21<00:24, 120.86entry/s]
#
#
# Extracting entities:  47%|████▋     | 2684/5654 [00:21<00:24, 121.06entry/s]
#
#
# Extracting entities:  48%|████▊     | 2697/5654 [00:21<00:24, 123.02entry/s]
#
#
# Extracting entities:  48%|████▊     | 2710/5654 [00:22<00:23, 123.14entry/s]
#
#
# Extracting entities:  48%|████▊     | 2723/5654 [00:22<00:23, 123.93entry/s]
#
#
# Extracting entities:  48%|████▊     | 2736/5654 [00:22<00:23, 122.91entry/s]
#
#
# Extracting entities:  49%|████▊     | 2749/5654 [00:22<00:23, 124.55entry/s]
#
#
# Extracting entities:  49%|████▉     | 2762/5654 [00:22<00:22, 125.80entry/s]
#
#
# Extracting entities:  49%|████▉     | 2775/5654 [00:22<00:22, 126.74entry/s]
#
#
# Extracting entities:  49%|████▉     | 2788/5654 [00:22<00:22, 125.64entry/s]
#
#
# Extracting entities:  50%|████▉     | 2801/5654 [00:22<00:22, 124.23entry/s]
#
#
# Extracting entities:  50%|████▉     | 2814/5654 [00:22<00:23, 121.05entry/s]
#
#
# Extracting entities:  50%|█████     | 2827/5654 [00:23<00:23, 120.63entry/s]
#
#
# Extracting entities:  50%|█████     | 2840/5654 [00:23<00:23, 122.32entry/s]
#
#
# Extracting entities:  50%|█████     | 2853/5654 [00:23<00:22, 123.64entry/s]
#
#
# Extracting entities:  51%|█████     | 2866/5654 [00:23<00:22, 125.31entry/s]
#
#
# Extracting entities:  51%|█████     | 2879/5654 [00:23<00:22, 125.39entry/s]
#
#
# Extracting entities:  51%|█████     | 2892/5654 [00:23<00:21, 125.63entry/s]
#
#
# Extracting entities:  51%|█████▏    | 2905/5654 [00:23<00:21, 126.17entry/s]
#
#
# Extracting entities:  52%|█████▏    | 2918/5654 [00:23<00:21, 124.94entry/s]
#
#
# Extracting entities:  52%|█████▏    | 2931/5654 [00:23<00:21, 123.78entry/s]
#
#
# Extracting entities:  52%|█████▏    | 2944/5654 [00:23<00:21, 123.21entry/s]
#
#
# Extracting entities:  52%|█████▏    | 2957/5654 [00:24<00:22, 122.49entry/s]
#
#
# Extracting entities:  53%|█████▎    | 2970/5654 [00:24<00:21, 123.58entry/s]
#
#
# Extracting entities:  53%|█████▎    | 2983/5654 [00:24<00:21, 124.83entry/s]
#
#
# Extracting entities:  53%|█████▎    | 2996/5654 [00:24<00:21, 124.65entry/s]
#
#
# Extracting entities:  53%|█████▎    | 3009/5654 [00:24<00:20, 126.19entry/s]
#
#
# Extracting entities:  53%|█████▎    | 3023/5654 [00:24<00:20, 127.81entry/s]
#
#
# Extracting entities:  54%|█████▎    | 3036/5654 [00:24<00:20, 127.87entry/s]
#
#
# Extracting entities:  54%|█████▍    | 3049/5654 [00:24<00:20, 126.95entry/s]
#
#
# Extracting entities:  54%|█████▍    | 3062/5654 [00:24<00:20, 127.50entry/s]
#
#
# Extracting entities:  54%|█████▍    | 3076/5654 [00:24<00:19, 129.18entry/s]
#
#
# Extracting entities:  55%|█████▍    | 3090/5654 [00:25<00:19, 130.22entry/s]
#
#
# Extracting entities:  55%|█████▍    | 3104/5654 [00:25<00:19, 129.04entry/s]
#
#
# Extracting entities:  55%|█████▌    | 3117/5654 [00:25<00:19, 129.28entry/s]
#
#
# Extracting entities:  55%|█████▌    | 3130/5654 [00:25<00:19, 129.48entry/s]
#
#
# Extracting entities:  56%|█████▌    | 3143/5654 [00:25<00:19, 128.84entry/s]
#
#
# Extracting entities:  56%|█████▌    | 3156/5654 [00:25<00:19, 126.84entry/s]
#
#
# Extracting entities:  56%|█████▌    | 3169/5654 [00:25<00:20, 123.60entry/s]
#
#
# Extracting entities:  56%|█████▋    | 3183/5654 [00:25<00:19, 126.58entry/s]
#
#
# Extracting entities:  57%|█████▋    | 3196/5654 [00:25<00:19, 124.09entry/s]
#
#
# Extracting entities:  57%|█████▋    | 3209/5654 [00:26<00:19, 124.75entry/s]
#
#
# Extracting entities:  57%|█████▋    | 3222/5654 [00:26<00:19, 124.45entry/s]
#
#
# Extracting entities:  57%|█████▋    | 3235/5654 [00:26<00:19, 125.80entry/s]
#
#
# Extracting entities:  57%|█████▋    | 3249/5654 [00:26<00:18, 128.10entry/s]
#
#
# Extracting entities:  58%|█████▊    | 3263/5654 [00:26<00:18, 130.28entry/s]
#
#
# Extracting entities:  58%|█████▊    | 3277/5654 [00:26<00:18, 130.56entry/s]
#
#
# Extracting entities:  58%|█████▊    | 3291/5654 [00:26<00:18, 130.64entry/s]
#
#
# Extracting entities:  58%|█████▊    | 3305/5654 [00:26<00:18, 126.92entry/s]
#
#
# Extracting entities:  59%|█████▊    | 3318/5654 [00:26<00:18, 127.33entry/s]
#
#
# Extracting entities:  59%|█████▉    | 3331/5654 [00:26<00:18, 126.91entry/s]
#
#
# Extracting entities:  59%|█████▉    | 3344/5654 [00:27<00:18, 125.78entry/s]
#
#
# Extracting entities:  59%|█████▉    | 3357/5654 [00:27<00:18, 126.45entry/s]
#
#
# Extracting entities:  60%|█████▉    | 3371/5654 [00:27<00:17, 129.82entry/s]
#
#
# Extracting entities:  60%|█████▉    | 3385/5654 [00:27<00:17, 130.12entry/s]
#
#
# Extracting entities:  60%|██████    | 3399/5654 [00:27<00:17, 131.80entry/s]
#
#
# Extracting entities:  60%|██████    | 3413/5654 [00:27<00:17, 131.54entry/s]
#
#
# Extracting entities:  61%|██████    | 3427/5654 [00:27<00:17, 128.81entry/s]
#
#
# Extracting entities:  61%|██████    | 3440/5654 [00:27<00:17, 125.15entry/s]
#
#
# Extracting entities:  61%|██████    | 3453/5654 [00:27<00:17, 124.61entry/s]
#
#
# Extracting entities:  61%|██████▏   | 3466/5654 [00:28<00:17, 125.60entry/s]
#
#
# Extracting entities:  62%|██████▏   | 3479/5654 [00:28<00:17, 126.31entry/s]
#
#
# Extracting entities:  62%|██████▏   | 3492/5654 [00:28<00:17, 125.94entry/s]
#
#
# Extracting entities:  62%|██████▏   | 3505/5654 [00:28<00:16, 126.47entry/s]
#
#
# Extracting entities:  62%|██████▏   | 3519/5654 [00:28<00:16, 128.87entry/s]
#
#
# Extracting entities:  62%|██████▏   | 3532/5654 [00:28<00:16, 128.51entry/s]
#
#
# Extracting entities:  63%|██████▎   | 3545/5654 [00:28<00:16, 128.55entry/s]
#
#
# Extracting entities:  63%|██████▎   | 3558/5654 [00:28<00:16, 125.62entry/s]
#
#
# Extracting entities:  63%|██████▎   | 3571/5654 [00:28<00:16, 126.01entry/s]
#
#
# Extracting entities:  63%|██████▎   | 3584/5654 [00:28<00:16, 126.07entry/s]
#
#
# Extracting entities:  64%|██████▎   | 3597/5654 [00:29<00:16, 125.86entry/s]
#
#
# Extracting entities:  64%|██████▍   | 3610/5654 [00:29<00:16, 125.11entry/s]
#
#
# Extracting entities:  64%|██████▍   | 3623/5654 [00:29<00:16, 124.58entry/s]
#
#
# Extracting entities:  64%|██████▍   | 3636/5654 [00:29<00:16, 125.20entry/s]
#
#
# Extracting entities:  65%|██████▍   | 3649/5654 [00:29<00:16, 125.14entry/s]
#
#
# Extracting entities:  65%|██████▍   | 3662/5654 [00:29<00:15, 126.47entry/s]
#
#
# Extracting entities:  65%|██████▍   | 3675/5654 [00:29<00:15, 127.16entry/s]
#
#
# Extracting entities:  65%|██████▌   | 3688/5654 [00:29<00:15, 125.39entry/s]
#
#
# Extracting entities:  65%|██████▌   | 3701/5654 [00:29<00:15, 125.48entry/s]
#
#
# Extracting entities:  66%|██████▌   | 3714/5654 [00:30<00:15, 126.29entry/s]
#
#
# Extracting entities:  66%|██████▌   | 3727/5654 [00:30<00:15, 127.11entry/s]
#
#
# Extracting entities:  66%|██████▌   | 3740/5654 [00:30<00:15, 123.85entry/s]
#
#
# Extracting entities:  66%|██████▋   | 3753/5654 [00:30<00:15, 123.99entry/s]
#
#
# Extracting entities:  67%|██████▋   | 3766/5654 [00:30<00:15, 123.82entry/s]
#
#
# Extracting entities:  67%|██████▋   | 3779/5654 [00:30<00:15, 123.13entry/s]
#
#
# Extracting entities:  67%|██████▋   | 3792/5654 [00:30<00:14, 124.57entry/s]
#
#
# Extracting entities:  67%|██████▋   | 3805/5654 [00:30<00:15, 119.29entry/s]
#
#
# Extracting entities:  68%|██████▊   | 3817/5654 [00:30<00:16, 111.04entry/s]
#
#
# Extracting entities:  68%|██████▊   | 3829/5654 [00:30<00:16, 112.93entry/s]
#
#
# Extracting entities:  68%|██████▊   | 3841/5654 [00:31<00:15, 113.99entry/s]
#
#
# Extracting entities:  68%|██████▊   | 3854/5654 [00:31<00:15, 116.79entry/s]
#
#
# Extracting entities:  68%|██████▊   | 3867/5654 [00:31<00:14, 119.65entry/s]
#
#
# Extracting entities:  69%|██████▊   | 3880/5654 [00:31<00:14, 121.65entry/s]
#
#
# Extracting entities:  69%|██████▉   | 3893/5654 [00:31<00:14, 123.89entry/s]
#
#
# Extracting entities:  69%|██████▉   | 3906/5654 [00:31<00:13, 124.88entry/s]
#
#
# Extracting entities:  69%|██████▉   | 3919/5654 [00:31<00:14, 121.80entry/s]
#
#
# Extracting entities:  70%|██████▉   | 3932/5654 [00:31<00:14, 119.89entry/s]
#
#
# Extracting entities:  70%|██████▉   | 3945/5654 [00:31<00:14, 120.16entry/s]
#
#
# Extracting entities:  70%|███████   | 3958/5654 [00:32<00:14, 118.89entry/s]
#
#
# Extracting entities:  70%|███████   | 3971/5654 [00:32<00:14, 119.99entry/s]
#
#
# Extracting entities:  70%|███████   | 3984/5654 [00:32<00:14, 115.44entry/s]
#
#
# Extracting entities:  71%|███████   | 3997/5654 [00:32<00:14, 117.83entry/s]
#
#
# Extracting entities:  71%|███████   | 4010/5654 [00:32<00:13, 120.41entry/s]
#
#
# Extracting entities:  71%|███████   | 4023/5654 [00:32<00:13, 121.33entry/s]
#
#
# Extracting entities:  71%|███████▏  | 4036/5654 [00:32<00:13, 123.68entry/s]
#
#
# Extracting entities:  72%|███████▏  | 4049/5654 [00:32<00:12, 123.67entry/s]
#
#
# Extracting entities:  72%|███████▏  | 4062/5654 [00:32<00:13, 122.21entry/s]
#
#
# Extracting entities:  72%|███████▏  | 4075/5654 [00:33<00:12, 123.55entry/s]
#
#
# Extracting entities:  72%|███████▏  | 4088/5654 [00:33<00:12, 123.84entry/s]
#
#
# Extracting entities:  73%|███████▎  | 4101/5654 [00:33<00:12, 123.47entry/s]
#
#
# Extracting entities:  73%|███████▎  | 4115/5654 [00:33<00:12, 126.00entry/s]
#
#
# Extracting entities:  73%|███████▎  | 4128/5654 [00:33<00:12, 126.58entry/s]
#
#
# Extracting entities:  73%|███████▎  | 4141/5654 [00:33<00:11, 126.89entry/s]
#
#
# Extracting entities:  73%|███████▎  | 4154/5654 [00:33<00:11, 127.52entry/s]
#
#
# Extracting entities:  74%|███████▎  | 4167/5654 [00:33<00:11, 127.38entry/s]
#
#
# Extracting entities:  74%|███████▍  | 4180/5654 [00:33<00:12, 119.80entry/s]
#
#
# Extracting entities:  74%|███████▍  | 4193/5654 [00:33<00:12, 120.48entry/s]
#
#
# Extracting entities:  74%|███████▍  | 4206/5654 [00:34<00:12, 120.66entry/s]
#
#
# Extracting entities:  75%|███████▍  | 4219/5654 [00:34<00:11, 119.80entry/s]
#
#
#
#
#
#
# Extracting entities:  75%|███████▌  | 4245/5654 [00:34<00:20, 67.91entry/s]
#
#
# Extracting entities:  75%|███████▌  | 4257/5654 [00:34<00:18, 77.16entry/s]
#
#
# Extracting entities:  75%|███████▌  | 4268/5654 [00:34<00:16, 83.77entry/s]
#
#
# Extracting entities:  76%|███████▌  | 4282/5654 [00:34<00:14, 94.94entry/s]
#
#
# Extracting entities:  76%|███████▌  | 4295/5654 [00:35<00:13, 102.54entry/s]
#
#
# Extracting entities:  76%|███████▌  | 4308/5654 [00:35<00:12, 108.49entry/s]
#
#
# Extracting entities:  76%|███████▋  | 4321/5654 [00:35<00:11, 113.14entry/s]
#
#
# Extracting entities:  77%|███████▋  | 4335/5654 [00:35<00:11, 118.64entry/s]
#
#
# Extracting entities:  77%|███████▋  | 4350/5654 [00:35<00:10, 124.77entry/s]
#
#
# Extracting entities:  77%|███████▋  | 4363/5654 [00:35<00:10, 125.35entry/s]
#
#
# Extracting entities:  77%|███████▋  | 4376/5654 [00:35<00:10, 121.34entry/s]
#
#
# Extracting entities:  78%|███████▊  | 4389/5654 [00:35<00:10, 117.90entry/s]
#
#
# Extracting entities:  78%|███████▊  | 4402/5654 [00:35<00:10, 119.75entry/s]
#
#
# Extracting entities:  78%|███████▊  | 4415/5654 [00:36<00:10, 121.99entry/s]
#
#
# Extracting entities:  78%|███████▊  | 4428/5654 [00:36<00:10, 122.39entry/s]
#
#
# Extracting entities:  79%|███████▊  | 4441/5654 [00:36<00:09, 123.76entry/s]
#
#
# Extracting entities:  79%|███████▉  | 4454/5654 [00:36<00:09, 124.10entry/s]
#
#
# Extracting entities:  79%|███████▉  | 4467/5654 [00:36<00:09, 124.92entry/s]
#
#
# Extracting entities:  79%|███████▉  | 4480/5654 [00:36<00:09, 125.40entry/s]
#
#
# Extracting entities:  79%|███████▉  | 4493/5654 [00:36<00:09, 124.88entry/s]
#
#
# Extracting entities:  80%|███████▉  | 4506/5654 [00:36<00:09, 125.14entry/s]
#
#
# Extracting entities:  80%|███████▉  | 4519/5654 [00:36<00:09, 124.57entry/s]
#
#
# Extracting entities:  80%|████████  | 4532/5654 [00:36<00:08, 124.73entry/s]
#
#
# Extracting entities:  80%|████████  | 4545/5654 [00:37<00:08, 124.25entry/s]
#
#
# Extracting entities:  81%|████████  | 4558/5654 [00:37<00:08, 124.63entry/s]
#
#
# Extracting entities:  81%|████████  | 4571/5654 [00:37<00:08, 123.74entry/s]
#
#
# Extracting entities:  81%|████████  | 4584/5654 [00:37<00:08, 125.45entry/s]
#
#
# Extracting entities:  81%|████████▏ | 4598/5654 [00:37<00:08, 127.08entry/s]
#
#
# Extracting entities:  82%|████████▏ | 4612/5654 [00:37<00:08, 129.78entry/s]
#
#
# Extracting entities:  82%|████████▏ | 4625/5654 [00:37<00:08, 127.31entry/s]
#
#
# Extracting entities:  82%|████████▏ | 4638/5654 [00:37<00:08, 120.08entry/s]
#
#
# Extracting entities:  82%|████████▏ | 4651/5654 [00:37<00:08, 119.98entry/s]
#
#
# Extracting entities:  82%|████████▏ | 4664/5654 [00:38<00:08, 120.13entry/s]
#
#
# Extracting entities:  83%|████████▎ | 4677/5654 [00:38<00:08, 121.14entry/s]
#
#
# Extracting entities:  83%|████████▎ | 4690/5654 [00:38<00:07, 121.55entry/s]
#
#
# Extracting entities:  83%|████████▎ | 4703/5654 [00:38<00:07, 123.58entry/s]
#
#
# Extracting entities:  83%|████████▎ | 4716/5654 [00:38<00:07, 123.46entry/s]
#
#
# Extracting entities:  84%|████████▎ | 4729/5654 [00:38<00:07, 124.46entry/s]
#
#
# Extracting entities:  84%|████████▍ | 4742/5654 [00:38<00:07, 124.39entry/s]
#
#
# Extracting entities:  84%|████████▍ | 4755/5654 [00:38<00:07, 124.34entry/s]
#
#
# Extracting entities:  84%|████████▍ | 4768/5654 [00:38<00:07, 124.93entry/s]
#
#
# Extracting entities:  85%|████████▍ | 4781/5654 [00:38<00:06, 125.32entry/s]
#
#
# Extracting entities:  85%|████████▍ | 4794/5654 [00:39<00:06, 124.80entry/s]
#
#
# Extracting entities:  85%|████████▌ | 4807/5654 [00:39<00:06, 124.11entry/s]
#
#
# Extracting entities:  85%|████████▌ | 4820/5654 [00:39<00:06, 124.74entry/s]
#
#
# Extracting entities:  85%|████████▌ | 4833/5654 [00:39<00:06, 125.96entry/s]
#
#
# Extracting entities:  86%|████████▌ | 4846/5654 [00:39<00:06, 125.74entry/s]
#
#
# Extracting entities:  86%|████████▌ | 4859/5654 [00:39<00:06, 123.36entry/s]
#
#
# Extracting entities:  86%|████████▌ | 4873/5654 [00:39<00:06, 125.78entry/s]
#
#
# Extracting entities:  86%|████████▋ | 4886/5654 [00:39<00:06, 121.72entry/s]
#
#
# Extracting entities:  87%|████████▋ | 4899/5654 [00:39<00:06, 120.18entry/s]
#
#
# Extracting entities:  87%|████████▋ | 4912/5654 [00:40<00:06, 121.60entry/s]
#
#
# Extracting entities:  87%|████████▋ | 4925/5654 [00:40<00:05, 121.69entry/s]
#
#
# Extracting entities:  87%|████████▋ | 4938/5654 [00:40<00:05, 123.43entry/s]
#
#
# Extracting entities:  88%|████████▊ | 4951/5654 [00:40<00:05, 124.45entry/s]
#
#
# Extracting entities:  88%|████████▊ | 4964/5654 [00:40<00:05, 125.95entry/s]
#
#
# Extracting entities:  88%|████████▊ | 4977/5654 [00:40<00:05, 123.74entry/s]
#
#
# Extracting entities:  88%|████████▊ | 4990/5654 [00:40<00:05, 122.28entry/s]
#
#
# Extracting entities:  88%|████████▊ | 5003/5654 [00:40<00:05, 121.65entry/s]
#
#
# Extracting entities:  89%|████████▊ | 5016/5654 [00:40<00:05, 122.07entry/s]
#
#
# Extracting entities:  89%|████████▉ | 5029/5654 [00:41<00:05, 123.12entry/s]
#
#
# Extracting entities:  89%|████████▉ | 5042/5654 [00:41<00:04, 122.78entry/s]
#
#
# Extracting entities:  89%|████████▉ | 5055/5654 [00:41<00:04, 122.47entry/s]
#
#
# Extracting entities:  90%|████████▉ | 5068/5654 [00:41<00:04, 123.24entry/s]
#
#
# Extracting entities:  90%|████████▉ | 5081/5654 [00:41<00:04, 124.95entry/s]
#
#
# Extracting entities:  90%|█████████ | 5094/5654 [00:41<00:04, 125.61entry/s]
#
#
# Extracting entities:  90%|█████████ | 5107/5654 [00:41<00:04, 125.06entry/s]
#
#
# Extracting entities:  91%|█████████ | 5120/5654 [00:41<00:04, 124.92entry/s]
#
#
# Extracting entities:  91%|█████████ | 5133/5654 [00:41<00:04, 124.26entry/s]
#
#
# Extracting entities:  91%|█████████ | 5146/5654 [00:41<00:04, 124.48entry/s]
#
#
# Extracting entities:  91%|█████████ | 5159/5654 [00:42<00:03, 125.13entry/s]
#
#
# Extracting entities:  91%|█████████▏| 5172/5654 [00:42<00:03, 123.58entry/s]
#
#
# Extracting entities:  92%|█████████▏| 5185/5654 [00:42<00:03, 122.85entry/s]
#
#
# Extracting entities:  92%|█████████▏| 5198/5654 [00:42<00:03, 123.58entry/s]
#
#
# Extracting entities:  92%|█████████▏| 5211/5654 [00:42<00:03, 121.02entry/s]
#
#
# Extracting entities:  92%|█████████▏| 5224/5654 [00:42<00:03, 120.03entry/s]
#
#
# Extracting entities:  93%|█████████▎| 5237/5654 [00:42<00:03, 120.24entry/s]
#
#
# Extracting entities:  93%|█████████▎| 5250/5654 [00:42<00:03, 118.44entry/s]
#
#
# Extracting entities:  93%|█████████▎| 5262/5654 [00:42<00:03, 114.86entry/s]
#
#
# Extracting entities:  93%|█████████▎| 5274/5654 [00:43<00:03, 114.93entry/s]
#
#
# Extracting entities:  93%|█████████▎| 5286/5654 [00:43<00:03, 114.26entry/s]
#
#
# Extracting entities:  94%|█████████▎| 5298/5654 [00:43<00:03, 115.17entry/s]
#
#
# Extracting entities:  94%|█████████▍| 5310/5654 [00:43<00:02, 115.44entry/s]
#
#
# Extracting entities:  94%|█████████▍| 5322/5654 [00:43<00:02, 116.09entry/s]
#
#
# Extracting entities:  94%|█████████▍| 5334/5654 [00:43<00:02, 112.75entry/s]
#
#
# Extracting entities:  95%|█████████▍| 5346/5654 [00:43<00:02, 111.95entry/s]
#
#
# Extracting entities:  95%|█████████▍| 5358/5654 [00:43<00:02, 112.41entry/s]
#
#
# Extracting entities:  95%|█████████▍| 5370/5654 [00:43<00:02, 110.41entry/s]
#
#
# Extracting entities:  95%|█████████▌| 5382/5654 [00:43<00:02, 108.42entry/s]
#
#
# Extracting entities:  95%|█████████▌| 5393/5654 [00:44<00:02, 108.22entry/s]
#
#
# Extracting entities:  96%|█████████▌| 5405/5654 [00:44<00:02, 110.54entry/s]
#
#
# Extracting entities:  96%|█████████▌| 5417/5654 [00:44<00:02, 109.35entry/s]
#
#
# Extracting entities:  96%|█████████▌| 5430/5654 [00:44<00:01, 113.79entry/s]
#
#
# Extracting entities:  96%|█████████▋| 5442/5654 [00:44<00:01, 115.36entry/s]
#
#
# Extracting entities:  96%|█████████▋| 5454/5654 [00:44<00:01, 114.89entry/s]
#
#
# Extracting entities:  97%|█████████▋| 5467/5654 [00:44<00:01, 117.52entry/s]
#
#
# Extracting entities:  97%|█████████▋| 5479/5654 [00:44<00:01, 115.37entry/s]
#
#
# Extracting entities:  97%|█████████▋| 5491/5654 [00:44<00:01, 114.67entry/s]
#
#
# Extracting entities:  97%|█████████▋| 5503/5654 [00:45<00:01, 115.15entry/s]
#
#
# Extracting entities:  98%|█████████▊| 5515/5654 [00:45<00:01, 115.42entry/s]
#
#
# Extracting entities:  98%|█████████▊| 5527/5654 [00:45<00:01, 115.48entry/s]
#
#
# Extracting entities:  98%|█████████▊| 5540/5654 [00:45<00:00, 117.31entry/s]
#
#
# Extracting entities:  98%|█████████▊| 5552/5654 [00:45<00:00, 117.59entry/s]
#
#
# Extracting entities:  98%|█████████▊| 5565/5654 [00:45<00:00, 118.95entry/s]
#
#
# Extracting entities:  99%|█████████▊| 5578/5654 [00:45<00:00, 121.21entry/s]
#
#
# Extracting entities:  99%|█████████▉| 5591/5654 [00:45<00:00, 121.43entry/s]
#
#
# Extracting entities:  99%|█████████▉| 5604/5654 [00:45<00:00, 121.91entry/s]
#
#
# Extracting entities:  99%|█████████▉| 5617/5654 [00:45<00:00, 122.89entry/s]
#
#
# Extracting entities: 100%|█████████▉| 5630/5654 [00:46<00:00, 121.32entry/s]
#
#
# Extracting entities: 100%|█████████▉| 5643/5654 [00:46<00:00, 121.30entry/s]
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ## Google daily news

# %% [markdown]
# ### Actual news

# %% [markdown]
# ### Sample datasets with more prompt information (but also with content ofc)
#
# different subheadings
#
# https://www.kaggle.com/datasets/diegoexe/2024-us-presidential-elections-top-news?select=fox-news_articles.txt
#
# https://www.kaggle.com/datasets/rmisra/news-category-dataset
#
#
# https://www.kaggle.com/code/adityarahul/fakenewsdetection/input
#
#
# https://www.kaggle.com/datasets/mrisdal/fake-news
#
# https://www.kaggle.com/datasets/ruchi798/source-based-news-classification/data
#
#
# includes half truth - https://www.kaggle.com/datasets/shivkumarganesh/politifact-factcheck-data
#
#
# https://www.kaggle.com/datasets/thedevastator/fakecovid-fact-checked-news-dataset - fact checked covid

# %% [markdown]
# ## Uk titles

# %%
uk_headlines = pd.read_csv('./Datasets/Overall_news/news_headlines_20_days.csv')
uk_headlines = uk_headlines.sample(10000)

# %%
uk_headlines['website'].unique()
# Out:
# array(['Telegraph', 'Times', 'Daily Mail', 'Independent',
#        'Manchester Evening News', 'Liverpool Echo', 'Birmingham Live',
#        'Guardian', 'BBC', 'Daily Express', 'Mirror', 'Sun', 'Sky News',
#        'Metro', 'Evening Standard'], dtype=object)

# %%
uk_headlines.columns, global_df.columns
# Out:
# (Index(['id', 'website', 'timestamp scraped', 'headline'], dtype='object'),
#  Index(['title', 'body', 'source', 'timestamp', 'Misinfo_flag',
#         'type_of_misinfo', 'type_reddit', 'topic', 'subtopic', 'entities',
#         'Polarization_flag', '\tMisinfo_flag', 'type_of_content',
#         'potential_prompt0', 'hashtags', 'gender', 'sentiment_category',
#         'Publisher', 'subtitle', 'prochoice_prolife'],
#        dtype='object'))

# %%
process_and_add_to_global(
    uk_headlines,
    dataset_name="news",
    column_mapping={ "title":"headline",
                    "timestamp":'timestamp scraped',
                     },
    # topic = 'news',

    additional_columns={
        'potential_prompt0': uk_headlines['headline'],
        'Polarization_flag': uk_headlines['website'].map({'BBC': 'Neutral/Mixed',
    'Sun': 'Conservative/Republican-leaning',
    'Mirror': 'Labour/Democratic-leaning',
    'Daily Mail': 'Conservative/Republican-leaning',
    'Independent': 'Labour/Democratic-leaning',
    'Telegraph': 'Conservative/Republican-leaning',
    'Guardian': 'Labour/Democratic-leaning',
    'Manchester Evening News': 'Neutral/Mixed',
    'Sky News': 'Neutral/Mixed (slightly Conservative)',
    'Metro': 'Neutral/Mixed',
    'Daily Express': 'Conservative/Republican-leaning',
    'Times': 'Conservative/Republican-leaning',
    'Liverpool Echo': 'Labour/Democratic-leaning',
    'Birmingham Live': 'Neutral/Mixed',
    'Evening Standard': 'Conservative/Republican-leaning'}),
        "Publisher": uk_headlines['website']
    }

)
# Out:
# <ipython-input-9-d2cb83ac51c1>:35: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   standardized_data["timestamp"] = pd.to_datetime(standardized_data.get("timestamp", None), errors="coerce")
# <ipython-input-9-d2cb83ac51c1>:35: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   standardized_data["timestamp"] = pd.to_datetime(standardized_data.get("timestamp", None), errors="coerce")
# Processing dataset: news
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
global_df.tail(15)
# Out:
#                                                     title body source  \
# 239734  You can see what drivers rate you on Uber: Fin...  NaN   news
# 239735  Norovirus levels ‘significantly higher’ than l...  NaN   news
# 239736  Westhoughton town hall project could see cinem...  NaN   news
# 239737  Eggs and margarine drive food inflation to rec...  NaN   news
# 239738  Two elderly people trapped in their homes in C...  NaN   news
# 239739  The final email and an abandoned Teams call: T...  NaN   news
# 239740  Mortified woman buys portraits - then discover...  NaN   news
# 239741  \n\tMore than 10,000 pride pin badges ordered ...  NaN   news
# 239742  Argos to close 50 stores in 2023 amid Sainsbur...  NaN   news
# 239743  EasyJet pilot does mid-air 360-degree turn so ...  NaN   news
# 239744  Liverpool transfer news - Alexis Mac Allister ...  NaN   news
# 239745  \n\tDisney petition: Employees rebel against B...  NaN   news
# 239746  ULEZ Expansion 2023: Sadiq Khan's advert inves...  NaN   news
# 239747  Dynasty star Stephanie Beacham struggled learn...  NaN   news
# 239748  Crowds gather in Omagh to demand end to violen...  NaN   news
#
#                         timestamp  Misinfo_flag type_of_misinfo type_reddit  \
# 239734                        NaT           NaN             NaN         NaN
# 239735  2023-02-16 13:00:00-10:00           NaN             NaN         NaN
# 239736  2023-02-17 13:00:00-18:00           NaN             NaN         NaN
# 239737                        NaT           NaN             NaN         NaN
# 239738                        NaT           NaN             NaN         NaN
# 239739                        NaT           NaN             NaN         NaN
# 239740                        NaT           NaN             NaN         NaN
# 239741                        NaT           NaN             NaN         NaN
# 239742  2023-02-25 14:00:00-19:00           NaN             NaN         NaN
# 239743                        NaT           NaN             NaN         NaN
# 239744                        NaT           NaN             NaN         NaN
# 239745                        NaT           NaN             NaN         NaN
# 239746  2023-02-25 14:00:00-19:00           NaN             NaN         NaN
# 239747                        NaT           NaN             NaN         NaN
# 239748                        NaT           NaN             NaN         NaN
#
#        topic subtopic                                           entities  \
# 239734  None     None  {'people': [], 'organizations': [], 'locations...
# 239735  None     None  {'people': [], 'organizations': [], 'locations...
# 239736  None     None  {'people': [], 'organizations': [], 'locations...
# 239737  None     None  {'people': [], 'organizations': [], 'locations...
# 239738  None     None  {'people': [], 'organizations': ['Chaah'], 'lo...
# 239739  None     None  {'people': [], 'organizations': [], 'locations...
# 239740  None     None  {'people': [], 'organizations': [], 'locations...
# 239741  None     None  {'people': [], 'organizations': ['NHS'], 'loca...
# 239742  None     None  {'people': [], 'organizations': ['Sainsbury'],...
# 239743  None     None  {'people': [], 'organizations': ['EasyJet'], '...
# 239744  None     None  {'people': ['Luka Sucic'], 'organizations': ['...
# 239745  None     None  {'people': ['Bob Iger's'], 'organizations': []...
# 239746  None     None  {'people': ['Khan'], 'organizations': ['ULEZ E...
# 239747  None     None  {'people': ['Stephanie Beacham'], 'organizatio...
# 239748  None     None  {'people': ['Omagh'], 'organizations': [], 'lo...
#
#                       Polarization_flag  \tMisinfo_flag type_of_content  \
# 239734  Conservative/Republican-leaning             NaN             NaN
# 239735        Labour/Democratic-leaning             NaN             NaN
# 239736                    Neutral/Mixed             NaN             NaN
# 239737                    Neutral/Mixed             NaN             NaN
# 239738  Conservative/Republican-leaning             NaN             NaN
# 239739        Labour/Democratic-leaning             NaN             NaN
# 239740        Labour/Democratic-leaning             NaN             NaN
# 239741  Conservative/Republican-leaning             NaN             NaN
# 239742  Conservative/Republican-leaning             NaN             NaN
# 239743                    Neutral/Mixed             NaN             NaN
# 239744        Labour/Democratic-leaning             NaN             NaN
# 239745  Conservative/Republican-leaning             NaN             NaN
# 239746  Conservative/Republican-leaning             NaN             NaN
# 239747        Labour/Democratic-leaning             NaN             NaN
# 239748  Conservative/Republican-leaning             NaN             NaN
#
#                                         potential_prompt0 hashtags gender  \
# 239734  You can see what drivers rate you on Uber: Fin...      NaN    NaN
# 239735  Norovirus levels ‘significantly higher’ than l...      NaN    NaN
# 239736  Westhoughton town hall project could see cinem...      NaN    NaN
# 239737  Eggs and margarine drive food inflation to rec...      NaN    NaN
# 239738  Two elderly people trapped in their homes in C...      NaN    NaN
# 239739  The final email and an abandoned Teams call: T...      NaN    NaN
# 239740  Mortified woman buys portraits - then discover...      NaN    NaN
# 239741  \n\tMore than 10,000 pride pin badges ordered ...      NaN    NaN
# 239742  Argos to close 50 stores in 2023 amid Sainsbur...      NaN    NaN
# 239743  EasyJet pilot does mid-air 360-degree turn so ...      NaN    NaN
# 239744  Liverpool transfer news - Alexis Mac Allister ...      NaN    NaN
# 239745  \n\tDisney petition: Employees rebel against B...      NaN    NaN
# 239746  ULEZ Expansion 2023: Sadiq Khan's advert inves...      NaN    NaN
# 239747  Dynasty star Stephanie Beacham struggled learn...      NaN    NaN
# 239748  Crowds gather in Omagh to demand end to violen...      NaN    NaN
#
#        sentiment_category                Publisher subtitle prochoice_prolife
# 239734                NaN                    Times      NaN               NaN
# 239735                NaN              Independent      NaN               NaN
# 239736                NaN  Manchester Evening News      NaN               NaN
# 239737                NaN                      BBC      NaN               NaN
# 239738                NaN                      Sun      NaN               NaN
# 239739                NaN              Independent      NaN               NaN
# 239740                NaN                   Mirror      NaN               NaN
# 239741                NaN               Daily Mail      NaN               NaN
# 239742                NaN                    Times      NaN               NaN
# 239743                NaN                    Metro      NaN               NaN
# 239744                NaN           Liverpool Echo      NaN               NaN
# 239745                NaN               Daily Mail      NaN               NaN
# 239746                NaN                    Times      NaN               NaN
# 239747                NaN              Independent      NaN               NaN
# 239748                NaN         Evening Standard      NaN               NaN

# %% [markdown]
# # news with short descriptions (may be used for prompting)

# %%
news_category = pd.read_json('./Datasets/Overall_news/News_Category_Dataset_v3.json', lines=True)

# %%
news_category = news_category.sample(10000)

# %%
news_category.head()
# Out:
#                                                      link  \
# 153     https://www.huffpost.com/entry/bc-lt-mexico-mi...
# 57281   https://www.huffingtonpost.com/entry/nickelode...
# 135354  https://www.huffingtonpost.com/entry/nike-shoe...
# 171993  https://www.huffingtonpost.com/entry/paris-fas...
# 181422  https://www.huffingtonpost.comhttp://www.care2...
#
#                                                  headline        category  \
# 153     6 Missing College Students In Mexico Were Held...      WORLD NEWS
# 57281   Even Kids Know Equality For Everyone Is Important        POLITICS
# 135354  If You Don't Have A Pair Of Badass Nike Shoes,...  STYLE & BEAUTY
# 171993      Who Needs Fashion When You Really Need Sleep?  STYLE & BEAUTY
# 181422  If A Teenage Girl Is Unhappy, It's Mom's Fault...       PARENTING
#
#                                         short_description  \
# 153     Six of 43 students kidnapped in 2014 were kept...
# 57281   The top issues for kids in this election inclu...
# 135354  This week Nike celebrated the 27th anniversary...
# 171993  It is the end of Paris Fashion Week and I am f...
# 181422  Just what mothers need: one more thing to feel...
#
#                                               authors       date
# 153       Fabiola Sánchez and Christopher Sherman, AP 2022-08-27
# 57281                                  Amber Ferguson 2016-09-07
# 135354                                    Megan Mayer 2014-03-30
# 171993  Eddie Parsons, Contributor\nFashion Marketing 2013-03-06
# 181422                                                2012-11-26

# %%
process_and_add_to_global(
    news_category,
    dataset_name="news",
    column_mapping={ "title":"headline",
                    "timestamp":"date",
                     'body':'short_description'},
    # topic = 'news',

    additional_columns={
        'potential_prompt0': news_category['headline'],
        'topic': news_category['category']}
        # 'type_of_content': 'news',
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0ade87060623> in <cell line: 1>()
# ----> 1 process_and_add_to_global(
#       2     news_category,
#       3     dataset_name="news",
#       4     column_mapping={ "title":"headline",
#       5                     "timestamp":"date",
#
# NameError: name 'process_and_add_to_global' is not defined

# %%
global_df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d34fd07f4a08> in <cell line: 1>()
# ----> 1 global_df.tail()
#
# NameError: name 'global_df' is not defined

# %% [markdown]
# ## Fake news

# %%
fakenews = pd.read_csv('./Datasets/fakeNews/WELFake_Dataset.csv')
fakenews = fakenews.sample(10000)
## append fakenews

# %%
fakenews.head()
# Out:
#        Unnamed: 0                                              title  \
# 60909       60909              Trove of Bin Laden documents released
# 16707       16707   Secret Service Just Killed The Fun: No Open C...
# 40031       40031   Democrats Are Pushing A Bill On Tax Returns T...
# 53583       53583   Zimbabwe truck accident kills 21, injures others
# 31336       31336  Clinton Gets Back In The Game After Blowout Lo...
#
#                                                     text  label
# 60909  U.S. intelligence officials on Wednesday relea...      0
# 16707  Despite a petition calling for guns to be allo...      1
# 40031  What is the one thing that might actually scar...      1
# 53583  HARARE (Reuters) - At least 21 people died in ...      0
# 31336  Clinton Gets Back In The Game After Blowout Lo...      0

# %%
process_and_add_to_global(
    fakenews,
    dataset_name="news",
    column_mapping={ "title":"title",
                    "body":"text"},


    additional_columns={
        'Misinfo_flag': fakenews['label']

    }
)
# Out:
# Processing dataset: news
# Extracting entities:  27%|██▋       | 2719/10000 [03:31<04:30, 26.92entry/s]
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %% [markdown]
# ## for prompting   - headlines
#
# https://www.kaggle.com/datasets/sagunsh/coronavirus-news-headline
#
# https://www.kaggle.com/datasets/fringewidth/climate-change-news
#
# https://www.kaggle.com/datasets/dexmasa/uk-news-headlines
#
# good on the fake news in politics - https://www.kaggle.com/datasets/techykajal/fakereal-news

# %% [markdown]
# ## Coronavirus headlines with publisher and polit affiliation

# %%
covid_headlines = pd.read_csv('./Datasets/Covid_Datasets/corona_news.csv', on_bad_lines='skip')
covid_headlines = covid_headlines.sample(10000)
# Out:
# <ipython-input-64-394ae3e7f7db>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid_headlines = pd.read_csv('./Datasets/Covid_Datasets/corona_news.csv', on_bad_lines='skip')

# %%
process_and_add_to_global(
    covid_headlines,
    dataset_name="news",
    column_mapping={ "title":"title",
                    "timestamp":"published_date"},
    topic = 'COVID',

    additional_columns={
        'potential_prompt0': covid_headlines['title'],
        'Publisher': covid_headlines['source'],
        'type_of_content': 'Covid news',
        'Polarization_flag': covid_headlines['source'].map({
            'nationalpost.com': 'Neutral/Mixed',
    'news.yahoo.com': 'Democratic',
    'dailymail.co.uk': 'Republican',
    'theguardian.com': 'Democratic',
    'feeds.foxnews.com': 'Republican'})


    }
)
# Out:
# Processing dataset: news
# Global dataframe saved to: /content/drive/MyDrive/MIDS/XAI/XAI_Final_project/global_dataset.csv

# %%
# Out:
#                                                     title  \
# 185614                                                NaN
# 125839                                                NaN
# 12216   People who suffer from ‘significant’ allergic ...
# 162166                                                NaN
# 164142  How sanctions became Bidens weapon of choice ...
# 52649                                                 NaN
# 203432  Maharashtra Covid-19 toll up by 1,328 after st...
# 189211                                                NaN
# 208194  Navy opens full investigation into coronavirus...
# 158121                                                NaN
#
#                                                      body   source  \
# 185614  Life is always best!!! #chooselife #ProLife ht...  twitter
# 125839  RT @NARAL: “There is nothing ‘pro-life’ about ...  twitter
# 12216   Those are entirely valid concerns. \n\nDo keep...   Reddit
# 162166  An interesting article for those who have been...  twitter
# 164142  Sanctions, long before the war in Ukraine, hav...     news
# 52649   The Broward Co. Sheriff, in front of a nationw...  twitter
# 203432                                                NaN     news
# 189211  It is what it is 🤷🏻‍♀️#roevwade #prochoice #fu...  twitter
# 208194                                                NaN     news
# 158121  RT @LarrySabato: The term $q$cafeteria Catholi...  twitter
#
#                         timestamp  Misinfo_flag type_of_misinfo  \
# 185614  2022-06-26 21:31:04+00:00           NaN             NaN
# 125839        2018-02-09 00:05:53           NaN             NaN
# 12216         2020-12-10 16:40:06           NaN             NaN
# 162166                       None           NaN             NaN
# 164142                       None           NaN             NaN
# 52649                         NaN           NaN             NaN
# 203432        2020-06-17 03:09:49           NaN             NaN
# 189211  2022-07-03 18:23:07+00:00           NaN             NaN
# 208194        2020-04-29 23:38:25           NaN             NaN
# 158121                       None           NaN             NaN
#
#            type_reddit           topic     subtopic  \
# 185614             NaN        Abortion         None
# 125839             NaN        Abortion         None
# 12216   post_and_title           COVID     Vaccines
# 162166             NaN  Climate Change         None
# 164142             NaN             War  Afghanistan
# 52649              NaN    Polarization          NaN
# 203432             NaN           COVID         None
# 189211             NaN        Abortion         None
# 208194             NaN           COVID         None
# 158121             NaN  Climate Change         None
#
#                                                  entities Polarization_flag  \
# 185614  {'people': [], 'organizations': [], 'locations...               NaN
# 125839  {'people': [], 'organizations': ['RT @NARAL'],...               NaN
# 12216   {'people': [], 'organizations': ['CVS'], 'loca...               NaN
# 162166  {'people': ['¦'], 'organizations': [], 'locati...               NaN
# 164142  {'people': ['Biden'], 'organizations': [], 'lo...               NaN
# 52649   {'people': ['https://t.co/DsSuPpiyGs'], 'organ...        Republican
# 203432  {'people': [], 'organizations': ['Maharashtra ...               NaN
# 189211  {'people': [], 'organizations': [], 'locations...               NaN
# 208194  {'people': ['USS Theodore Roosevelt'], 'organi...        Republican
# 158121  {'people': ['q$cafeteria', 'Rs'], 'organizatio...               NaN
#
#         \tMisinfo_flag type_of_content  \
# 185614             NaN             NaN
# 125839             NaN             NaN
# 12216              NaN             NaN
# 162166             NaN             NaN
# 164142             NaN        War news
# 52649              NaN             NaN
# 203432             NaN      Covid news
# 189211             NaN             NaN
# 208194             NaN      Covid news
# 158121             NaN             NaN
#
#                                         potential_prompt0 hashtags   gender  \
# 185614                                                NaN      NaN      NaN
# 125839                                                NaN      NaN  unknown
# 12216                                                 NaN      NaN      NaN
# 162166                                                NaN      NaN      NaN
# 164142                                                NaN      NaN      NaN
# 52649                                                 NaN      NaN      NaN
# 203432  Maharashtra Covid-19 toll up by 1,328 after st...      NaN      NaN
# 189211                                                NaN      NaN      NaN
# 208194  Navy opens full investigation into coronavirus...      NaN      NaN
# 158121                                                NaN      NaN      NaN
#
#        sentiment_category              Publisher subtitle prochoice_prolife
# 185614                NaN                    NaN      NaN           prolife
# 125839               None                   None     None              None
# 12216                None                   None     None              None
# 162166                Pro                   None     None              None
# 164142                NaN                    Vox     None              None
# 52649                None                   None     None              None
# 203432                NaN  business-standard.com      NaN               NaN
# 189211                NaN                    NaN      NaN         prochoice
# 208194                NaN      feeds.foxnews.com      NaN               NaN
# 158121            Neutral                   None     None              None

# %% [markdown]
# # super powered tweets
# https://www.kaggle.com/datasets/jackksoncsie/twitter-dataset-keywords-likes-and-tweets -- with a lot of topics labelled for me
#
# political events classifier https://www.kaggle.com/datasets/akashhiremath25/eventclassifier-twitter-data-set -- may use to see which ones it would generate?

# %% [markdown]
# ## Truth social - alternative on politicals discussions
# https://www.kaggle.com/datasets/kashishashah/truthsocial-2024-election-integrity-initiative

# %% [markdown]
# ## trump elections and stuff like that
#
# https://www.kaggle.com/datasets/muhammetakkurt/trump-2024-campaign-truthsocial-truths-tweets

# %% [markdown]
# ## gaza
#
# https://www.kaggle.com/datasets/emirslspr/israel-hamas-conflict-news-dataset
#
# reddit - https://www.kaggle.com/datasets/asaniczka/reddit-on-israel-palestine-daily-updated

# %% [markdown]
# ## sentiments
#
# hatred on me too https://www.kaggle.com/datasets/rahulgoel1106/hatred-on-twitter-during-metoo-movement
